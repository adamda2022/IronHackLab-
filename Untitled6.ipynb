# %%
import config

# %%
import numpy as np
import pandas as pd
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practise
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
from IPython.display import IFrame

# %%
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                           client_secret= config.c_se))

# %%
playlist = sp.user_playlist_tracks("spotify", "6yPiKpy7evrwvZodByKvM9",market="GB")

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

get_playlist_tracks('Spotify','6yPiKpy7evrwvZodByKvM9')
# Out:
# [{'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IVapwlnM3dEOiMsHXsghT'},
#       'href': 'https://api.spotify.com/v1/artists/0IVapwlnM3dEOiMsHXsghT',
#       'id': '0IVapwlnM3dEOiMsHXsghT',
#       'name': 'Nosaj Thing',
#       'type': 'artist',
#       'uri': 'spotify:artist:0IVapwlnM3dEOiMsHXsghT'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3RzkEbP69xVKvZycU8xqFG'},
#     'href': 'https://api.spotify.com/v1/albums/3RzkEbP69xVKvZycU8xqFG',
#     'id': '3RzkEbP69xVKvZycU8xqFG',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dfa3a6bcdb42f3e609a538e0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dfa3a6bcdb42f3e609a538e0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dfa3a6bcdb42f3e609a538e0',
#       'width': 64}],
#     'name': 'Fated',
#     'release_date': '2015-05-04',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3RzkEbP69xVKvZycU8xqFG'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0IVapwlnM3dEOiMsHXsghT'},
#      'href': 'https://api.spotify.com/v1/artists/0IVapwlnM3dEOiMsHXsghT',
#      'id': '0IVapwlnM3dEOiMsHXsghT',
#      'name': 'Nosaj Thing',
#      'type': 'artist',
#      'uri': 'spotify:artist:0IVapwlnM3dEOiMsHXsghT'}],
#    'disc_number': 1,
#    'duration_ms': 152560,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USD8D1528015'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3lMSWyB8H0A0rSRhUDSwoz'},
#    'href': 'https://api.spotify.com/v1/tracks/3lMSWyB8H0A0rSRhUDSwoz',
#    'id': '3lMSWyB8H0A0rSRhUDSwoz',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/33xMbeHzmWd6Od0BmLZEUs'},
#     'href': 'https://api.spotify.com/v1/tracks/33xMbeHzmWd6Od0BmLZEUs',
#     'id': '33xMbeHzmWd6Od0BmLZEUs',
#     'type': 'track',
#     'uri': 'spotify:track:33xMbeHzmWd6Od0BmLZEUs'},
#    'name': '2k',
#    'popularity': 16,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c109a6849f93412d0bbaf14dc2f642dfe7c3d614?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 15,
#    'type': 'track',
#    'uri': 'spotify:track:3lMSWyB8H0A0rSRhUDSwoz'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#       'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#       'id': '22WZ7M8sxp5THdruNY3gXt',
#       'name': 'The Doors',
#       'type': 'artist',
#       'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/26Fac6kNgB6MLeoGVkmpKN'},
#     'href': 'https://api.spotify.com/v1/albums/26Fac6kNgB6MLeoGVkmpKN',
#     'id': '26Fac6kNgB6MLeoGVkmpKN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a217433125ab8324ce5f7e09',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a217433125ab8324ce5f7e09',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a217433125ab8324ce5f7e09',
#       'width': 64}],
#     'name': 'Full Circle',
#     'release_date': '1972-07-17',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:26Fac6kNgB6MLeoGVkmpKN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/22WZ7M8sxp5THdruNY3gXt'},
#      'href': 'https://api.spotify.com/v1/artists/22WZ7M8sxp5THdruNY3gXt',
#      'id': '22WZ7M8sxp5THdruNY3gXt',
#      'name': 'The Doors',
#      'type': 'artist',
#      'uri': 'spotify:artist:22WZ7M8sxp5THdruNY3gXt'}],
#    'disc_number': 1,
#    'duration_ms': 197706,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USEE10609618'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3UnyplmZaq547hwsfOR5yy'},
#    'href': 'https://api.spotify.com/v1/tracks/3UnyplmZaq547hwsfOR5yy',
#    'id': '3UnyplmZaq547hwsfOR5yy',
#    'is_local': False,
#    'is_playable': True,
#    'name': '4 Billion Souls',
#    'popularity': 24,
#    'preview_url': 'https://p.scdn.co/mp3-preview/67062557a83d13768ff455811aeb35d4dc13064b?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:3UnyplmZaq547hwsfOR5yy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6zTAW5oRuOmxJuUHhcQope'},
#     'href': 'https://api.spotify.com/v1/albums/6zTAW5oRuOmxJuUHhcQope',
#     'id': '6zTAW5oRuOmxJuUHhcQope',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734b88d5c1b3358cca2c94ec0b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024b88d5c1b3358cca2c94ec0b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514b88d5c1b3358cca2c94ec0b',
#       'width': 64}],
#     'name': 'In Rainbows (Disk 2)',
#     'release_date': '2007',
#     'release_date_precision': 'year',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:6zTAW5oRuOmxJuUHhcQope'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'disc_number': 1,
#    'duration_ms': 244284,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBSTK0700018'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3HPLfZhQUds6N6tZ4WiApn'},
#    'href': 'https://api.spotify.com/v1/tracks/3HPLfZhQUds6N6tZ4WiApn',
#    'id': '3HPLfZhQUds6N6tZ4WiApn',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1w8QCSDH4QobcQeT4uMKLm'},
#     'href': 'https://api.spotify.com/v1/tracks/1w8QCSDH4QobcQeT4uMKLm',
#     'id': '1w8QCSDH4QobcQeT4uMKLm',
#     'type': 'track',
#     'uri': 'spotify:track:1w8QCSDH4QobcQeT4uMKLm'},
#    'name': '4 Minute Warning',
#    'popularity': 46,
#    'preview_url': 'https://p.scdn.co/mp3-preview/948bcbd67867e775cc7d4034c10703f091f013c9?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3HPLfZhQUds6N6tZ4WiApn'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UK6JkgUMa28b4t8eCtg6P'},
#       'href': 'https://api.spotify.com/v1/artists/0UK6JkgUMa28b4t8eCtg6P',
#       'id': '0UK6JkgUMa28b4t8eCtg6P',
#       'name': 'Vitas',
#       'type': 'artist',
#       'uri': 'spotify:artist:0UK6JkgUMa28b4t8eCtg6P'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7yPAnDgrwZgJz6sTgxViwt'},
#     'href': 'https://api.spotify.com/v1/albums/7yPAnDgrwZgJz6sTgxViwt',
#     'id': '7yPAnDgrwZgJz6sTgxViwt',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273cb60dec99665654fe16d294f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02cb60dec99665654fe16d294f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851cb60dec99665654fe16d294f',
#       'width': 64}],
#     'name': 'Философия чуда',
#     'release_date': '2001',
#     'release_date_precision': 'year',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:7yPAnDgrwZgJz6sTgxViwt'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0UK6JkgUMa28b4t8eCtg6P'},
#      'href': 'https://api.spotify.com/v1/artists/0UK6JkgUMa28b4t8eCtg6P',
#      'id': '0UK6JkgUMa28b4t8eCtg6P',
#      'name': 'Vitas',
#      'type': 'artist',
#      'uri': 'spotify:artist:0UK6JkgUMa28b4t8eCtg6P'}],
#    'disc_number': 1,
#    'duration_ms': 250000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRX201605492'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5iFhkFf9JLA3XiROdYsg1i'},
#    'href': 'https://api.spotify.com/v1/tracks/5iFhkFf9JLA3XiROdYsg1i',
#    'id': '5iFhkFf9JLA3XiROdYsg1i',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7J9mBHG4J2eIfDAv5BehKA'},
#     'href': 'https://api.spotify.com/v1/tracks/7J9mBHG4J2eIfDAv5BehKA',
#     'id': '7J9mBHG4J2eIfDAv5BehKA',
#     'type': 'track',
#     'uri': 'spotify:track:7J9mBHG4J2eIfDAv5BehKA'},
#    'name': '7 элемент',
#    'popularity': 54,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8e390b447e8a4f3999f627079f28b66fa3041460?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:5iFhkFf9JLA3XiROdYsg1i'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5A5XFtOnsqgw9QzghVq5Lf'},
#     'href': 'https://api.spotify.com/v1/albums/5A5XFtOnsqgw9QzghVq5Lf',
#     'id': '5A5XFtOnsqgw9QzghVq5Lf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e3524fed78bd90e266b2d384',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e3524fed78bd90e266b2d384',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e3524fed78bd90e266b2d384',
#       'width': 64}],
#     'name': 'Instant Karma: The Amnesty International Campaign To Save Darfur [The Complete Recordings] (Audio Only)',
#     'release_date': '2007-06-11',
#     'release_date_precision': 'day',
#     'total_tracks': 61,
#     'type': 'album',
#     'uri': 'spotify:album:5A5XFtOnsqgw9QzghVq5Lf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4KWTAlx2RvbpseOGMEmROg'},
#      'href': 'https://api.spotify.com/v1/artists/4KWTAlx2RvbpseOGMEmROg',
#      'id': '4KWTAlx2RvbpseOGMEmROg',
#      'name': 'R.E.M.',
#      'type': 'artist',
#      'uri': 'spotify:artist:4KWTAlx2RvbpseOGMEmROg'}],
#    'disc_number': 1,
#    'duration_ms': 278320,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBLLZ0700007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1VZedwJj1gyi88WFRhfThb'},
#    'href': 'https://api.spotify.com/v1/tracks/1VZedwJj1gyi88WFRhfThb',
#    'id': '1VZedwJj1gyi88WFRhfThb',
#    'is_local': False,
#    'is_playable': True,
#    'name': '#9 Dream',
#    'popularity': 5,
#    'preview_url': 'https://p.scdn.co/mp3-preview/7356549cd8305d9779420a219b8ebc8218c703ff?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 47,
#    'type': 'track',
#    'uri': 'spotify:track:1VZedwJj1gyi88WFRhfThb'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5A5XFtOnsqgw9QzghVq5Lf'},
#     'href': 'https://api.spotify.com/v1/albums/5A5XFtOnsqgw9QzghVq5Lf',
#     'id': '5A5XFtOnsqgw9QzghVq5Lf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e3524fed78bd90e266b2d384',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e3524fed78bd90e266b2d384',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e3524fed78bd90e266b2d384',
#       'width': 64}],
#     'name': 'Instant Karma: The Amnesty International Campaign To Save Darfur [The Complete Recordings] (Audio Only)',
#     'release_date': '2007-06-11',
#     'release_date_precision': 'day',
#     'total_tracks': 61,
#     'type': 'album',
#     'uri': 'spotify:album:5A5XFtOnsqgw9QzghVq5Lf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2jzc5TC5TVFLXQlBNiIUzE'},
#      'href': 'https://api.spotify.com/v1/artists/2jzc5TC5TVFLXQlBNiIUzE',
#      'id': '2jzc5TC5TVFLXQlBNiIUzE',
#      'name': 'a-ha',
#      'type': 'artist',
#      'uri': 'spotify:artist:2jzc5TC5TVFLXQlBNiIUzE'}],
#    'disc_number': 1,
#    'duration_ms': 247066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBLLZ0700013'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3DSmOF7ETJHAQEqqgoSJao'},
#    'href': 'https://api.spotify.com/v1/tracks/3DSmOF7ETJHAQEqqgoSJao',
#    'id': '3DSmOF7ETJHAQEqqgoSJao',
#    'is_local': False,
#    'is_playable': True,
#    'name': '#9 Dream',
#    'popularity': 8,
#    'preview_url': 'https://p.scdn.co/mp3-preview/726c985361c5b1fba595d2ece63b9239688417bf?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:3DSmOF7ETJHAQEqqgoSJao'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#       'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#       'id': '7mnBLXK823vNxN3UWB7Gfz',
#       'name': 'The Black Keys',
#       'type': 'artist',
#       'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6TvxpBzf9c8H1fsrAaQ8t3'},
#     'href': 'https://api.spotify.com/v1/albums/6TvxpBzf9c8H1fsrAaQ8t3',
#     'id': '6TvxpBzf9c8H1fsrAaQ8t3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2731af8fb0d8859055d35d2290f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e021af8fb0d8859055d35d2290f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048511af8fb0d8859055d35d2290f',
#       'width': 64}],
#     'name': 'Turn Blue',
#     'release_date': '2014-05-09',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:6TvxpBzf9c8H1fsrAaQ8t3'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7mnBLXK823vNxN3UWB7Gfz'},
#      'href': 'https://api.spotify.com/v1/artists/7mnBLXK823vNxN3UWB7Gfz',
#      'id': '7mnBLXK823vNxN3UWB7Gfz',
#      'name': 'The Black Keys',
#      'type': 'artist',
#      'uri': 'spotify:artist:7mnBLXK823vNxN3UWB7Gfz'}],
#    'disc_number': 1,
#    'duration_ms': 213226,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USNO11400185'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5HPnumlogzZtpLEaORZjz1'},
#    'href': 'https://api.spotify.com/v1/tracks/5HPnumlogzZtpLEaORZjz1',
#    'id': '5HPnumlogzZtpLEaORZjz1',
#    'is_local': False,
#    'is_playable': True,
#    'name': '10 Lovers',
#    'popularity': 51,
#    'preview_url': 'https://p.scdn.co/mp3-preview/11696698187388fdbb621e3d39ca05038f608f1a?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:5HPnumlogzZtpLEaORZjz1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rAv1GhTQ2rmG94p9lU3rB'},
#       'href': 'https://api.spotify.com/v1/artists/1rAv1GhTQ2rmG94p9lU3rB',
#       'id': '1rAv1GhTQ2rmG94p9lU3rB',
#       'name': 'Julian Casablancas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1rAv1GhTQ2rmG94p9lU3rB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/22sqaYEVQVbt9hG6cvocKh'},
#     'href': 'https://api.spotify.com/v1/albums/22sqaYEVQVbt9hG6cvocKh',
#     'id': '22sqaYEVQVbt9hG6cvocKh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ad098ad60efad80116b08250',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ad098ad60efad80116b08250',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ad098ad60efad80116b08250',
#       'width': 64}],
#     'name': 'Phrazes for the Young',
#     'release_date': '2009-11-02',
#     'release_date_precision': 'day',
#     'total_tracks': 8,
#     'type': 'album',
#     'uri': 'spotify:album:22sqaYEVQVbt9hG6cvocKh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1rAv1GhTQ2rmG94p9lU3rB'},
#      'href': 'https://api.spotify.com/v1/artists/1rAv1GhTQ2rmG94p9lU3rB',
#      'id': '1rAv1GhTQ2rmG94p9lU3rB',
#      'name': 'Julian Casablancas',
#      'type': 'artist',
#      'uri': 'spotify:artist:1rAv1GhTQ2rmG94p9lU3rB'}],
#    'disc_number': 1,
#    'duration_ms': 245533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10900512'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ZwQZ0uasFP54ivamFLLhP'},
#    'href': 'https://api.spotify.com/v1/tracks/1ZwQZ0uasFP54ivamFLLhP',
#    'id': '1ZwQZ0uasFP54ivamFLLhP',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6i99ThziImjuFABb8rUQvy'},
#     'href': 'https://api.spotify.com/v1/tracks/6i99ThziImjuFABb8rUQvy',
#     'id': '6i99ThziImjuFABb8rUQvy',
#     'type': 'track',
#     'uri': 'spotify:track:6i99ThziImjuFABb8rUQvy'},
#    'name': '11th Dimension',
#    'popularity': 36,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c3e9c5e7f575e431ad3b485eeba2d09bfa2142ac?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1ZwQZ0uasFP54ivamFLLhP'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3HFbH1loOUbqCyPsLuHLLh'},
#     'href': 'https://api.spotify.com/v1/albums/3HFbH1loOUbqCyPsLuHLLh',
#     'id': '3HFbH1loOUbqCyPsLuHLLh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730f35726025e0f025da4c688f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020f35726025e0f025da4c688f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510f35726025e0f025da4c688f',
#       'width': 64}],
#     'name': 'Room On Fire',
#     'release_date': '2003-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3HFbH1loOUbqCyPsLuHLLh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#      'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#      'id': '0epOFNiUfyON9EYx7Tpr6V',
#      'name': 'The Strokes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#    'disc_number': 1,
#    'duration_ms': 153133,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10301489'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Yu1OL8I0D4vjOzYdsXYGK'},
#    'href': 'https://api.spotify.com/v1/tracks/6Yu1OL8I0D4vjOzYdsXYGK',
#    'id': '6Yu1OL8I0D4vjOzYdsXYGK',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0nkLI0pdyTRpq7BsTFBufZ'},
#     'href': 'https://api.spotify.com/v1/tracks/0nkLI0pdyTRpq7BsTFBufZ',
#     'id': '0nkLI0pdyTRpq7BsTFBufZ',
#     'type': 'track',
#     'uri': 'spotify:track:0nkLI0pdyTRpq7BsTFBufZ'},
#    'name': '12:51',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/42b1f98b5145116b35f5a08fe5690ba8ff8bbde4?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6Yu1OL8I0D4vjOzYdsXYGK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3HFbH1loOUbqCyPsLuHLLh'},
#     'href': 'https://api.spotify.com/v1/albums/3HFbH1loOUbqCyPsLuHLLh',
#     'id': '3HFbH1loOUbqCyPsLuHLLh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2730f35726025e0f025da4c688f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e020f35726025e0f025da4c688f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048510f35726025e0f025da4c688f',
#       'width': 64}],
#     'name': 'Room On Fire',
#     'release_date': '2003-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3HFbH1loOUbqCyPsLuHLLh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#      'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#      'id': '0epOFNiUfyON9EYx7Tpr6V',
#      'name': 'The Strokes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#    'disc_number': 1,
#    'duration_ms': 153133,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10301489'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6Yu1OL8I0D4vjOzYdsXYGK'},
#    'href': 'https://api.spotify.com/v1/tracks/6Yu1OL8I0D4vjOzYdsXYGK',
#    'id': '6Yu1OL8I0D4vjOzYdsXYGK',
#    'is_local': False,
#    'is_playable': True,
#    'name': '12:51',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/42b1f98b5145116b35f5a08fe5690ba8ff8bbde4?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:6Yu1OL8I0D4vjOzYdsXYGK'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#       'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#       'id': '3WrFJ7ztbogyGnTHbHJFl2',
#       'name': 'The Beatles',
#       'type': 'artist',
#       'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Lf8VA23cMAl5imbABTZoo'},
#     'href': 'https://api.spotify.com/v1/albums/3Lf8VA23cMAl5imbABTZoo',
#     'id': '3Lf8VA23cMAl5imbABTZoo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c87ae2e5b263f2ff8042c5df',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c87ae2e5b263f2ff8042c5df',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c87ae2e5b263f2ff8042c5df',
#       'width': 64}],
#     'name': 'Anthology 2',
#     'release_date': '1996-03-18',
#     'release_date_precision': 'day',
#     'total_tracks': 45,
#     'type': 'album',
#     'uri': 'spotify:album:3Lf8VA23cMAl5imbABTZoo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3WrFJ7ztbogyGnTHbHJFl2'},
#      'href': 'https://api.spotify.com/v1/artists/3WrFJ7ztbogyGnTHbHJFl2',
#      'id': '3WrFJ7ztbogyGnTHbHJFl2',
#      'name': 'The Beatles',
#      'type': 'artist',
#      'uri': 'spotify:artist:3WrFJ7ztbogyGnTHbHJFl2'}],
#    'disc_number': 1,
#    'duration_ms': 175080,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAYE1100486'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HvTGx5fzFGpHSyRNvXd9T'},
#    'href': 'https://api.spotify.com/v1/tracks/2HvTGx5fzFGpHSyRNvXd9T',
#    'id': '2HvTGx5fzFGpHSyRNvXd9T',
#    'is_local': False,
#    'is_playable': True,
#    'name': '12 Bar Original - Anthology 2 Version',
#    'popularity': 29,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:2HvTGx5fzFGpHSyRNvXd9T'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#       'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#       'id': '0epOFNiUfyON9EYx7Tpr6V',
#       'name': 'The Strokes',
#       'type': 'artist',
#       'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1HQ61my1h3VWp2EBWKlp0n'},
#     'href': 'https://api.spotify.com/v1/albums/1HQ61my1h3VWp2EBWKlp0n',
#     'id': '1HQ61my1h3VWp2EBWKlp0n',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736898a982ff3c6049ba52586c',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026898a982ff3c6049ba52586c',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516898a982ff3c6049ba52586c',
#       'width': 64}],
#     'name': 'First Impressions Of Earth',
#     'release_date': '2006-01-03',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:1HQ61my1h3VWp2EBWKlp0n'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0epOFNiUfyON9EYx7Tpr6V'},
#      'href': 'https://api.spotify.com/v1/artists/0epOFNiUfyON9EYx7Tpr6V',
#      'id': '0epOFNiUfyON9EYx7Tpr6V',
#      'name': 'The Strokes',
#      'type': 'artist',
#      'uri': 'spotify:artist:0epOFNiUfyON9EYx7Tpr6V'}],
#    'disc_number': 1,
#    'duration_ms': 273133,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRC10503568'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0Sqi2XLLVk5JGfZnFnidM2'},
#    'href': 'https://api.spotify.com/v1/tracks/0Sqi2XLLVk5JGfZnFnidM2',
#    'id': '0Sqi2XLLVk5JGfZnFnidM2',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2XS4lIQ1bl9KSNsYtkqK46'},
#     'href': 'https://api.spotify.com/v1/tracks/2XS4lIQ1bl9KSNsYtkqK46',
#     'id': '2XS4lIQ1bl9KSNsYtkqK46',
#     'type': 'track',
#     'uri': 'spotify:track:2XS4lIQ1bl9KSNsYtkqK46'},
#    'name': '15 Minutes',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d41ddfe75cab34ea6cf7cdf1cc601cd5bd2c0d49?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:0Sqi2XLLVk5JGfZnFnidM2'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#       'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#       'id': '4Z8W4fKeB5YxbusRsdQVPb',
#       'name': 'Radiohead',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5vkqYmiPBYLaalcmjujWxK'},
#     'href': 'https://api.spotify.com/v1/albums/5vkqYmiPBYLaalcmjujWxK',
#     'id': '5vkqYmiPBYLaalcmjujWxK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273de3c04b5fc750b68899b20a9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02de3c04b5fc750b68899b20a9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851de3c04b5fc750b68899b20a9',
#       'width': 64}],
#     'name': 'In Rainbows',
#     'release_date': '2007-12-28',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5vkqYmiPBYLaalcmjujWxK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Z8W4fKeB5YxbusRsdQVPb'},
#      'href': 'https://api.spotify.com/v1/artists/4Z8W4fKeB5YxbusRsdQVPb',
#      'id': '4Z8W4fKeB5YxbusRsdQVPb',
#      'name': 'Radiohead',
#      'type': 'artist',
#      'uri': 'spotify:artist:4Z8W4fKeB5YxbusRsdQVPb'}],
#    'disc_number': 1,
#    'duration_ms': 237293,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBSTK0700001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4oXg7xT4ksBxHTx8PcmSXw'},
#    'href': 'https://api.spotify.com/v1/tracks/4oXg7xT4ksBxHTx8PcmSXw',
#    'id': '4oXg7xT4ksBxHTx8PcmSXw',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6dsq7Nt5mIFzvm5kIYNORy'},
#     'href': 'https://api.spotify.com/v1/tracks/6dsq7Nt5mIFzvm5kIYNORy',
#     'id': '6dsq7Nt5mIFzvm5kIYNORy',
#     'type': 'track',
#     'uri': 'spotify:track:6dsq7Nt5mIFzvm5kIYNORy'},
#    'name': '15 Step',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e21eca6129debee48f554d982e6412747a9b828a?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4oXg7xT4ksBxHTx8PcmSXw'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#       'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#       'id': '2ueoLVCXQ948OfhVvAy3Nn',
#       'name': 'Perfume Genius',
#       'type': 'artist',
#       'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3t2Ha3L2yRttt8i6Hrjhr8'},
#     'href': 'https://api.spotify.com/v1/albums/3t2Ha3L2yRttt8i6Hrjhr8',
#     'id': '3t2Ha3L2yRttt8i6Hrjhr8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273b5ec3e51eef58034098e8cb2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02b5ec3e51eef58034098e8cb2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851b5ec3e51eef58034098e8cb2',
#       'width': 64}],
#     'name': 'Put Your Back N 2 It',
#     'release_date': '2012-02-20',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3t2Ha3L2yRttt8i6Hrjhr8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2ueoLVCXQ948OfhVvAy3Nn'},
#      'href': 'https://api.spotify.com/v1/artists/2ueoLVCXQ948OfhVvAy3Nn',
#      'id': '2ueoLVCXQ948OfhVvAy3Nn',
#      'name': 'Perfume Genius',
#      'type': 'artist',
#      'uri': 'spotify:artist:2ueoLVCXQ948OfhVvAy3Nn'}],
#    'disc_number': 1,
#    'duration_ms': 150013,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GB7TY1102004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5mrJNJjEfMXWkqYZ1bN4kY'},
#    'href': 'https://api.spotify.com/v1/tracks/5mrJNJjEfMXWkqYZ1bN4kY',
#    'id': '5mrJNJjEfMXWkqYZ1bN4kY',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1wKGGfnznnXIvupuEZt9mM'},
#     'href': 'https://api.spotify.com/v1/tracks/1wKGGfnznnXIvupuEZt9mM',
#     'id': '1wKGGfnznnXIvupuEZt9mM',
#     'type': 'track',
#     'uri': 'spotify:track:1wKGGfnznnXIvupuEZt9mM'},
#    'name': '17',
#    'popularity': 9,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6fc5883f2b6c2a18f08047ee66534eafb755658b?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5mrJNJjEfMXWkqYZ1bN4kY'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ceQN2NVlLg1hgTzljDE4n'},
#       'href': 'https://api.spotify.com/v1/artists/3ceQN2NVlLg1hgTzljDE4n',
#       'id': '3ceQN2NVlLg1hgTzljDE4n',
#       'name': 'Half Moon Run',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ceQN2NVlLg1hgTzljDE4n'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1h0JzrOSEyEldBJOBMj9Ge'},
#     'href': 'https://api.spotify.com/v1/albums/1h0JzrOSEyEldBJOBMj9Ge',
#     'id': '1h0JzrOSEyEldBJOBMj9Ge',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c200077c4c009128dc53ffb9',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c200077c4c009128dc53ffb9',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c200077c4c009128dc53ffb9',
#       'width': 64}],
#     'name': 'Dark Eyes',
#     'release_date': '2012',
#     'release_date_precision': 'year',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1h0JzrOSEyEldBJOBMj9Ge'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3ceQN2NVlLg1hgTzljDE4n'},
#      'href': 'https://api.spotify.com/v1/artists/3ceQN2NVlLg1hgTzljDE4n',
#      'id': '3ceQN2NVlLg1hgTzljDE4n',
#      'name': 'Half Moon Run',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ceQN2NVlLg1hgTzljDE4n'}],
#    'disc_number': 1,
#    'duration_ms': 292413,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'CAI251212611'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6d4Wen8pkWjoUC5w7TxJu8'},
#    'href': 'https://api.spotify.com/v1/tracks/6d4Wen8pkWjoUC5w7TxJu8',
#    'id': '6d4Wen8pkWjoUC5w7TxJu8',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7Jjqx75QRHaYsxF5WnHovC'},
#     'href': 'https://api.spotify.com/v1/tracks/7Jjqx75QRHaYsxF5WnHovC',
#     'id': '7Jjqx75QRHaYsxF5WnHovC',
#     'type': 'track',
#     'uri': 'spotify:track:7Jjqx75QRHaYsxF5WnHovC'},
#    'name': '21 Gun Salute',
#    'popularity': 28,
#    'preview_url': None,
#    'track': True,
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:6d4Wen8pkWjoUC5w7TxJu8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5x9UA1g9OYt1wCyPb0YN8l'},
#       'href': 'https://api.spotify.com/v1/artists/5x9UA1g9OYt1wCyPb0YN8l',
#       'id': '5x9UA1g9OYt1wCyPb0YN8l',
#       'name': 'Ariane Moffatt',
#       'type': 'artist',
#       'uri': 'spotify:artist:5x9UA1g9OYt1wCyPb0YN8l'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2HdjJqBfxdOKa4LHZB21X8'},
#     'href': 'https://api.spotify.com/v1/albums/2HdjJqBfxdOKa4LHZB21X8',
#     'id': '2HdjJqBfxdOKa4LHZB21X8',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2734a87fc110d1f4ef431cd56f4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e024a87fc110d1f4ef431cd56f4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048514a87fc110d1f4ef431cd56f4',
#       'width': 64}],
#     'name': '22h22',
#     'release_date': '2015-02-10',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2HdjJqBfxdOKa4LHZB21X8'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5x9UA1g9OYt1wCyPb0YN8l'},
#      'href': 'https://api.spotify.com/v1/artists/5x9UA1g9OYt1wCyPb0YN8l',
#      'id': '5x9UA1g9OYt1wCyPb0YN8l',
#      'name': 'Ariane Moffatt',
#      'type': 'artist',
#      'uri': 'spotify:artist:5x9UA1g9OYt1wCyPb0YN8l'}],
#    'disc_number': 1,
#    'duration_ms': 200906,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CA60L1520001'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4aWdwtfLEVFE16wKIYLDxp'},
#    'href': 'https://api.spotify.com/v1/tracks/4aWdwtfLEVFE16wKIYLDxp',
#    'id': '4aWdwtfLEVFE16wKIYLDxp',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7BIPYQPHbPVDE9UsA0eT72'},
#     'href': 'https://api.spotify.com/v1/tracks/7BIPYQPHbPVDE9UsA0eT72',
#     'id': '7BIPYQPHbPVDE9UsA0eT72',
#     'type': 'track',
#     'uri': 'spotify:track:7BIPYQPHbPVDE9UsA0eT72'},
#    'name': '22h22',
#    'popularity': 11,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a95b265ce1fab90ce99eb1f4a37f1a0afd1276ac?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4aWdwtfLEVFE16wKIYLDxp'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l8KabfQ4VAdFHzm3ZOOYZ'},
#       'href': 'https://api.spotify.com/v1/artists/6l8KabfQ4VAdFHzm3ZOOYZ',
#       'id': '6l8KabfQ4VAdFHzm3ZOOYZ',
#       'name': 'Karkwa',
#       'type': 'artist',
#       'uri': 'spotify:artist:6l8KabfQ4VAdFHzm3ZOOYZ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4YRqmOFPSlKb9LTFjSjKhZ'},
#     'href': 'https://api.spotify.com/v1/albums/4YRqmOFPSlKb9LTFjSjKhZ',
#     'id': '4YRqmOFPSlKb9LTFjSjKhZ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f464b2e1a25113798b177b52',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f464b2e1a25113798b177b52',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f464b2e1a25113798b177b52',
#       'width': 64}],
#     'name': 'Les chemins de verre',
#     'release_date': '2011-10-17',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:4YRqmOFPSlKb9LTFjSjKhZ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6l8KabfQ4VAdFHzm3ZOOYZ'},
#      'href': 'https://api.spotify.com/v1/artists/6l8KabfQ4VAdFHzm3ZOOYZ',
#      'id': '6l8KabfQ4VAdFHzm3ZOOYZ',
#      'name': 'Karkwa',
#      'type': 'artist',
#      'uri': 'spotify:artist:6l8KabfQ4VAdFHzm3ZOOYZ'}],
#    'disc_number': 1,
#    'duration_ms': 292120,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CA60L1100011'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5DN3rkjJDrRauypfu4YZTq'},
#    'href': 'https://api.spotify.com/v1/tracks/5DN3rkjJDrRauypfu4YZTq',
#    'id': '5DN3rkjJDrRauypfu4YZTq',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4KEw5m7CZXVbpWbHVK4OrV'},
#     'href': 'https://api.spotify.com/v1/tracks/4KEw5m7CZXVbpWbHVK4OrV',
#     'id': '4KEw5m7CZXVbpWbHVK4OrV',
#     'type': 'track',
#     'uri': 'spotify:track:4KEw5m7CZXVbpWbHVK4OrV'},
#    'name': '28 jours',
#    'popularity': 2,
#    'preview_url': 'https://p.scdn.co/mp3-preview/47101f1dd819557525f9f721c71e3b0a4f84269e?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:5DN3rkjJDrRauypfu4YZTq'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lt78N8RGSNxqbrHI8JeFM'},
#       'href': 'https://api.spotify.com/v1/artists/5Lt78N8RGSNxqbrHI8JeFM',
#       'id': '5Lt78N8RGSNxqbrHI8JeFM',
#       'name': 'Vinnie Who',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Lt78N8RGSNxqbrHI8JeFM'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Ody4dHXJpSSQwirZncLuv'},
#     'href': 'https://api.spotify.com/v1/albums/0Ody4dHXJpSSQwirZncLuv',
#     'id': '0Ody4dHXJpSSQwirZncLuv',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27359c6f5319d3b7cc0b183ef93',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0259c6f5319d3b7cc0b183ef93',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485159c6f5319d3b7cc0b183ef93',
#       'width': 64}],
#     'name': 'Midnight Special',
#     'release_date': '2013-02-18',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:0Ody4dHXJpSSQwirZncLuv'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Lt78N8RGSNxqbrHI8JeFM'},
#      'href': 'https://api.spotify.com/v1/artists/5Lt78N8RGSNxqbrHI8JeFM',
#      'id': '5Lt78N8RGSNxqbrHI8JeFM',
#      'name': 'Vinnie Who',
#      'type': 'artist',
#      'uri': 'spotify:artist:5Lt78N8RGSNxqbrHI8JeFM'}],
#    'disc_number': 1,
#    'duration_ms': 309786,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DKABA1300043'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2YTRLoG5jdzCp4yg3B6OnH'},
#    'href': 'https://api.spotify.com/v1/tracks/2YTRLoG5jdzCp4yg3B6OnH',
#    'id': '2YTRLoG5jdzCp4yg3B6OnH',
#    'is_local': False,
#    'is_playable': True,
#    'name': '39',
#    'popularity': 29,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1411859fa56ddae86c6c33e32dc186cfeb6f751f?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:2YTRLoG5jdzCp4yg3B6OnH'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
# ...
#       'id': '19f2JXwlRU26376TCKmp6L',
#       'name': 'GoGo Penguin',
#       'type': 'artist',
#       'uri': 'spotify:artist:19f2JXwlRU26376TCKmp6L'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7rXrjbrYcXG8EkqXpt0weK'},
#     'href': 'https://api.spotify.com/v1/albums/7rXrjbrYcXG8EkqXpt0weK',
#     'id': '7rXrjbrYcXG8EkqXpt0weK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a5e54268be71f1d22b5c5e60',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a5e54268be71f1d22b5c5e60',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a5e54268be71f1d22b5c5e60',
#       'width': 64}],
#     'name': 'v2.0 (Deluxe Edition)',
#     'release_date': '2014-03-17',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:7rXrjbrYcXG8EkqXpt0weK'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/19f2JXwlRU26376TCKmp6L'},
#      'href': 'https://api.spotify.com/v1/artists/19f2JXwlRU26376TCKmp6L',
#      'id': '19f2JXwlRU26376TCKmp6L',
#      'name': 'GoGo Penguin',
#      'type': 'artist',
#      'uri': 'spotify:artist:19f2JXwlRU26376TCKmp6L'}],
#    'disc_number': 1,
#    'duration_ms': 224665,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBVTB1409002'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0q9pEXqEUZivY4Ll7uBxOy'},
#    'href': 'https://api.spotify.com/v1/tracks/0q9pEXqEUZivY4Ll7uBxOy',
#    'id': '0q9pEXqEUZivY4Ll7uBxOy',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2Hh5BKsYsg9Z5uLYyI9Ppl'},
#     'href': 'https://api.spotify.com/v1/tracks/2Hh5BKsYsg9Z5uLYyI9Ppl',
#     'id': '2Hh5BKsYsg9Z5uLYyI9Ppl',
#     'type': 'track',
#     'uri': 'spotify:track:2Hh5BKsYsg9Z5uLYyI9Ppl'},
#    'name': 'Garden Dog Barbecue',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2842da749470b267c35565b5860a6709804c998d?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0q9pEXqEUZivY4Ll7uBxOy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XHO7cRUPCLOr6jwp8vsx5'},
#       'href': 'https://api.spotify.com/v1/artists/3XHO7cRUPCLOr6jwp8vsx5',
#       'id': '3XHO7cRUPCLOr6jwp8vsx5',
#       'name': 'alt-J',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XHO7cRUPCLOr6jwp8vsx5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0YMkSv2yrFliXpo3dnqY60'},
#     'href': 'https://api.spotify.com/v1/albums/0YMkSv2yrFliXpo3dnqY60',
#     'id': '0YMkSv2yrFliXpo3dnqY60',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27373e8dbaf6c9b6ec2cd8ad722',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0273e8dbaf6c9b6ec2cd8ad722',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485173e8dbaf6c9b6ec2cd8ad722',
#       'width': 64}],
#     'name': 'This Is All Yours',
#     'release_date': '2014-09-22',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:0YMkSv2yrFliXpo3dnqY60'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XHO7cRUPCLOr6jwp8vsx5'},
#      'href': 'https://api.spotify.com/v1/artists/3XHO7cRUPCLOr6jwp8vsx5',
#      'id': '3XHO7cRUPCLOr6jwp8vsx5',
#      'name': 'alt-J',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XHO7cRUPCLOr6jwp8vsx5'}],
#    'disc_number': 1,
#    'duration_ms': 67684,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBZUZ1400277'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0VITTmOHGRaIVXmUZLvkxi'},
#    'href': 'https://api.spotify.com/v1/tracks/0VITTmOHGRaIVXmUZLvkxi',
#    'id': '0VITTmOHGRaIVXmUZLvkxi',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6onmdzTxsisLDtItnIS5WV'},
#     'href': 'https://api.spotify.com/v1/tracks/6onmdzTxsisLDtItnIS5WV',
#     'id': '6onmdzTxsisLDtItnIS5WV',
#     'type': 'track',
#     'uri': 'spotify:track:6onmdzTxsisLDtItnIS5WV'},
#    'name': 'Garden of England - Interlude',
#    'popularity': 38,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5ba471a8db668948b743687d032c9c83e4f141ad?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:0VITTmOHGRaIVXmUZLvkxi'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tKUoNubW02udXOh7SLtXV'},
#       'href': 'https://api.spotify.com/v1/artists/4tKUoNubW02udXOh7SLtXV',
#       'id': '4tKUoNubW02udXOh7SLtXV',
#       'name': 'Alpine',
#       'type': 'artist',
#       'uri': 'spotify:artist:4tKUoNubW02udXOh7SLtXV'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/182yEwjKPN6FHGDvplJgSW'},
#     'href': 'https://api.spotify.com/v1/albums/182yEwjKPN6FHGDvplJgSW',
#     'id': '182yEwjKPN6FHGDvplJgSW',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a636ac95bef17fb9fff4c41d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a636ac95bef17fb9fff4c41d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a636ac95bef17fb9fff4c41d',
#       'width': 64}],
#     'name': 'A Is For Alpine',
#     'release_date': '2012-08-10',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:182yEwjKPN6FHGDvplJgSW'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4tKUoNubW02udXOh7SLtXV'},
#      'href': 'https://api.spotify.com/v1/artists/4tKUoNubW02udXOh7SLtXV',
#      'id': '4tKUoNubW02udXOh7SLtXV',
#      'name': 'Alpine',
#      'type': 'artist',
#      'uri': 'spotify:artist:4tKUoNubW02udXOh7SLtXV'}],
#    'disc_number': 1,
#    'duration_ms': 203933,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'AULI01282660'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1LT9AlR86S4X54leu4sjS1'},
#    'href': 'https://api.spotify.com/v1/tracks/1LT9AlR86S4X54leu4sjS1',
#    'id': '1LT9AlR86S4X54leu4sjS1',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2xXaSJNH5LfCXz5FHhnoSg'},
#     'href': 'https://api.spotify.com/v1/tracks/2xXaSJNH5LfCXz5FHhnoSg',
#     'id': '2xXaSJNH5LfCXz5FHhnoSg',
#     'type': 'track',
#     'uri': 'spotify:track:2xXaSJNH5LfCXz5FHhnoSg'},
#    'name': 'Gasoline',
#    'popularity': 41,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b2896640d6433726d51ddd63933b74f9e263cf0e?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:1LT9AlR86S4X54leu4sjS1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZyKRTkzuio6OSVVGeVgQt'},
#       'href': 'https://api.spotify.com/v1/artists/1ZyKRTkzuio6OSVVGeVgQt',
#       'id': '1ZyKRTkzuio6OSVVGeVgQt',
#       'name': 'Philippe Brach',
#       'type': 'artist',
#       'uri': 'spotify:artist:1ZyKRTkzuio6OSVVGeVgQt'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2vaq3quZp7augCjd37QXEF'},
#     'href': 'https://api.spotify.com/v1/albums/2vaq3quZp7augCjd37QXEF',
#     'id': '2vaq3quZp7augCjd37QXEF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27318f4f443731eb29bdb464cb6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0218f4f443731eb29bdb464cb6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485118f4f443731eb29bdb464cb6',
#       'width': 64}],
#     'name': "La foire et l'ordre",
#     'release_date': '2014-04-22',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:2vaq3quZp7augCjd37QXEF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1ZyKRTkzuio6OSVVGeVgQt'},
#      'href': 'https://api.spotify.com/v1/artists/1ZyKRTkzuio6OSVVGeVgQt',
#      'id': '1ZyKRTkzuio6OSVVGeVgQt',
#      'name': 'Philippe Brach',
#      'type': 'artist',
#      'uri': 'spotify:artist:1ZyKRTkzuio6OSVVGeVgQt'}],
#    'disc_number': 1,
#    'duration_ms': 225480,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'CAS741447009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3oFhUO6a0v6MDSDmakiUxN'},
#    'href': 'https://api.spotify.com/v1/tracks/3oFhUO6a0v6MDSDmakiUxN',
#    'id': '3oFhUO6a0v6MDSDmakiUxN',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1DOiWHcSHnJViGkHTQzwZB'},
#     'href': 'https://api.spotify.com/v1/tracks/1DOiWHcSHnJViGkHTQzwZB',
#     'id': '1DOiWHcSHnJViGkHTQzwZB',
#     'type': 'track',
#     'uri': 'spotify:track:1DOiWHcSHnJViGkHTQzwZB'},
#    'name': 'Gaston',
#    'popularity': 14,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3oFhUO6a0v6MDSDmakiUxN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CWTBjOJK75cTE8Xv8u1kj'},
#       'href': 'https://api.spotify.com/v1/artists/6CWTBjOJK75cTE8Xv8u1kj',
#       'id': '6CWTBjOJK75cTE8Xv8u1kj',
#       'name': 'Feist',
#       'type': 'artist',
#       'uri': 'spotify:artist:6CWTBjOJK75cTE8Xv8u1kj'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/12bMKICVsvDdRlGzpSEKpB'},
#     'href': 'https://api.spotify.com/v1/albums/12bMKICVsvDdRlGzpSEKpB',
#     'id': '12bMKICVsvDdRlGzpSEKpB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732e3a93f7e7cf2ff54852c8a1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022e3a93f7e7cf2ff54852c8a1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512e3a93f7e7cf2ff54852c8a1',
#       'width': 64}],
#     'name': 'Let It Die',
#     'release_date': '2004-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:12bMKICVsvDdRlGzpSEKpB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6CWTBjOJK75cTE8Xv8u1kj'},
#      'href': 'https://api.spotify.com/v1/artists/6CWTBjOJK75cTE8Xv8u1kj',
#      'id': '6CWTBjOJK75cTE8Xv8u1kj',
#      'name': 'Feist',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CWTBjOJK75cTE8Xv8u1kj'}],
#    'disc_number': 1,
#    'duration_ms': 137520,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRZ020302430'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/71pLAOb9hGDPnDuGse80fV'},
#    'href': 'https://api.spotify.com/v1/tracks/71pLAOb9hGDPnDuGse80fV',
#    'id': '71pLAOb9hGDPnDuGse80fV',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7mawP3kgmL66EZzNds5KiD'},
#     'href': 'https://api.spotify.com/v1/tracks/7mawP3kgmL66EZzNds5KiD',
#     'id': '7mawP3kgmL66EZzNds5KiD',
#     'type': 'track',
#     'uri': 'spotify:track:7mawP3kgmL66EZzNds5KiD'},
#    'name': 'Gatekeeper',
#    'popularity': 47,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:71pLAOb9hGDPnDuGse80fV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-02-27T01:38:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/12160726861'},
#    'href': 'https://api.spotify.com/v1/users/12160726861',
#    'id': '12160726861',
#    'type': 'user',
#    'uri': 'spotify:user:12160726861'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ly9gfnncBXv77g2zuRG9m'},
#       'href': 'https://api.spotify.com/v1/artists/5ly9gfnncBXv77g2zuRG9m',
#       'id': '5ly9gfnncBXv77g2zuRG9m',
#       'name': 'General Elektriks',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ly9gfnncBXv77g2zuRG9m'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4ut4wtoA1bnxSWMCq8B4KH'},
#     'href': 'https://api.spotify.com/v1/albums/4ut4wtoA1bnxSWMCq8B4KH',
#     'id': '4ut4wtoA1bnxSWMCq8B4KH',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739f32f7d8a33fd5e930ab16e6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029f32f7d8a33fd5e930ab16e6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519f32f7d8a33fd5e930ab16e6',
#       'width': 64}],
#     'name': 'Good City for Dreamers (Deluxe Edition)',
#     'release_date': '2010-02-23',
#     'release_date_precision': 'day',
#     'total_tracks': 18,
#     'type': 'album',
#     'uri': 'spotify:album:4ut4wtoA1bnxSWMCq8B4KH'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ly9gfnncBXv77g2zuRG9m'},
#      'href': 'https://api.spotify.com/v1/artists/5ly9gfnncBXv77g2zuRG9m',
#      'id': '5ly9gfnncBXv77g2zuRG9m',
#      'name': 'General Elektriks',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ly9gfnncBXv77g2zuRG9m'}],
#    'disc_number': 1,
#    'duration_ms': 168706,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USR8J0800009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1icshwRezUGRD7dyzehbX3'},
#    'href': 'https://api.spotify.com/v1/tracks/1icshwRezUGRD7dyzehbX3',
#    'id': '1icshwRezUGRD7dyzehbX3',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5cQyiQZZGp1wFJyALKTZzV'},
#     'href': 'https://api.spotify.com/v1/tracks/5cQyiQZZGp1wFJyALKTZzV',
#     'id': '5cQyiQZZGp1wFJyALKTZzV',
#     'type': 'track',
#     'uri': 'spotify:track:5cQyiQZZGp1wFJyALKTZzV'},
#    'name': 'Gathering All the Lost Loves',
#    'popularity': 22,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d329e0f3329e41a380de145fb9696cf1eb21c57c?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1icshwRezUGRD7dyzehbX3'},
#   'video_thumbnail': {'url': None}},
#  ...]

# %%
list_of_songs=[]
for index in range(0,len(playlist["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(playlist["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [286], in <cell line: 2>()
#       1 list_of_songs=[]
# ----> 2 for index in range(0,len(playlist["tracks"]["items"])):
#       3     list_of_songs.append(sp.audio_features(playlist["tracks"]["items"][index]["uri"])[0])
#       4 df=pd.DataFrame(list_of_songs)
#
# KeyError: 'tracks'

# %% [markdown]
# ### kmeans.predict(scaler_x)

# %% [markdown]
# list_of_songs=[]
# for index in range(0,len(song["tracks"]["items"])):
#     list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
# df=pd.DataFrame(list_of_songs)
# df=df[["danceability","energy","loudness","speechiness","acousticness",
#     "instrumentalness","liveness","valence","tempo","duration_ms"]]
#
# df

# %% [markdown]
# scaler = StandardScaler()
# scaler.fit(df)
# audio_features_scaled = scaler.transform(df)
# audio_features_scaled

# %%
kmeans = KMeans(n_clusters=4, random_state=1234)
kmeans.fit(audio_features_scaled)


# assign a cluster to each example
labels = kmeans.predict(audio_features_scaled)
# retrieve unique clusters
clusters = np.unique(labels)
# create scatter plot for samples from each cluster
for cluster in clusters:
    # get row indexes for samples with this cluster
    row_ix = np.where(labels == cluster)
    # create scatter of these samples
    pyplot.scatter(df.to_numpy()[row_ix, 0], df.to_numpy()[row_ix,1])
    pyplot.xlabel("energy")
    pyplot.ylabel("tempo")
    # show the plot
pyplot.show()

# %%
playlist = sp.user_playlist_tracks("spotify", "59fmLtRSCPQC1TyvoD8HeA",market="DE")

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
import numpy as np

# %% [markdown]
# ## extracting a song from playlist

# %%
playlist['items'][0]['track']['id']
# Out:
# '2nL4qDv2x7ePRVEAWMlHJv'

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  836
# 100

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks=get_playlist_tracks("spotify", "59fmLtRSCPQC1TyvoD8HeA")

# %%
list_of_songs=[]
for index in range(0,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
df=pd.DataFrame(list_of_songs)    
df=df[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [285], in <cell line: 2>()
#       1 list_of_songs=[]
# ----> 2 for index in range(0,len(tracks["items"])):
#       3     list_of_songs.append(sp.audio_features(tracks["items"][index]["uri"])[0])
#       4 df=pd.DataFrame(list_of_songs)
#
# TypeError: list indices must be integers or slices, not str

# %%
scaler = StandardScaler()
scaler.fit(df)
audio_features_scaled = scaler.transform(df)
audio_features_scaled

#scaler = StandardScaler()
#model = KMeans()

with open("scaler_songrecommender.pickle", "wb") as f:
    pickle.dump(audio_features_scaled,f)

# %%
scaler = StandardScaler()
scaler.fit(df)
X_scaled = scaler.transform(df)
X_scaled_df = pd.DataFrame(X_scaled, columns = df.columns)
display(df.head())
print()
display(X_scaled_df.head())
X_scaled_df
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.613   0.764    -6.509       0.1360        0.0527
# 1         0.687   0.845    -4.370       0.0576        0.1000
# 2         0.818   0.803    -4.282       0.0797        0.0340
# 3         0.624   0.876    -3.374       0.1000        0.0735
# 4         0.614   0.379   -10.480       0.0476        0.6070
#
#    instrumentalness  liveness  valence    tempo  duration_ms
# 0          0.000000    0.1970    0.417  160.015       208187
# 1          0.000000    0.0452    0.809   87.972       190227
# 2          0.000000    0.1530    0.632  106.970       225983
# 3          0.000000    0.3270    0.781   99.943       170827
# 4          0.000464    0.0986    0.201  107.989       258987
#    danceability    energy  loudness  speechiness  acousticness  \
# 0     -0.609291  0.521181 -0.217637     2.482435     -0.425387
# 1      0.064551  1.067388  0.787674    -0.003241     -0.171652
# 2      1.257434  0.784170  0.829033     0.697441     -0.525700
# 3     -0.509125  1.276430  1.255786     1.341053     -0.313808
# 4     -0.600185 -2.074985 -2.083973    -0.320291      2.548087
#
#    instrumentalness  liveness   valence     tempo  duration_ms
# 0         -0.152299  0.633248 -1.037217  1.813492    -0.426375
# 1         -0.152299 -1.064177  1.031354 -0.913462    -0.984846
# 2         -0.152299  0.141241  0.097331 -0.194355     0.126996
# 3         -0.152299  2.086906  0.883599 -0.460339    -1.588094
# 4         -0.148194 -0.467059 -2.177042 -0.155784     1.153263
#     danceability    energy  loudness  speechiness  acousticness  \
# 0      -0.609291  0.521181 -0.217637     2.482435     -0.425387
# 1       0.064551  1.067388  0.787674    -0.003241     -0.171652
# 2       1.257434  0.784170  0.829033     0.697441     -0.525700
# 3      -0.509125  1.276430  1.255786     1.341053     -0.313808
# 4      -0.600185 -2.074985 -2.083973    -0.320291      2.548087
# 5       0.774817 -1.103951  0.805064    -0.878300      0.278956
# 6      -0.618397 -2.742570 -1.222949    -0.453453      4.291509
# 7      -2.412274 -1.002802 -3.132054    -0.662706      1.437661
# 8       0.938725 -0.517285 -0.036691     0.377220      1.131892
# 9       0.920513 -1.629928 -0.007081    -0.894153      1.834625
# 10     -1.902340  1.600107  1.005750     0.028464     -0.691942
# 11     -0.472701 -0.072228  0.063417     1.074731     -0.656752
# 12     -0.254158  0.777426 -0.031991     3.909163     -0.240852
# 13     -2.357638  1.256200  0.800364    -0.041287     -0.357259
# 14      0.574486  0.440262  0.579468    -0.516863     -0.607239
# 15      0.620016  0.683020 -0.474253    -0.770503     -0.391055
# 16      0.201141  0.730223  0.602498    -0.028605      1.056790
# 17      1.576143 -0.854450  0.509909    -0.542227     -0.638352
# 18     -1.310451  0.548154  0.046028    -0.729287     -0.684861
# 19     -0.645715 -0.126174  0.828093    -0.665877     -0.411976
# 20     -1.155649 -0.153148 -0.644389     0.519892     -0.327755
# 21      1.084421 -0.996059 -0.143379    -0.494669      0.359421
# 22      0.237565  0.763940 -0.134919    -0.564420     -0.676761
# 23      0.893195 -0.928626 -0.046090    -0.329803     -0.413585
# 24     -0.518231 -1.602955 -3.424858    -1.027314      0.429158
# 25     -1.720220 -0.551002 -1.904436    -0.665877      0.321871
# 26     -0.108462  0.210990  0.615657     0.088704     -0.619577
# 27     -0.062932  1.343863  0.754775    -0.462964      0.284320
# 28      1.102632  0.730223  0.437531    -0.231517     -0.484395
# 29      0.620016 -1.097208  0.210055    -0.757821      1.512762
# 30     -0.126674  0.966238  0.155536     0.551597     -0.642107
# 31      0.711076  0.170530  1.064499     1.721514     -0.608848
# 32      1.603461 -0.524028 -0.553211     0.783044     -0.665121
# 33      0.729287  0.109841  0.297943    -0.117379     -0.155559
# 34      0.383260  0.500951  0.745845    -0.323462     -0.645326
# 35     -1.146544  0.575128  0.575708    -0.504181     -0.681965
# 36      0.319519  1.782176 -0.207768     2.355615      0.107296
# 37      0.064551  0.393059  0.758535    -0.627830      0.246770
# 38     -1.283133  0.103097 -0.585171    -0.447112     -0.694946
# 39     -0.527337 -1.468089 -0.353465    -0.678559     -0.683735
# 40      0.856771  0.447005  0.281963    -0.190301      0.107296
# 41      0.938725 -0.719584 -0.235967    -0.535886     -0.646935
# 42     -0.172204  0.285166 -0.242077    -0.637342     -0.696556
# 43      1.011573  0.453748  1.088939    -0.025434     -0.684164
# 44      1.029785 -0.355446  0.582288    -0.802208     -0.504243
#
#     instrumentalness  liveness   valence     tempo  duration_ms
# 0          -0.152299  0.633248 -1.037217  1.813492    -0.426375
# 1          -0.152299 -1.064177  1.031354 -0.913462    -0.984846
# 2          -0.152299  0.141241  0.097331 -0.194355     0.126996
# 3          -0.152299  2.086906  0.883599 -0.460339    -1.588094
# 4          -0.148194 -0.467059 -2.177042 -0.155784     1.153263
# 5          -0.151984 -0.093581 -1.158587 -0.269377    -0.142787
# 6          -0.152299 -0.585588 -1.195526 -1.487939    -0.250998
# 7           6.633065 -0.815937 -0.868354 -0.642860    -1.606347
# 8          -0.152299 -0.470414 -1.031940 -0.456402    -0.237378
# 9          -0.152299  0.487882 -0.119025 -1.253144     1.855176
# 10         -0.152299  1.930359  0.588089  1.622190    -1.387436
# 11         -0.152064 -0.216583  0.720013 -0.988712    -0.894048
# 12         -0.152242  0.085331 -1.681007  2.197385    -0.309892
# 13         -0.152299 -0.194219  0.081500 -1.034058    -0.602188
# 14         -0.152299  1.639627 -0.361765 -0.079096     0.288380
# 15         -0.152299 -0.604598  1.427126  0.301731     0.422712
# 16         -0.152299 -1.004913  1.173832 -1.065286     0.798777
# 17         -0.152299 -0.514023  1.300479  0.831277    -0.472832
# 18         -0.152299 -0.294857 -0.361765 -1.320558     0.193851
# 19         -0.152299  0.297789  1.041908 -1.180242     2.074087
# 20         -0.102758 -0.384312 -0.773369  1.058160    -0.045365
# 21         -0.152152  0.275425 -1.158587  0.940366    -0.601752
# 22         -0.152299 -0.650444  0.081500 -0.457765     1.164022
# 23         -0.152299 -0.760027  0.994415  0.792479    -1.115042
# 24         -0.152299 -0.884147 -0.219287 -1.049312     1.060382
# 25         -0.152299  1.661991  1.527389  1.488005    -1.193806
# 26         -0.152299 -0.406676 -1.417159 -0.761260    -0.923495
# 27         -0.152299 -0.645971  0.957476 -0.571282    -0.159391
# 28         -0.151299 -0.767855  0.741121 -1.252009    -1.823609
# 29         -0.152299 -0.328402  0.250363 -0.647062     0.717090
# 30         -0.152299  0.566156  0.466718  0.035027     0.438539
# 31         -0.152299 -0.812582  0.957476  1.434293    -0.886585
# 32         -0.151578 -1.184943  1.659313  0.109141     1.485361
# 33         -0.152299 -0.548688 -0.229841 -0.609702     0.308716
# 34         -0.152299  1.952723  0.055115  0.603334    -0.634527
# 35         -0.152240  2.388820 -0.836692  2.569354     0.051217
# 36         -0.152299  1.807357  0.303132  0.550303     1.958008
# 37         -0.152158 -0.328402 -0.942232  0.676085     0.317827
# 38         -0.152089 -0.261311 -2.150657  0.227163     2.486627
# 39         -0.152279 -1.195006  0.345348 -1.328053    -0.067754
# 40         -0.152299 -1.154751  1.490450  0.261078    -0.085571
# 41         -0.152279 -0.361948  0.245086  0.299649    -0.886181
# 42         -0.140798 -1.036222  0.287302 -0.307266     0.317827
# 43         -0.152299  0.253061 -0.995001  0.488643     0.396592
# 44         -0.152283  1.829721  0.007622  0.186169    -0.289152

# %%
with open("name_of_file.pickle", "wb") as f:
    pickle.dump(X_scaled_df, f)

# %%
X_scaled_df.describe()
# Out:
#        danceability        energy      loudness   speechiness  acousticness  \
# count  4.358000e+03  4.358000e+03  4.358000e+03  4.358000e+03  4.358000e+03
# mean   6.932398e-16 -5.579138e-16  5.558758e-17  7.962373e-17  1.647756e-16
# std    1.000115e+00  1.000115e+00  1.000115e+00  1.000115e+00  1.000115e+00
# min   -3.314640e+00 -3.520600e+00 -1.097490e+01 -6.863871e-01 -8.089782e-01
# 25%   -6.825214e-01 -6.015585e-01 -4.321593e-01 -5.229820e-01 -7.281277e-01
# 50%    5.333966e-02  1.856980e-01  2.232330e-01 -3.639152e-01 -4.499378e-01
# 75%    7.113692e-01  7.682677e-01  6.729549e-01  1.929122e-02  3.558121e-01
# max    2.614702e+00  1.670988e+00  2.051767e+00  7.141147e+00  3.169733e+00
#
#        instrumentalness      liveness       valence         tempo  \
# count      4.358000e+03  4.358000e+03  4.358000e+03  4.358000e+03
# mean      -1.863407e-16 -7.438851e-18 -1.994446e-16 -3.828079e-16
# std        1.000115e+00  1.000115e+00  1.000115e+00  1.000115e+00
# min       -1.949816e-01 -1.155591e+00 -2.203630e+00 -2.745404e+00
# 25%       -1.949816e-01 -6.018540e-01 -7.795089e-01 -7.542996e-01
# 50%       -1.949816e-01 -3.921377e-01  7.517124e-03 -4.416941e-02
# 75%       -1.941407e-01  2.901586e-01  7.934439e-01  6.607252e-01
# max        7.681040e+00  5.748529e+00  1.964090e+00  3.062844e+00
#
#         duration_ms       cluster
# count  4.358000e+03  4.358000e+03
# mean  -2.609202e-16 -2.637480e-15
# std    1.000115e+00  1.000115e+00
# min   -2.243395e+00 -1.084510e+00
# 25%   -6.123319e-01 -1.084510e+00
# 50%   -1.640247e-01 -6.437305e-02
# 75%    3.722975e-01  9.557642e-01
# max    1.290423e+01  2.996039e+00

# %%
kmeans = KMeans(n_clusters=5, random_state=1234)
kmeans.fit(X_scaled_df)
# Out:
# KMeans(n_clusters=5, random_state=1234)

# %%
kmeans.labels_
# Out:
# array([1, 0, 0, 1, 3, 2, 3, 4, 2, 2, 1, 0, 1, 0, 2, 0, 0, 0, 2, 2, 1, 2,
#        2, 0, 3, 1, 2, 0, 0, 2, 0, 0, 0, 2, 1, 1, 1, 2, 2, 2, 0, 0, 0, 2,
#        2], dtype=int32)

# %%
clusters = kmeans.predict(X_scaled_df)
#clusters
pd.Series(clusters).value_counts().sort_index()
# Out:
# 0    3221
# 1     730
# 2     407
# dtype: int64

# %%
X_scaled_df['cluster']=clusters
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [245], in <cell line: 1>()
# ----> 1 X_scaled_df['cluster']=clusters
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (5) does not match length of index (45)

# %%
df["cluster"] = clusters
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [244], in <cell line: 1>()
# ----> 1 df["cluster"] = clusters
#       2 df
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
#    3836         and value.ndim == 1
#    3837         and not is_extension_array_dtype(value)
#    3838     ):
#    3839         # broadcast across multiple columns if necessary
#    3840         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~/opt/anaconda3/envs/DA_Env/lib/python3.9/site-packages/pandas/core/common.py:557, in require_length_match(data, index)
#     553 """
#     554 Check the length of data matches the length of the index.
#     555 """
#     556 if len(data) != len(index):
# --> 557     raise ValueError(
#     558         "Length of values "
#     559         f"({len(data)}) "
#     560         "does not match length of index "
#     561         f"({len(index)})"
#     562     )
#
# ValueError: Length of values (5) does not match length of index (45)

# %%
df[df['cluster'] == 2].sample()
# Out:
#       danceability  energy  loudness  speechiness  acousticness  \
# 2809         0.756   0.589    -5.093        0.232        0.0812
#
#       instrumentalness  liveness  valence    tempo  duration_ms  cluster
# 2809               0.0     0.176    0.811  146.928       205593        2

# %%
kmeans.inertia_
# Out:
# 34439.43759682328

# %%
kmeans2 = KMeans(n_clusters=5,
                init="k-means++",
                n_init=50,  # try with 1, 4, 8, 20, 30, 100...
                max_iter=10,
                tol=0,
                algorithm="elkan",
                random_state=1234)
kmeans2.fit(X_scaled_df)
print(kmeans2.inertia_)
# Out:
# 26443.27085603324

# %%
kmeans2.labels_
# Out:
# array([4, 1, 1, ..., 3, 3, 3], dtype=int32)

# %%
K = range(2, 21)
inertia = []

for k in K:
    print("Training a K-Means model with {} clusters! ".format(k))
    print()
    kmeans = KMeans(n_clusters=k,
                    random_state=1234)
    kmeans.fit(X_scaled_df)
    inertia.append(kmeans.inertia_)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(16,8))
plt.plot(K, inertia, 'bx-')
plt.xlabel('k')
plt.ylabel('inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.title('Elbow Method showing the optimal k')
# Out:
# Training a K-Means model with 2 clusters!
#
# Training a K-Means model with 3 clusters!
#
# Training a K-Means model with 4 clusters!
#
# Training a K-Means model with 5 clusters!
#
# Training a K-Means model with 6 clusters!
#
# Training a K-Means model with 7 clusters!
#
# Training a K-Means model with 8 clusters!
#
# Training a K-Means model with 9 clusters!
#
# Training a K-Means model with 10 clusters!
#
# Training a K-Means model with 11 clusters!
#
# Training a K-Means model with 12 clusters!
#
# Training a K-Means model with 13 clusters!
#
# Training a K-Means model with 14 clusters!
#
# Training a K-Means model with 15 clusters!
#
# Training a K-Means model with 16 clusters!
#
# Training a K-Means model with 17 clusters!
#
# Training a K-Means model with 18 clusters!
#
# Training a K-Means model with 19 clusters!
#
# Training a K-Means model with 20 clusters!
# Text(0.5, 1.0, 'Elbow Method showing the optimal k')

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"
track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/spotify:track:3hgl7EQwTutSm6PESsB7gZ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

play_song('2yLa0QULdQr0qAIvVwN6B5')
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/2yLa0QULdQr0qAIvVwN6B5?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#scaler = StandardScaler()
#model = KMeans()

with open("scaler.pickle", "wb") as f:
    pickle.dump(scaler,f)

with open("kmeans_5.pickle", "wb") as f:
    pickle.dump(kmeans,f)

# %%
def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!") 
load('scaler.pickle')
# Out:
# StandardScaler()

# %%
scaler2 = load("scaler.pickle")

# %%
scaler2
# Out:
# StandardScaler()

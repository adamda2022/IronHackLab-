# %%
import pickle
import config
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

def load(filename = "filename.pickle"): 
    try: 
        with open(filename, "rb") as f: 
            return pickle.load(f) 
        
    except FileNotFoundError: 
        print("File not found!")

# %%
load('scaler.pickle')
# Out:
# StandardScaler()

# %%
config.c_id
# Out:
# '27528ddd860a4c138498069634e5f2de'

# %%
config.c_se
# Out:
# 'a7e8d288a87a41a4b5a854263f691884'

# %%
c_id = "27528ddd860a4c138498069634e5f2de"
c_se ="a7e8d288a87a41a4b5a854263f691884"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))

# %%
sp.search('Apache', market='DE')
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Apache&type=track&market=DE&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0IoleYbJxOgQLuZDkzyzPG'},
#      'href': 'https://api.spotify.com/v1/albums/0IoleYbJxOgQLuZDkzyzPG',
#      'id': '0IoleYbJxOgQLuZDkzyzPG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730e579f4157261d692293055a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020e579f4157261d692293055a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510e579f4157261d692293055a',
#        'width': 64}],
#      'name': 'Platte',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:0IoleYbJxOgQLuZDkzyzPG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 157093,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEQ321900164'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6hw1Sy9wZ8UCxYGdpKrU6M'},
#     'href': 'https://api.spotify.com/v1/tracks/6hw1Sy9wZ8UCxYGdpKrU6M',
#     'id': '6hw1Sy9wZ8UCxYGdpKrU6M',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roller',
#     'popularity': 69,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5f8af31324b83de9eba1c8ca82a71567f361e5af?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6hw1Sy9wZ8UCxYGdpKrU6M'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3RJvPSUpz8E4b6SjectOPu'},
#      'href': 'https://api.spotify.com/v1/albums/3RJvPSUpz8E4b6SjectOPu',
#      'id': '3RJvPSUpz8E4b6SjectOPu',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e4e2e847019209d8dab2863',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e4e2e847019209d8dab2863',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e4e2e847019209d8dab2863',
#        'width': 64}],
#      'name': 'Roller',
#      'release_date': '2019-08-23',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3RJvPSUpz8E4b6SjectOPu'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 158853,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEQ321900164'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5dhQeuLGmlhfwlI6BWfSpo'},
#     'href': 'https://api.spotify.com/v1/tracks/5dhQeuLGmlhfwlI6BWfSpo',
#     'id': '5dhQeuLGmlhfwlI6BWfSpo',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Roller',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/df2304a08aee287f7d8e413e747cc1593d34d703?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5dhQeuLGmlhfwlI6BWfSpo'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Yttlv9ndGjCDCVLqM7ACq'},
#        'href': 'https://api.spotify.com/v1/artists/4Yttlv9ndGjCDCVLqM7ACq',
#        'id': '4Yttlv9ndGjCDCVLqM7ACq',
#        'name': 'Sido',
#        'type': 'artist',
#        'uri': 'spotify:artist:4Yttlv9ndGjCDCVLqM7ACq'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3jdqYXotnRgQwG3HTniNdH'},
#      'href': 'https://api.spotify.com/v1/albums/3jdqYXotnRgQwG3HTniNdH',
#      'id': '3jdqYXotnRgQwG3HTniNdH',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739d8ec4df88e6b21929522c74',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029d8ec4df88e6b21929522c74',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519d8ec4df88e6b21929522c74',
#        'width': 64}],
#      'name': 'Ich & keine Maske',
#      'release_date': '2019-09-26',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:3jdqYXotnRgQwG3HTniNdH'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Yttlv9ndGjCDCVLqM7ACq'},
#       'href': 'https://api.spotify.com/v1/artists/4Yttlv9ndGjCDCVLqM7ACq',
#       'id': '4Yttlv9ndGjCDCVLqM7ACq',
#       'name': 'Sido',
#       'type': 'artist',
#       'uri': 'spotify:artist:4Yttlv9ndGjCDCVLqM7ACq'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 237157,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEUM71901812'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2u8AXJyk8pICzj2wyPBL0b'},
#     'href': 'https://api.spotify.com/v1/tracks/2u8AXJyk8pICzj2wyPBL0b',
#     'id': '2u8AXJyk8pICzj2wyPBL0b',
#     'is_local': False,
#     'is_playable': True,
#     'name': '2002',
#     'popularity': 65,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2u8AXJyk8pICzj2wyPBL0b'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0IoleYbJxOgQLuZDkzyzPG'},
#      'href': 'https://api.spotify.com/v1/albums/0IoleYbJxOgQLuZDkzyzPG',
#      'id': '0IoleYbJxOgQLuZDkzyzPG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730e579f4157261d692293055a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020e579f4157261d692293055a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510e579f4157261d692293055a',
#        'width': 64}],
#      'name': 'Platte',
#      'release_date': '2019-10-25',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:0IoleYbJxOgQLuZDkzyzPG'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 163146,
#     'explicit': True,
#     'external_ids': {'isrc': 'DEQ321900168'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2PGA1AsJal6cyMNmKyE56q'},
#     'href': 'https://api.spotify.com/v1/tracks/2PGA1AsJal6cyMNmKyE56q',
#     'id': '2PGA1AsJal6cyMNmKyE56q',
#     'is_local': False,
#     'is_playable': True,
#     'name': '200 km/h',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b099db8cb029b38b6198791aa6c259d52d754e01?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2PGA1AsJal6cyMNmKyE56q'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13bDjug9N0pyv3ZUINjkDV'},
#        'href': 'https://api.spotify.com/v1/artists/13bDjug9N0pyv3ZUINjkDV',
#        'id': '13bDjug9N0pyv3ZUINjkDV',
#        'name': 'Bausa',
#        'type': 'artist',
#        'uri': 'spotify:artist:13bDjug9N0pyv3ZUINjkDV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/70DNEZBWsHHPYBFNQn3Ena'},
#      'href': 'https://api.spotify.com/v1/albums/70DNEZBWsHHPYBFNQn3Ena',
#      'id': '70DNEZBWsHHPYBFNQn3Ena',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366985352b41b9d94527a8f38',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266985352b41b9d94527a8f38',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166985352b41b9d94527a8f38',
#        'width': 64}],
#      'name': 'Madonna',
#      'release_date': '2021-02-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:70DNEZBWsHHPYBFNQn3Ena'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13bDjug9N0pyv3ZUINjkDV'},
#       'href': 'https://api.spotify.com/v1/artists/13bDjug9N0pyv3ZUINjkDV',
#       'id': '13bDjug9N0pyv3ZUINjkDV',
#       'name': 'Bausa',
#       'type': 'artist',
#       'uri': 'spotify:artist:13bDjug9N0pyv3ZUINjkDV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 195734,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA622000742'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0DAQryfUiFZdWFo76RYBc8'},
#     'href': 'https://api.spotify.com/v1/tracks/0DAQryfUiFZdWFo76RYBc8',
#     'id': '0DAQryfUiFZdWFo76RYBc8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Madonna',
#     'popularity': 64,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7079728fedbea7071df110fff92921743b3f63da?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0DAQryfUiFZdWFo76RYBc8'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3t8Ay5wZfH4NTm4bCj6LAN'},
#      'href': 'https://api.spotify.com/v1/albums/3t8Ay5wZfH4NTm4bCj6LAN',
#      'id': '3t8Ay5wZfH4NTm4bCj6LAN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273144b9521b2b9b6bb8b4f2a79',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02144b9521b2b9b6bb8b4f2a79',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851144b9521b2b9b6bb8b4f2a79',
#        'width': 64}],
#      'name': 'Kein Problem',
#      'release_date': '2019-04-05',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3t8Ay5wZfH4NTm4bCj6LAN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 139693,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQ321900074'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Zigq1lfHmFRlyoRrh9k2s'},
#     'href': 'https://api.spotify.com/v1/tracks/3Zigq1lfHmFRlyoRrh9k2s',
#     'id': '3Zigq1lfHmFRlyoRrh9k2s',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Kein Problem',
#     'popularity': 60,
#     'preview_url': 'https://p.scdn.co/mp3-preview/fe23b8f422950989df102fad0a86c2f85ee64329?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3Zigq1lfHmFRlyoRrh9k2s'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3h7DCGcI0lWcVf9DWAfB0v'},
#      'href': 'https://api.spotify.com/v1/albums/3h7DCGcI0lWcVf9DWAfB0v',
#      'id': '3h7DCGcI0lWcVf9DWAfB0v',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d544a11f415d16f566445a6c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d544a11f415d16f566445a6c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d544a11f415d16f566445a6c',
#        'width': 64}],
#      'name': 'Sport',
#      'release_date': '2021-11-26',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3h7DCGcI0lWcVf9DWAfB0v'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 175330,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQ322100375'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0rRn3j1DLkhEI6XL52Gaie'},
#     'href': 'https://api.spotify.com/v1/tracks/0rRn3j1DLkhEI6XL52Gaie',
#     'id': '0rRn3j1DLkhEI6XL52Gaie',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Sport',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/7a74e6a47cb55ab76f708e3603af22ec32a943d2?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0rRn3j1DLkhEI6XL52Gaie'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13bDjug9N0pyv3ZUINjkDV'},
#        'href': 'https://api.spotify.com/v1/artists/13bDjug9N0pyv3ZUINjkDV',
#        'id': '13bDjug9N0pyv3ZUINjkDV',
#        'name': 'Bausa',
#        'type': 'artist',
#        'uri': 'spotify:artist:13bDjug9N0pyv3ZUINjkDV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3KAtEV9jbwMKd1BPbN4XfV'},
#      'href': 'https://api.spotify.com/v1/albums/3KAtEV9jbwMKd1BPbN4XfV',
#      'id': '3KAtEV9jbwMKd1BPbN4XfV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273804a20343ab9df88ca2c0548',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02804a20343ab9df88ca2c0548',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851804a20343ab9df88ca2c0548',
#        'width': 64}],
#      'name': '100 Pro',
#      'release_date': '2021-02-26',
#      'release_date_precision': 'day',
#      'total_tracks': 16,
#      'type': 'album',
#      'uri': 'spotify:album:3KAtEV9jbwMKd1BPbN4XfV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/13bDjug9N0pyv3ZUINjkDV'},
#       'href': 'https://api.spotify.com/v1/artists/13bDjug9N0pyv3ZUINjkDV',
#       'id': '13bDjug9N0pyv3ZUINjkDV',
#       'name': 'Bausa',
#       'type': 'artist',
#       'uri': 'spotify:artist:13bDjug9N0pyv3ZUINjkDV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 195734,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEA622000742'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6a3kNt1UlUOapDKmEr3JzZ'},
#     'href': 'https://api.spotify.com/v1/tracks/6a3kNt1UlUOapDKmEr3JzZ',
#     'id': '6a3kNt1UlUOapDKmEr3JzZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Madonna',
#     'popularity': 62,
#     'preview_url': 'https://p.scdn.co/mp3-preview/10f9d638f4d46a59e5edab6f2acad20a4e5583a2?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6a3kNt1UlUOapDKmEr3JzZ'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5VImZL7dJaNGpmjkZry28Y'},
#      'href': 'https://api.spotify.com/v1/albums/5VImZL7dJaNGpmjkZry28Y',
#      'id': '5VImZL7dJaNGpmjkZry28Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27357f1414f67a30b5215b6b4e8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0257f1414f67a30b5215b6b4e8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485157f1414f67a30b5215b6b4e8',
#        'width': 64}],
#      'name': 'Bläulich',
#      'release_date': '2020-07-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5VImZL7dJaNGpmjkZry28Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 196229,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQ322000175'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/57tck8MCxkY6tcQC6VhahR'},
#     'href': 'https://api.spotify.com/v1/tracks/57tck8MCxkY6tcQC6VhahR',
#     'id': '57tck8MCxkY6tcQC6VhahR',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bläulich',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c8b06c04dbae513ca4ab13d87d14174d532bb581?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:57tck8MCxkY6tcQC6VhahR'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#        'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#        'id': '1qQLhymHXFPtP5U8KNKsm6',
#        'name': 'Apache 207',
#        'type': 'artist',
#        'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ANcyb7GrRVY6LZDZKZ72C'},
#      'href': 'https://api.spotify.com/v1/albums/5ANcyb7GrRVY6LZDZKZ72C',
#      'id': '5ANcyb7GrRVY6LZDZKZ72C',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f79bdf9c55cd91f83c4a6804',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f79bdf9c55cd91f83c4a6804',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f79bdf9c55cd91f83c4a6804',
#        'width': 64}],
#      'name': 'Fame',
#      'release_date': '2020-05-08',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:5ANcyb7GrRVY6LZDZKZ72C'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1qQLhymHXFPtP5U8KNKsm6'},
#       'href': 'https://api.spotify.com/v1/artists/1qQLhymHXFPtP5U8KNKsm6',
#       'id': '1qQLhymHXFPtP5U8KNKsm6',
#       'name': 'Apache 207',
#       'type': 'artist',
#       'uri': 'spotify:artist:1qQLhymHXFPtP5U8KNKsm6'}],
#     'disc_number': 1,
#     'duration_ms': 173760,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEQ322000135'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3goH7O78TLkV9RhCAyM4AT'},
#     'href': 'https://api.spotify.com/v1/tracks/3goH7O78TLkV9RhCAyM4AT',
#     'id': '3goH7O78TLkV9RhCAyM4AT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Fame',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/2b9a2e5127f1ac0fdbc0cdea083561da092af8ab?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3goH7O78TLkV9RhCAyM4AT'}],
#   'limit': 10,
#   'next': 'https://api.spotify.com/v1/search?query=Apache&type=track&market=DE&offset=10&limit=10',
#   'offset': 0,
#   'previous': None,
#   'total': 10106}}

# %% [markdown]
# # Installing Spotipy

# %% [markdown]
# In order to use the Spotify API (SpotiPy) we will have to create an account in Spotify and follow these steps. Once we have done it we will start initializing the API and look at the search method for which we can introduce a "query" q, in this example we will try it with Lady Gaga:

# %%
##!conda install -c conda-forge spotipy

# %% [markdown]
# ## Loading credentials from another config file

# %%
import config

# %% [markdown]
# ## Starting with Spotify API

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                           client_secret= config.c_se))

# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

results = sp.search(q="Lose yourself",limit=1,market="GB")
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['external_urls']["spotify"]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=1',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#      'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#      'id': '1rfORa9iYmocEsnnZGMVC4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#        'width': 64}],
#      'name': 'Just Lose It',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 322226,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#     'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#     'id': '1v7L65Lzy0j0vdpRjJewt1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#     'popularity': 79,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}],
#   'limit': 1,
#   'next': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=1&limit=1',
#   'offset': 0,
#   'previous': None,
#   'total': 4312}}

# %%
results["tracks"]["items"][0]["external_urls"]["spotify"]
results["tracks"]["items"][0]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'

# %%
track_id=results['tracks']['items'][0]['external_urls']["spotify"][31:]
track_id
# Out:
# '1v7L65Lzy0j0vdpRjJewt1'

# %% [markdown]
# ## Embeded track player

# %% [markdown]
# {'spotify': https://open.spotify.com/track/4O2N861eOnF9q8EtpH8IJu

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"

IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1v7L65Lzy0j0vdpRjJewt1?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# <b> navigating through the dictionary..

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %% [markdown]
# <b> more readable version

# %%
import pprint

pprint.pprint(results)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=1',
#             'items': [{'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#                                               'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#                                               'id': '7dGJo4pcD2V6oG8kP0tJRR',
#                                               'name': 'Eminem',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#                                  'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#                                  'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#                                  'id': '1rfORa9iYmocEsnnZGMVC4',
#                                  'images': [{'height': 640,
#                                              'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#                                              'width': 640},
#                                             {'height': 300,
#                                              'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#                                              'width': 300},
#                                             {'height': 64,
#                                              'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#                                              'width': 64}],
#                                  'name': 'Just Lose It',
#                                  'release_date': '2004-01-01',
#                                  'release_date_precision': 'day',
#                                  'total_tracks': 2,
#                                  'type': 'album',
#                                  'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#                                     'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#                                     'id': '7dGJo4pcD2V6oG8kP0tJRR',
#                                     'name': 'Eminem',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#                        'disc_number': 1,
#                        'duration_ms': 322226,
#                        'explicit': True,
#                        'external_ids': {'isrc': 'USIR10211559'},
#                        'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#                        'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#                        'id': '1v7L65Lzy0j0vdpRjJewt1',
#                        'is_local': False,
#                        'is_playable': True,
#                        'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#                        'popularity': 79,
#                        'preview_url': None,
#                        'track_number': 2,
#                        'type': 'track',
#                        'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}],
#             'limit': 1,
#             'next': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=1&limit=1',
#             'offset': 0,
#             'previous': None,
#             'total': 4312}}

# %%
results['tracks']['items'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#     'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#     'id': '7dGJo4pcD2V6oG8kP0tJRR',
#     'name': 'Eminem',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#   'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#   'id': '1rfORa9iYmocEsnnZGMVC4',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#     'width': 64}],
#   'name': 'Just Lose It',
#   'release_date': '2004-01-01',
#   'release_date_precision': 'day',
#   'total_tracks': 2,
#   'type': 'album',
#   'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#    'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#    'id': '7dGJo4pcD2V6oG8kP0tJRR',
#    'name': 'Eminem',
#    'type': 'artist',
#    'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#  'disc_number': 1,
#  'duration_ms': 322226,
#  'explicit': True,
#  'external_ids': {'isrc': 'USIR10211559'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#  'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#  'id': '1v7L65Lzy0j0vdpRjJewt1',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#  'popularity': 79,
#  'preview_url': None,
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}

# %%
results['tracks']['items'][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %% [markdown]
# <b> getting the track id

# %%
results['tracks']['items'][0]['id']
# Out:
# '1v7L65Lzy0j0vdpRjJewt1'

# %%
for item in results['tracks']['items']:
    print("The name of song is: '{}' and the id is: {}".format(item['name'],item["id"]))
# Out:
# The name of song is: 'Lose Yourself - From "8 Mile" Soundtrack' and the id is: 1v7L65Lzy0j0vdpRjJewt1

# %%
import pandas as pd

song = sp.search(q="Bad Guy", limit=50,market="GB") 
song
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Bad+Guy&type=track&market=GB&offset=0&limit=50',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0S0KGZnfBGSIssfF54WSJh'},
#      'href': 'https://api.spotify.com/v1/albums/0S0KGZnfBGSIssfF54WSJh',
#      'id': '0S0KGZnfBGSIssfF54WSJh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27350a3147b4edd7701a876c6ce',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0250a3147b4edd7701a876c6ce',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485150a3147b4edd7701a876c6ce',
#        'width': 64}],
#      'name': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#      'release_date': '2019-03-29',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:0S0KGZnfBGSIssfF54WSJh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 194087,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71900764'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2Fxmhks0bxGSBdJ92vM42m'},
#     'href': 'https://api.spotify.com/v1/tracks/2Fxmhks0bxGSBdJ92vM42m',
#     'id': '2Fxmhks0bxGSBdJ92vM42m',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 84,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lMlX68jJrx67hiCqdiDvW'},
#      'href': 'https://api.spotify.com/v1/albums/6lMlX68jJrx67hiCqdiDvW',
#      'id': '6lMlX68jJrx67hiCqdiDvW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a69b8b111a5fb8cb1c97e8eb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a69b8b111a5fb8cb1c97e8eb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a69b8b111a5fb8cb1c97e8eb',
#        'width': 64}],
#      'name': 'bad guy (with Justin Bieber)',
#      'release_date': '2019-07-11',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6lMlX68jJrx67hiCqdiDvW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'disc_number': 1,
#     'duration_ms': 194839,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71912813'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3yNZ5r3LKfdmjoS3gkhUCT'},
#     'href': 'https://api.spotify.com/v1/tracks/3yNZ5r3LKfdmjoS3gkhUCT',
#     'id': '3yNZ5r3LKfdmjoS3gkhUCT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy (with Justin Bieber)',
#     'popularity': 68,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3yNZ5r3LKfdmjoS3gkhUCT'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#        'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#        'id': '5ND0mGcL9SKSjWIjPd0xIb',
#        'name': 'Bowling For Soup',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2safYwJ4j0WKLcQUwEBQEi'},
#      'href': 'https://api.spotify.com/v1/albums/2safYwJ4j0WKLcQUwEBQEi',
#      'id': '2safYwJ4j0WKLcQUwEBQEi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27397ed7b212715424daac8c600',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0297ed7b212715424daac8c600',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485197ed7b212715424daac8c600',
#        'width': 64}],
#      'name': 'Drunk Enough To Dance',
#      'release_date': '2002',
#      'release_date_precision': 'year',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:2safYwJ4j0WKLcQUwEBQEi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ND0mGcL9SKSjWIjPd0xIb'},
#       'href': 'https://api.spotify.com/v1/artists/5ND0mGcL9SKSjWIjPd0xIb',
#       'id': '5ND0mGcL9SKSjWIjPd0xIb',
#       'name': 'Bowling For Soup',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ND0mGcL9SKSjWIjPd0xIb'}],
#     'disc_number': 1,
#     'duration_ms': 197800,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10200080'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0KqyBk4aVT88TEqBIC8mAP'},
#     'href': 'https://api.spotify.com/v1/tracks/0KqyBk4aVT88TEqBIC8mAP',
#     'id': '0KqyBk4aVT88TEqBIC8mAP',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Girl All the Bad Guys Want',
#     'popularity': 63,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5bcc19208807576006348dce8e193cb1ad3b6b60?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0KqyBk4aVT88TEqBIC8mAP'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6DN7GcZF1HywzrkGN6Eeqk'},
#      'href': 'https://api.spotify.com/v1/albums/6DN7GcZF1HywzrkGN6Eeqk',
#      'id': '6DN7GcZF1HywzrkGN6Eeqk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cb66bcc14c6f857c127d5969',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cb66bcc14c6f857c127d5969',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cb66bcc14c6f857c127d5969',
#        'width': 64}],
#      'name': 'The Marshall Mathers LP2 (Deluxe)',
#      'release_date': '2013-11-05',
#      'release_date_precision': 'day',
#      'total_tracks': 21,
#      'type': 'album',
#      'uri': 'spotify:album:6DN7GcZF1HywzrkGN6Eeqk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 434077,
#     'explicit': True,
#     'external_ids': {'isrc': 'USUM71314073'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3IaAYtmN8T0YIYVqnxNnVz'},
#     'href': 'https://api.spotify.com/v1/tracks/3IaAYtmN8T0YIYVqnxNnVz',
#     'id': '3IaAYtmN8T0YIYVqnxNnVz',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 60,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3IaAYtmN8T0YIYVqnxNnVz'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#        'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#        'id': '3f626JSVauIhTQgatsFcs4',
#        'name': 'Paul Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Je0MVXBcSsJ3dhXXjYJpv'},
#      'href': 'https://api.spotify.com/v1/albums/4Je0MVXBcSsJ3dhXXjYJpv',
#      'id': '4Je0MVXBcSsJ3dhXXjYJpv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bec3afb4a8379d8adf24b1a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bec3afb4a8379d8adf24b1a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bec3afb4a8379d8adf24b1a2',
#        'width': 64}],
#      'name': 'Bugsy Malone (From "Bugsy Malone" Original Motion Picture Soundtrack)',
#      'release_date': '1976-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4Je0MVXBcSsJ3dhXXjYJpv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#       'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#       'id': '3f626JSVauIhTQgatsFcs4',
#       'name': 'Paul Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#     'disc_number': 1,
#     'duration_ms': 136133,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAKW7600475'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3gZoHbFt5W3HltDGcnbDrD'},
#     'href': 'https://api.spotify.com/v1/tracks/3gZoHbFt5W3HltDGcnbDrD',
#     'id': '3gZoHbFt5W3HltDGcnbDrD',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys - From "Bugsy Malone" Original Motion Picture Soundtrack',
#     'popularity': 38,
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:3gZoHbFt5W3HltDGcnbDrD'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25Maank76ry2Tmbi2Ql1SF'},
#        'href': 'https://api.spotify.com/v1/artists/25Maank76ry2Tmbi2Ql1SF',
#        'id': '25Maank76ry2Tmbi2Ql1SF',
#        'name': 'The Interrupters',
#        'type': 'artist',
#        'uri': 'spotify:artist:25Maank76ry2Tmbi2Ql1SF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2oU2YsoVW3KG0jIlDXWIkx'},
#      'href': 'https://api.spotify.com/v1/albums/2oU2YsoVW3KG0jIlDXWIkx',
#      'id': '2oU2YsoVW3KG0jIlDXWIkx',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a33fad32ad43b17010154e0a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a33fad32ad43b17010154e0a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a33fad32ad43b17010154e0a',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2019-10-04',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2oU2YsoVW3KG0jIlDXWIkx'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/25Maank76ry2Tmbi2Ql1SF'},
#       'href': 'https://api.spotify.com/v1/artists/25Maank76ry2Tmbi2Ql1SF',
#       'id': '25Maank76ry2Tmbi2Ql1SF',
#       'name': 'The Interrupters',
#       'type': 'artist',
#       'uri': 'spotify:artist:25Maank76ry2Tmbi2Ql1SF'}],
#     'disc_number': 1,
#     'duration_ms': 157831,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHEL1901003'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iM1Ioz4N4p7MU1DKyqsov'},
#     'href': 'https://api.spotify.com/v1/tracks/0iM1Ioz4N4p7MU1DKyqsov',
#     'id': '0iM1Ioz4N4p7MU1DKyqsov',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/974dd5be76f18bb66527a454269473f8410a0ba0?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iM1Ioz4N4p7MU1DKyqsov'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CmaKO2zEGJ1NWpS1yfVGz'},
#        'href': 'https://api.spotify.com/v1/artists/2CmaKO2zEGJ1NWpS1yfVGz',
#        'id': '2CmaKO2zEGJ1NWpS1yfVGz',
#        'name': 'Falling In Reverse',
#        'type': 'artist',
#        'uri': 'spotify:artist:2CmaKO2zEGJ1NWpS1yfVGz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1KwwS07TEbKS8r1rU4UUe4'},
#      'href': 'https://api.spotify.com/v1/albums/1KwwS07TEbKS8r1rU4UUe4',
#      'id': '1KwwS07TEbKS8r1rU4UUe4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a4546ed22694f4297f6bdb9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a4546ed22694f4297f6bdb9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a4546ed22694f4297f6bdb9',
#        'width': 64}],
#      'name': 'The Drug In Me Is You',
#      'release_date': '2011-07-26',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:1KwwS07TEbKS8r1rU4UUe4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2CmaKO2zEGJ1NWpS1yfVGz'},
#       'href': 'https://api.spotify.com/v1/artists/2CmaKO2zEGJ1NWpS1yfVGz',
#       'id': '2CmaKO2zEGJ1NWpS1yfVGz',
#       'name': 'Falling In Reverse',
#       'type': 'artist',
#       'uri': 'spotify:artist:2CmaKO2zEGJ1NWpS1yfVGz'}],
#     'disc_number': 1,
#     'duration_ms': 195373,
#     'explicit': True,
#     'external_ids': {'isrc': 'USEP41118005'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78ML3F5Lz3KiNkpnFAaR3q'},
#     'href': 'https://api.spotify.com/v1/tracks/78ML3F5Lz3KiNkpnFAaR3q',
#     'id': '78ML3F5Lz3KiNkpnFAaR3q',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Good Girls Bad Guys',
#     'popularity': 65,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b6fa3c43bb7d890eb178328ac784168611ee2262?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:78ML3F5Lz3KiNkpnFAaR3q'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#        'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#        'id': '6MERXsiRbur2oJZFgYRDKz',
#        'name': 'Vitamin String Quartet',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2wWBoQpcybsDVpouFubTqZ'},
#        'href': 'https://api.spotify.com/v1/artists/2wWBoQpcybsDVpouFubTqZ',
#        'id': '2wWBoQpcybsDVpouFubTqZ',
#        'name': 'Kris Bowers',
#        'type': 'artist',
#        'uri': 'spotify:artist:2wWBoQpcybsDVpouFubTqZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5dhbc8LcvYmiI2CQhByaBR'},
#        'href': 'https://api.spotify.com/v1/artists/5dhbc8LcvYmiI2CQhByaBR',
#        'id': '5dhbc8LcvYmiI2CQhByaBR',
#        'name': 'Duomo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5dhbc8LcvYmiI2CQhByaBR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5zdSoEL5yn9hXs7bJQdnqe'},
#      'href': 'https://api.spotify.com/v1/albums/5zdSoEL5yn9hXs7bJQdnqe',
#      'id': '5zdSoEL5yn9hXs7bJQdnqe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a40f30c4800e43a7df2aa1a7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a40f30c4800e43a7df2aa1a7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a40f30c4800e43a7df2aa1a7',
#        'width': 64}],
#      'name': 'Bridgerton (Covers from the Netflix Original Series)',
#      'release_date': '2020-12-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:5zdSoEL5yn9hXs7bJQdnqe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#       'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#       'id': '6MERXsiRbur2oJZFgYRDKz',
#       'name': 'Vitamin String Quartet',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#     'disc_number': 1,
#     'duration_ms': 193226,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1990865'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1qOsHMitiWT4Zhx9ICzmjW'},
#     'href': 'https://api.spotify.com/v1/tracks/1qOsHMitiWT4Zhx9ICzmjW',
#     'id': '1qOsHMitiWT4Zhx9ICzmjW',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy',
#     'popularity': 58,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4ff5c9a72ebd59de2cf41fe83644834456e989d5?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:1qOsHMitiWT4Zhx9ICzmjW'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47XRL63LCDh1LkOq7W69WA'},
#        'href': 'https://api.spotify.com/v1/artists/47XRL63LCDh1LkOq7W69WA',
#        'id': '47XRL63LCDh1LkOq7W69WA',
#        'name': 'Clay K Slider',
#        'type': 'artist',
#        'uri': 'spotify:artist:47XRL63LCDh1LkOq7W69WA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0UBK7oymoowTKxYBz8VGeU'},
#      'href': 'https://api.spotify.com/v1/albums/0UBK7oymoowTKxYBz8VGeU',
#      'id': '0UBK7oymoowTKxYBz8VGeU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273db1cf1c1ed30dd12a79afcac',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02db1cf1c1ed30dd12a79afcac',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851db1cf1c1ed30dd12a79afcac',
#        'width': 64}],
#      'name': 'KK Slider Covers',
#      'release_date': '2019-10-26',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:0UBK7oymoowTKxYBz8VGeU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/47XRL63LCDh1LkOq7W69WA'},
#       'href': 'https://api.spotify.com/v1/artists/47XRL63LCDh1LkOq7W69WA',
#       'id': '47XRL63LCDh1LkOq7W69WA',
#       'name': 'Clay K Slider',
#       'type': 'artist',
#       'uri': 'spotify:artist:47XRL63LCDh1LkOq7W69WA'}],
#     'disc_number': 1,
#     'duration_ms': 135882,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZHN91936038'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4I1ypegnI8R0HlsAF5rZYn'},
#     'href': 'https://api.spotify.com/v1/tracks/4I1ypegnI8R0HlsAF5rZYn',
#     'id': '4I1ypegnI8R0HlsAF5rZYn',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/53a3945235c96f14155525e42aac712fb4540d8c?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4I1ypegnI8R0HlsAF5rZYn'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#        'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#        'id': '3bn93QEHOITZ4ARuiZdfRA',
#        'name': 'Morrisson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#        'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#        'id': '5VNMclLseLzRnVhvkrqdpn',
#        'name': 'Loski',
#        'type': 'artist',
#        'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1lHttlzArtuCKOvxe12DN3'},
#      'href': 'https://api.spotify.com/v1/albums/1lHttlzArtuCKOvxe12DN3',
#      'id': '1lHttlzArtuCKOvxe12DN3',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a4dfd9835c62bf673851d87',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a4dfd9835c62bf673851d87',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a4dfd9835c62bf673851d87',
#        'width': 64}],
#      'name': 'Bad Guy (feat. Loski)',
#      'release_date': '2020-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:1lHttlzArtuCKOvxe12DN3'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#       'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#       'id': '3bn93QEHOITZ4ARuiZdfRA',
#       'name': 'Morrisson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#       'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#       'id': '5VNMclLseLzRnVhvkrqdpn',
#       'name': 'Loski',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#     'disc_number': 1,
#     'duration_ms': 221560,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBARL2001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1VQKKey9XgeYOm6rd1Aje8'},
#     'href': 'https://api.spotify.com/v1/tracks/1VQKKey9XgeYOm6rd1Aje8',
#     'id': '1VQKKey9XgeYOm6rd1Aje8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (feat. Loski)',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3c19b91f49ba7119a446109268c2fda8b9b55a16?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1VQKKey9XgeYOm6rd1Aje8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oYuKMBiaAc0W8Gt7FVIjb'},
#        'href': 'https://api.spotify.com/v1/artists/5oYuKMBiaAc0W8Gt7FVIjb',
#        'id': '5oYuKMBiaAc0W8Gt7FVIjb',
#        'name': 'We Three',
#        'type': 'artist',
#        'uri': 'spotify:artist:5oYuKMBiaAc0W8Gt7FVIjb'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7trgJ2APR947xPbysXVx8n'},
#      'href': 'https://api.spotify.com/v1/albums/7trgJ2APR947xPbysXVx8n',
#      'id': '7trgJ2APR947xPbysXVx8n',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d9aa20143667f19089e9e5c7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d9aa20143667f19089e9e5c7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d9aa20143667f19089e9e5c7',
#        'width': 64}],
#      'name': 'Happy',
#      'release_date': '2022-05-27',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:7trgJ2APR947xPbysXVx8n'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5oYuKMBiaAc0W8Gt7FVIjb'},
#       'href': 'https://api.spotify.com/v1/artists/5oYuKMBiaAc0W8Gt7FVIjb',
#       'id': '5oYuKMBiaAc0W8Gt7FVIjb',
#       'name': 'We Three',
#       'type': 'artist',
#       'uri': 'spotify:artist:5oYuKMBiaAc0W8Gt7FVIjb'}],
#     'disc_number': 1,
#     'duration_ms': 152969,
#     'explicit': True,
#     'external_ids': {'isrc': 'GB5ZK2100025'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6O0yvfx7qeE16s0UyhxOVT'},
#     'href': 'https://api.spotify.com/v1/tracks/6O0yvfx7qeE16s0UyhxOVT',
#     'id': '6O0yvfx7qeE16s0UyhxOVT',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 51,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a4cc6fe4a201a24b8b9a5e77a853dfee9912eda0?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:6O0yvfx7qeE16s0UyhxOVT'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kART38d9tWb1yOcSO40YH'},
#        'href': 'https://api.spotify.com/v1/artists/6kART38d9tWb1yOcSO40YH',
#        'id': '6kART38d9tWb1yOcSO40YH',
#        'name': 'Eklipse',
#        'type': 'artist',
#        'uri': 'spotify:artist:6kART38d9tWb1yOcSO40YH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7jgCENuww6WXc03Gpm3bKe'},
#      'href': 'https://api.spotify.com/v1/albums/7jgCENuww6WXc03Gpm3bKe',
#      'id': '7jgCENuww6WXc03Gpm3bKe',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273a4bfa1801605c62c6d102346',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02a4bfa1801605c62c6d102346',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851a4bfa1801605c62c6d102346',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2020-05-29',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:7jgCENuww6WXc03Gpm3bKe'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kART38d9tWb1yOcSO40YH'},
#       'href': 'https://api.spotify.com/v1/artists/6kART38d9tWb1yOcSO40YH',
#       'id': '6kART38d9tWb1yOcSO40YH',
#       'name': 'Eklipse',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kART38d9tWb1yOcSO40YH'}],
#     'disc_number': 1,
#     'duration_ms': 191974,
#     'explicit': False,
#     'external_ids': {'isrc': 'DEPI82010434'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2FH0jT9o0mz71s7AtMkAa4'},
#     'href': 'https://api.spotify.com/v1/tracks/2FH0jT9o0mz71s7AtMkAa4',
#     'id': '2FH0jT9o0mz71s7AtMkAa4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/0c2e321a33e79373b4452b181292df3f51557383?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2FH0jT9o0mz71s7AtMkAa4'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#        'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#        'id': '1hCkSJcXREhrodeIHQdav8',
#        'name': 'Ramin Djawadi',
#        'type': 'artist',
#        'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7DQjEbNiFCXAZ9mEirk4bm'},
#      'href': 'https://api.spotify.com/v1/albums/7DQjEbNiFCXAZ9mEirk4bm',
#      'id': '7DQjEbNiFCXAZ9mEirk4bm',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273100cab204e4377d9e2db2297',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02100cab204e4377d9e2db2297',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851100cab204e4377d9e2db2297',
#        'width': 64}],
#      'name': 'Westworld: Season 4, Episodes 1-3 (Soundtrack from the HBO® Series)',
#      'release_date': '2022-07-10',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:7DQjEbNiFCXAZ9mEirk4bm'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1hCkSJcXREhrodeIHQdav8'},
#       'href': 'https://api.spotify.com/v1/artists/1hCkSJcXREhrodeIHQdav8',
#       'id': '1hCkSJcXREhrodeIHQdav8',
#       'name': 'Ramin Djawadi',
#       'type': 'artist',
#       'uri': 'spotify:artist:1hCkSJcXREhrodeIHQdav8'}],
#     'disc_number': 1,
#     'duration_ms': 139988,
#     'explicit': False,
#     'external_ids': {'isrc': 'USNLR2200774'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2REZ4nGyiA1LChTTl1kmeX'},
#     'href': 'https://api.spotify.com/v1/tracks/2REZ4nGyiA1LChTTl1kmeX',
#     'id': '2REZ4nGyiA1LChTTl1kmeX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy - from "Westworld: Season 4"',
#     'popularity': 0,
#     'preview_url': 'https://p.scdn.co/mp3-preview/4bd69ee3d01a0ac18129a6e08fdc769aa77d7131?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2REZ4nGyiA1LChTTl1kmeX'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6W3w8o7f0eU4JoqRzDOG4h'},
#        'href': 'https://api.spotify.com/v1/artists/6W3w8o7f0eU4JoqRzDOG4h',
#        'id': '6W3w8o7f0eU4JoqRzDOG4h',
#        'name': 'Paul Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:6W3w8o7f0eU4JoqRzDOG4h'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0hlLaHMjLt0vn2BHrb2PHr'},
#        'href': 'https://api.spotify.com/v1/artists/0hlLaHMjLt0vn2BHrb2PHr',
#        'id': '0hlLaHMjLt0vn2BHrb2PHr',
#        'name': 'Original London Cast Of Bugsy Malone',
#        'type': 'artist',
#        'uri': 'spotify:artist:0hlLaHMjLt0vn2BHrb2PHr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6mGiRsq1L26DFq39oSKt15'},
#      'href': 'https://api.spotify.com/v1/albums/6mGiRsq1L26DFq39oSKt15',
#      'id': '6mGiRsq1L26DFq39oSKt15',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eb5e1b010d425d769886f0a9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eb5e1b010d425d769886f0a9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eb5e1b010d425d769886f0a9',
#        'width': 64}],
#      'name': 'Bugsy Malone (Original London Cast)',
#      'release_date': '1997-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:6mGiRsq1L26DFq39oSKt15'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hlLaHMjLt0vn2BHrb2PHr'},
#       'href': 'https://api.spotify.com/v1/artists/0hlLaHMjLt0vn2BHrb2PHr',
#       'id': '0hlLaHMjLt0vn2BHrb2PHr',
#       'name': 'Original London Cast Of Bugsy Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hlLaHMjLt0vn2BHrb2PHr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6W3w8o7f0eU4JoqRzDOG4h'},
#       'href': 'https://api.spotify.com/v1/artists/6W3w8o7f0eU4JoqRzDOG4h',
#       'id': '6W3w8o7f0eU4JoqRzDOG4h',
#       'name': 'Paul Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:6W3w8o7f0eU4JoqRzDOG4h'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/37gpELl9PSTmHqvC1vD1uI'},
#       'href': 'https://api.spotify.com/v1/artists/37gpELl9PSTmHqvC1vD1uI',
#       'id': '37gpELl9PSTmHqvC1vD1uI',
#       'name': 'Boys of Bugsy Malone',
#       'type': 'artist',
#       'uri': 'spotify:artist:37gpELl9PSTmHqvC1vD1uI'}],
#     'disc_number': 1,
#     'duration_ms': 142706,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDGA9900058'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/62RAFYQzdJlRPG9Rhhsbrx'},
#     'href': 'https://api.spotify.com/v1/tracks/62RAFYQzdJlRPG9Rhhsbrx',
#     'id': '62RAFYQzdJlRPG9Rhhsbrx',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys',
#     'popularity': 14,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e36a7a9e4e6a4b00900cd2fdfdbc7352d9b9cab4?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:62RAFYQzdJlRPG9Rhhsbrx'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/10nO3EJJDMm6j6d2uK3Jah'},
#      'href': 'https://api.spotify.com/v1/albums/10nO3EJJDMm6j6d2uK3Jah',
#      'id': '10nO3EJJDMm6j6d2uK3Jah',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d12909c6ebc83cb4c6bef6f4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d12909c6ebc83cb4c6bef6f4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d12909c6ebc83cb4c6bef6f4',
#        'width': 64}],
#      'name': 'The Slim Shady LP (Expanded Edition)',
#      'release_date': '1999-02-23',
#      'release_date_precision': 'day',
#      'total_tracks': 30,
#      'type': 'album',
#      'uri': 'spotify:album:10nO3EJJDMm6j6d2uK3Jah'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6DPYiyq5kWVQS4RGwxzPC7'},
#       'href': 'https://api.spotify.com/v1/artists/6DPYiyq5kWVQS4RGwxzPC7',
#       'id': '6DPYiyq5kWVQS4RGwxzPC7',
#       'name': 'Dr. Dre',
#       'type': 'artist',
#       'uri': 'spotify:artist:6DPYiyq5kWVQS4RGwxzPC7'}],
#     'disc_number': 1,
#     'duration_ms': 279133,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR19902296'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4KVVy0GeXO03ni8Cv4SWk8'},
#     'href': 'https://api.spotify.com/v1/tracks/4KVVy0GeXO03ni8Cv4SWk8',
#     'id': '4KVVy0GeXO03ni8Cv4SWk8',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys Always Die - From "Wild Wild West" Soundtrack',
#     'popularity': 48,
#     'preview_url': None,
#     'track_number': 24,
#     'type': 'track',
#     'uri': 'spotify:track:4KVVy0GeXO03ni8Cv4SWk8'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#        'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#        'id': '3bn93QEHOITZ4ARuiZdfRA',
#        'name': 'Morrisson',
#        'type': 'artist',
#        'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6TJhrY1zpxLFbrKDAM5Nci'},
#      'href': 'https://api.spotify.com/v1/albums/6TJhrY1zpxLFbrKDAM5Nci',
#      'id': '6TJhrY1zpxLFbrKDAM5Nci',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d3824f87f0c4401bbba74087',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d3824f87f0c4401bbba74087',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d3824f87f0c4401bbba74087',
#        'width': 64}],
#      'name': 'Guilty',
#      'release_date': '2021-08-20',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:6TJhrY1zpxLFbrKDAM5Nci'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3bn93QEHOITZ4ARuiZdfRA'},
#       'href': 'https://api.spotify.com/v1/artists/3bn93QEHOITZ4ARuiZdfRA',
#       'id': '3bn93QEHOITZ4ARuiZdfRA',
#       'name': 'Morrisson',
#       'type': 'artist',
#       'uri': 'spotify:artist:3bn93QEHOITZ4ARuiZdfRA'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5VNMclLseLzRnVhvkrqdpn'},
#       'href': 'https://api.spotify.com/v1/artists/5VNMclLseLzRnVhvkrqdpn',
#       'id': '5VNMclLseLzRnVhvkrqdpn',
#       'name': 'Loski',
#       'type': 'artist',
#       'uri': 'spotify:artist:5VNMclLseLzRnVhvkrqdpn'}],
#     'disc_number': 1,
#     'duration_ms': 221560,
#     'explicit': True,
#     'external_ids': {'isrc': 'GBARL2001262'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7vLzU22xRA0pz9A8Ch1NNl'},
#     'href': 'https://api.spotify.com/v1/tracks/7vLzU22xRA0pz9A8Ch1NNl',
#     'id': '7vLzU22xRA0pz9A8Ch1NNl',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (feat. Loski)',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/deaea57b23c2ae68962f9c758a4699a4b54e7060?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7vLzU22xRA0pz9A8Ch1NNl'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BMbiYi3XahOvSkppnMCIO'},
#        'href': 'https://api.spotify.com/v1/artists/3BMbiYi3XahOvSkppnMCIO',
#        'id': '3BMbiYi3XahOvSkppnMCIO',
#        'name': 'Silver Screen Superstars',
#        'type': 'artist',
#        'uri': 'spotify:artist:3BMbiYi3XahOvSkppnMCIO'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4eSZSlYlHZYOTcoc4HwV6V'},
#      'href': 'https://api.spotify.com/v1/albums/4eSZSlYlHZYOTcoc4HwV6V',
#      'id': '4eSZSlYlHZYOTcoc4HwV6V',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732be8294dc3a6e9c360efc834',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022be8294dc3a6e9c360efc834',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512be8294dc3a6e9c360efc834',
#        'width': 64}],
#      'name': 'Music from Bugsy Malone, West Side Story & Grease',
#      'release_date': '2014-02-09',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:4eSZSlYlHZYOTcoc4HwV6V'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3BMbiYi3XahOvSkppnMCIO'},
#       'href': 'https://api.spotify.com/v1/artists/3BMbiYi3XahOvSkppnMCIO',
#       'id': '3BMbiYi3XahOvSkppnMCIO',
#       'name': 'Silver Screen Superstars',
#       'type': 'artist',
#       'uri': 'spotify:artist:3BMbiYi3XahOvSkppnMCIO'}],
#     'disc_number': 1,
#     'duration_ms': 137500,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBQRF1312821'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5PdHjcV5USm51vfOlj1Rh2'},
#     'href': 'https://api.spotify.com/v1/tracks/5PdHjcV5USm51vfOlj1Rh2',
#     'id': '5PdHjcV5USm51vfOlj1Rh2',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guys (From "Bugsy Malone")',
#     'popularity': 12,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d97fc311e0d625b723dc391240fd825a93b75e0c?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:5PdHjcV5USm51vfOlj1Rh2'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06bDwgCHeMAwhgI8il4Y5k'},
#        'href': 'https://api.spotify.com/v1/artists/06bDwgCHeMAwhgI8il4Y5k',
#        'id': '06bDwgCHeMAwhgI8il4Y5k',
#        'name': 'Set It Off',
#        'type': 'artist',
#        'uri': 'spotify:artist:06bDwgCHeMAwhgI8il4Y5k'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4mPWTksMsByAvomErPtJwK'},
#      'href': 'https://api.spotify.com/v1/albums/4mPWTksMsByAvomErPtJwK',
#      'id': '4mPWTksMsByAvomErPtJwK',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273eef2f969585ecd89a33564c6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02eef2f969585ecd89a33564c6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851eef2f969585ecd89a33564c6',
#        'width': 64}],
#      'name': 'Duality',
#      'release_date': '2014-10-14',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:4mPWTksMsByAvomErPtJwK'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06bDwgCHeMAwhgI8il4Y5k'},
#       'href': 'https://api.spotify.com/v1/artists/06bDwgCHeMAwhgI8il4Y5k',
#       'id': '06bDwgCHeMAwhgI8il4Y5k',
#       'name': 'Set It Off',
#       'type': 'artist',
#       'uri': 'spotify:artist:06bDwgCHeMAwhgI8il4Y5k'}],
#     'disc_number': 1,
#     'duration_ms': 189226,
#     'explicit': False,
#     'external_ids': {'isrc': 'ITH711400136'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/760frpppJAxqsVBuiOt1yL'},
#     'href': 'https://api.spotify.com/v1/tracks/760frpppJAxqsVBuiOt1yL',
#     'id': '760frpppJAxqsVBuiOt1yL',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 34,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6a347ed810a48b8c4d8a29698d5b81949c56d8ce?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:760frpppJAxqsVBuiOt1yL'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5njMahLKD1tLJ5bejvqseV'},
#        'href': 'https://api.spotify.com/v1/artists/5njMahLKD1tLJ5bejvqseV',
#        'id': '5njMahLKD1tLJ5bejvqseV',
#        'name': 'Workout Music ',
#        'type': 'artist',
#        'uri': 'spotify:artist:5njMahLKD1tLJ5bejvqseV'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/59kxWJDPhfg2yJUbOKabOb'},
#      'href': 'https://api.spotify.com/v1/albums/59kxWJDPhfg2yJUbOKabOb',
#      'id': '59kxWJDPhfg2yJUbOKabOb',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733fa44238207932316a87a992',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023fa44238207932316a87a992',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513fa44238207932316a87a992',
#        'width': 64}],
#      'name': '100 New Year 2020! Fitness & Workout Collection',
#      'release_date': '2019-12-26',
#      'release_date_precision': 'day',
#      'total_tracks': 100,
#      'type': 'album',
#      'uri': 'spotify:album:59kxWJDPhfg2yJUbOKabOb'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5njMahLKD1tLJ5bejvqseV'},
#       'href': 'https://api.spotify.com/v1/artists/5njMahLKD1tLJ5bejvqseV',
#       'id': '5njMahLKD1tLJ5bejvqseV',
#       'name': 'Workout Music ',
#       'type': 'artist',
#       'uri': 'spotify:artist:5njMahLKD1tLJ5bejvqseV'}],
#     'disc_number': 1,
#     'duration_ms': 281252,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUV401916719'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5v7OrTvBQNhXQwVzi3oXpb'},
#     'href': 'https://api.spotify.com/v1/tracks/5v7OrTvBQNhXQwVzi3oXpb',
#     'id': '5v7OrTvBQNhXQwVzi3oXpb',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy (Remix)',
#     'popularity': 26,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c892ea2abad01db3252a57161eed43347f9fe90f?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:5v7OrTvBQNhXQwVzi3oXpb'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gvJCmaQhMlqFpXCaz9o3l'},
#        'href': 'https://api.spotify.com/v1/artists/7gvJCmaQhMlqFpXCaz9o3l',
#        'id': '7gvJCmaQhMlqFpXCaz9o3l',
#        'name': '7AM',
#        'type': 'artist',
#        'uri': 'spotify:artist:7gvJCmaQhMlqFpXCaz9o3l'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Btky5ia7ihAQE8UEXPmbQ'},
#        'href': 'https://api.spotify.com/v1/artists/0Btky5ia7ihAQE8UEXPmbQ',
#        'id': '0Btky5ia7ihAQE8UEXPmbQ',
#        'name': 'DJ Boat',
#        'type': 'artist',
#        'uri': 'spotify:artist:0Btky5ia7ihAQE8UEXPmbQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2UMoEumdcdZdCjZChHIjBh'},
#      'href': 'https://api.spotify.com/v1/albums/2UMoEumdcdZdCjZChHIjBh',
#      'id': '2UMoEumdcdZdCjZChHIjBh',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738445b0e6be4f5bcf897e48f5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028445b0e6be4f5bcf897e48f5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518445b0e6be4f5bcf897e48f5',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2021-09-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2UMoEumdcdZdCjZChHIjBh'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7gvJCmaQhMlqFpXCaz9o3l'},
#       'href': 'https://api.spotify.com/v1/artists/7gvJCmaQhMlqFpXCaz9o3l',
#       'id': '7gvJCmaQhMlqFpXCaz9o3l',
#       'name': '7AM',
#       'type': 'artist',
#       'uri': 'spotify:artist:7gvJCmaQhMlqFpXCaz9o3l'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Btky5ia7ihAQE8UEXPmbQ'},
#       'href': 'https://api.spotify.com/v1/artists/0Btky5ia7ihAQE8UEXPmbQ',
#       'id': '0Btky5ia7ihAQE8UEXPmbQ',
#       'name': 'DJ Boat',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Btky5ia7ihAQE8UEXPmbQ'}],
#     'disc_number': 1,
#     'duration_ms': 150810,
#     'explicit': True,
#     'external_ids': {'isrc': 'QZK6H2157492'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0iXlgib8Sp7tU0tRdoUJYg'},
#     'href': 'https://api.spotify.com/v1/tracks/0iXlgib8Sp7tU0tRdoUJYg',
#     'id': '0iXlgib8Sp7tU0tRdoUJYg',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a64d51d5fbe17a714cc078ca42c6eb2276981cd1?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0iXlgib8Sp7tU0tRdoUJYg'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/28dC2QiilKWSn06mecinrD'},
#        'href': 'https://api.spotify.com/v1/artists/28dC2QiilKWSn06mecinrD',
#        'id': '28dC2QiilKWSn06mecinrD',
#        'name': 'Zeeteah Massiah',
#        'type': 'artist',
#        'uri': 'spotify:artist:28dC2QiilKWSn06mecinrD'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7h0cjF0PQQMRkr0lXIlMA7'},
#      'href': 'https://api.spotify.com/v1/albums/7h0cjF0PQQMRkr0lXIlMA7',
#      'id': '7h0cjF0PQQMRkr0lXIlMA7',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27334312ad890041f565b90ba37',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0234312ad890041f565b90ba37',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485134312ad890041f565b90ba37',
#        'width': 64}],
#      'name': 'Bad Guy',
#      'release_date': '2022-06-10',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
# ...
#     'href': 'https://api.spotify.com/v1/tracks/7ER1r3QQOPfjj3x1UCa5pq',
#     'id': '7ER1r3QQOPfjj3x1UCa5pq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 37,
#     'preview_url': 'https://p.scdn.co/mp3-preview/c04976e140b03b1f2f065a388718396b534a485e?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:7ER1r3QQOPfjj3x1UCa5pq'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jDwZUFYUH1dC4xWzOd8QU'},
#        'href': 'https://api.spotify.com/v1/artists/6jDwZUFYUH1dC4xWzOd8QU',
#        'id': '6jDwZUFYUH1dC4xWzOd8QU',
#        'name': 'Caleb Hyles',
#        'type': 'artist',
#        'uri': 'spotify:artist:6jDwZUFYUH1dC4xWzOd8QU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3NDmzlfi4cf5fFPxsjMLuz'},
#      'href': 'https://api.spotify.com/v1/albums/3NDmzlfi4cf5fFPxsjMLuz',
#      'id': '3NDmzlfi4cf5fFPxsjMLuz',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e10a38fc64912978e1a2aca3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e10a38fc64912978e1a2aca3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e10a38fc64912978e1a2aca3',
#        'width': 64}],
#      'name': "I'm the Bad Guy",
#      'release_date': '2017-02-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3NDmzlfi4cf5fFPxsjMLuz'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6jDwZUFYUH1dC4xWzOd8QU'},
#       'href': 'https://api.spotify.com/v1/artists/6jDwZUFYUH1dC4xWzOd8QU',
#       'id': '6jDwZUFYUH1dC4xWzOd8QU',
#       'name': 'Caleb Hyles',
#       'type': 'artist',
#       'uri': 'spotify:artist:6jDwZUFYUH1dC4xWzOd8QU'}],
#     'disc_number': 1,
#     'duration_ms': 144169,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZ4JJ1790058'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4FoRp17jtblWkNCfPe9QEU'},
#     'href': 'https://api.spotify.com/v1/tracks/4FoRp17jtblWkNCfPe9QEU',
#     'id': '4FoRp17jtblWkNCfPe9QEU',
#     'is_local': False,
#     'is_playable': True,
#     'name': "I'm the Bad Guy",
#     'popularity': 48,
#     'preview_url': 'https://p.scdn.co/mp3-preview/135fe2bf29e71908393d3f482206764afb71bb7b?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4FoRp17jtblWkNCfPe9QEU'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#        'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#        'id': '3f626JSVauIhTQgatsFcs4',
#        'name': 'Paul Williams',
#        'type': 'artist',
#        'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4Je0MVXBcSsJ3dhXXjYJpv'},
#      'href': 'https://api.spotify.com/v1/albums/4Je0MVXBcSsJ3dhXXjYJpv',
#      'id': '4Je0MVXBcSsJ3dhXXjYJpv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bec3afb4a8379d8adf24b1a2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bec3afb4a8379d8adf24b1a2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bec3afb4a8379d8adf24b1a2',
#        'width': 64}],
#      'name': 'Bugsy Malone (From "Bugsy Malone" Original Motion Picture Soundtrack)',
#      'release_date': '1976-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:4Je0MVXBcSsJ3dhXXjYJpv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3f626JSVauIhTQgatsFcs4'},
#       'href': 'https://api.spotify.com/v1/artists/3f626JSVauIhTQgatsFcs4',
#       'id': '3f626JSVauIhTQgatsFcs4',
#       'name': 'Paul Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:3f626JSVauIhTQgatsFcs4'}],
#     'disc_number': 1,
#     'duration_ms': 234106,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAKW7600481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/69XnaNHFaYiND63w3tUoga'},
#     'href': 'https://api.spotify.com/v1/tracks/69XnaNHFaYiND63w3tUoga',
#     'id': '69XnaNHFaYiND63w3tUoga',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'You Give A Little Love - From "Bugsy Malone" Original Motion Picture Soundtrack',
#     'popularity': 41,
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:69XnaNHFaYiND63w3tUoga'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfmnXYxa9yh0RkUBPjSwZ'},
#        'href': 'https://api.spotify.com/v1/artists/2kfmnXYxa9yh0RkUBPjSwZ',
#        'id': '2kfmnXYxa9yh0RkUBPjSwZ',
#        'name': 'Dan Berk',
#        'type': 'artist',
#        'uri': 'spotify:artist:2kfmnXYxa9yh0RkUBPjSwZ'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/5KFXAufcOTSKibMfLnmyYC'},
#        'href': 'https://api.spotify.com/v1/artists/5KFXAufcOTSKibMfLnmyYC',
#        'id': '5KFXAufcOTSKibMfLnmyYC',
#        'name': 'Lance Allen',
#        'type': 'artist',
#        'uri': 'spotify:artist:5KFXAufcOTSKibMfLnmyYC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4PuPKfAW5lJKLmpZisa9ob'},
#      'href': 'https://api.spotify.com/v1/albums/4PuPKfAW5lJKLmpZisa9ob',
#      'id': '4PuPKfAW5lJKLmpZisa9ob',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734d75a5742b9fc4532b8275e6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024d75a5742b9fc4532b8275e6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514d75a5742b9fc4532b8275e6',
#        'width': 64}],
#      'name': 'bad guy (Acoustic)',
#      'release_date': '2020-01-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:4PuPKfAW5lJKLmpZisa9ob'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2kfmnXYxa9yh0RkUBPjSwZ'},
#       'href': 'https://api.spotify.com/v1/artists/2kfmnXYxa9yh0RkUBPjSwZ',
#       'id': '2kfmnXYxa9yh0RkUBPjSwZ',
#       'name': 'Dan Berk',
#       'type': 'artist',
#       'uri': 'spotify:artist:2kfmnXYxa9yh0RkUBPjSwZ'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5KFXAufcOTSKibMfLnmyYC'},
#       'href': 'https://api.spotify.com/v1/artists/5KFXAufcOTSKibMfLnmyYC',
#       'id': '5KFXAufcOTSKibMfLnmyYC',
#       'name': 'Lance Allen',
#       'type': 'artist',
#       'uri': 'spotify:artist:5KFXAufcOTSKibMfLnmyYC'}],
#     'disc_number': 1,
#     'duration_ms': 183240,
#     'explicit': False,
#     'external_ids': {'isrc': 'UK42F2000051'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1zQ2PdP4hpA9gaWiaMMoJy'},
#     'href': 'https://api.spotify.com/v1/tracks/1zQ2PdP4hpA9gaWiaMMoJy',
#     'id': '1zQ2PdP4hpA9gaWiaMMoJy',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'bad guy - Acoustic',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/263775a5f3e947c534d6a5095e7de5acf6de852b?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:1zQ2PdP4hpA9gaWiaMMoJy'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4cyL40CdreXwIw00c8RX'},
#        'href': 'https://api.spotify.com/v1/artists/7n4cyL40CdreXwIw00c8RX',
#        'id': '7n4cyL40CdreXwIw00c8RX',
#        'name': 'Ben Schuller',
#        'type': 'artist',
#        'uri': 'spotify:artist:7n4cyL40CdreXwIw00c8RX'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/40e1LUjt5mFUmSL1mNp0Av'},
#      'href': 'https://api.spotify.com/v1/albums/40e1LUjt5mFUmSL1mNp0Av',
#      'id': '40e1LUjt5mFUmSL1mNp0Av',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e1c9c789963afd53b5f70b6',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e1c9c789963afd53b5f70b6',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e1c9c789963afd53b5f70b6',
#        'width': 64}],
#      'name': 'Cover Sessions',
#      'release_date': '2017-05-01',
#      'release_date_precision': 'day',
#      'total_tracks': 22,
#      'type': 'album',
#      'uri': 'spotify:album:40e1LUjt5mFUmSL1mNp0Av'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7n4cyL40CdreXwIw00c8RX'},
#       'href': 'https://api.spotify.com/v1/artists/7n4cyL40CdreXwIw00c8RX',
#       'id': '7n4cyL40CdreXwIw00c8RX',
#       'name': 'Ben Schuller',
#       'type': 'artist',
#       'uri': 'spotify:artist:7n4cyL40CdreXwIw00c8RX'}],
#     'disc_number': 1,
#     'duration_ms': 239480,
#     'explicit': False,
#     'external_ids': {'isrc': 'QM4DW1623700'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4G1FKyLsB8xcTdVEXgwcix'},
#     'href': 'https://api.spotify.com/v1/tracks/4G1FKyLsB8xcTdVEXgwcix',
#     'id': '4G1FKyLsB8xcTdVEXgwcix',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Once I Was 7 Years Old',
#     'popularity': 53,
#     'preview_url': 'https://p.scdn.co/mp3-preview/79b7c4a2dda8a47e8b2e2966bbde8c5298ab9397?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4G1FKyLsB8xcTdVEXgwcix'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aLQtm6eoBgUhsbHvgAJPF'},
#        'href': 'https://api.spotify.com/v1/artists/5aLQtm6eoBgUhsbHvgAJPF',
#        'id': '5aLQtm6eoBgUhsbHvgAJPF',
#        'name': 'The Cog is Dead',
#        'type': 'artist',
#        'uri': 'spotify:artist:5aLQtm6eoBgUhsbHvgAJPF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5PnVFIKBAfThVW4eb16GQn'},
#      'href': 'https://api.spotify.com/v1/albums/5PnVFIKBAfThVW4eb16GQn',
#      'id': '5PnVFIKBAfThVW4eb16GQn',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2734bed57d8c8dbc65f957ceea0',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e024bed57d8c8dbc65f957ceea0',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048514bed57d8c8dbc65f957ceea0',
#        'width': 64}],
#      'name': 'Incognito: Cog Covers, Vol. 1',
#      'release_date': '2020-12-04',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:5PnVFIKBAfThVW4eb16GQn'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5aLQtm6eoBgUhsbHvgAJPF'},
#       'href': 'https://api.spotify.com/v1/artists/5aLQtm6eoBgUhsbHvgAJPF',
#       'id': '5aLQtm6eoBgUhsbHvgAJPF',
#       'name': 'The Cog is Dead',
#       'type': 'artist',
#       'uri': 'spotify:artist:5aLQtm6eoBgUhsbHvgAJPF'}],
#     'disc_number': 1,
#     'duration_ms': 194061,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZGWW1962098'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6tRLfrfy692qlbT2cECgQS'},
#     'href': 'https://api.spotify.com/v1/tracks/6tRLfrfy692qlbT2cECgQS',
#     'id': '6tRLfrfy692qlbT2cECgQS',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 38,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e55a06fb60bcecb332c9bad80f6d24c87153eb3b?cid=27528ddd860a4c138498069634e5f2de',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6tRLfrfy692qlbT2cECgQS'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#        'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#        'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#        'name': 'Billie Eilish',
#        'type': 'artist',
#        'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3oxhQpF3Twbkl18oQYfnh5'},
#      'href': 'https://api.spotify.com/v1/albums/3oxhQpF3Twbkl18oQYfnh5',
#      'id': '3oxhQpF3Twbkl18oQYfnh5',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273954fe13f7c5f4b2f18d066b8',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02954fe13f7c5f4b2f18d066b8',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851954fe13f7c5f4b2f18d066b8',
#        'width': 64}],
#      'name': 'my future',
#      'release_date': '2020-07-30',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:3oxhQpF3Twbkl18oQYfnh5'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6qqNVTkY8uBg9cP3Jd7DAH'},
#       'href': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH',
#       'id': '6qqNVTkY8uBg9cP3Jd7DAH',
#       'name': 'Billie Eilish',
#       'type': 'artist',
#       'uri': 'spotify:artist:6qqNVTkY8uBg9cP3Jd7DAH'}],
#     'disc_number': 1,
#     'duration_ms': 208155,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM72013019'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ygvZOXrIeVL4xZmAWJT2C'},
#     'href': 'https://api.spotify.com/v1/tracks/2ygvZOXrIeVL4xZmAWJT2C',
#     'id': '2ygvZOXrIeVL4xZmAWJT2C',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'my future',
#     'popularity': 72,
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2ygvZOXrIeVL4xZmAWJT2C'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63bCkf4n15jiKjHhLV7kSZ'},
#        'href': 'https://api.spotify.com/v1/artists/63bCkf4n15jiKjHhLV7kSZ',
#        'id': '63bCkf4n15jiKjHhLV7kSZ',
#        'name': 'Niykee Heaton',
#        'type': 'artist',
#        'uri': 'spotify:artist:63bCkf4n15jiKjHhLV7kSZ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1ZWlheyrmKAaNoaa1dsq5T'},
#      'href': 'https://api.spotify.com/v1/albums/1ZWlheyrmKAaNoaa1dsq5T',
#      'id': '1ZWlheyrmKAaNoaa1dsq5T',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27356e1e5fe96b03fe6a6da1e02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0256e1e5fe96b03fe6a6da1e02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485156e1e5fe96b03fe6a6da1e02',
#        'width': 64}],
#      'name': 'Starting Over',
#      'release_date': '2018-10-05',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:1ZWlheyrmKAaNoaa1dsq5T'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63bCkf4n15jiKjHhLV7kSZ'},
#       'href': 'https://api.spotify.com/v1/artists/63bCkf4n15jiKjHhLV7kSZ',
#       'id': '63bCkf4n15jiKjHhLV7kSZ',
#       'name': 'Niykee Heaton',
#       'type': 'artist',
#       'uri': 'spotify:artist:63bCkf4n15jiKjHhLV7kSZ'}],
#     'disc_number': 1,
#     'duration_ms': 213553,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71813688'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/34LbYwWS8Vxr6dsdZ64OXd'},
#     'href': 'https://api.spotify.com/v1/tracks/34LbYwWS8Vxr6dsdZ64OXd',
#     'id': '34LbYwWS8Vxr6dsdZ64OXd',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Bad Guy',
#     'popularity': 46,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:34LbYwWS8Vxr6dsdZ64OXd'}],
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?query=Bad+Guy&type=track&market=GB&offset=50&limit=50',
#   'offset': 0,
#   'previous': None,
#   'total': 10060}}

# %%
song["tracks"]["items"][3]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#     'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#     'id': '7dGJo4pcD2V6oG8kP0tJRR',
#     'name': 'Eminem',
#     'type': 'artist',
#     'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/6DN7GcZF1HywzrkGN6Eeqk'},
#   'href': 'https://api.spotify.com/v1/albums/6DN7GcZF1HywzrkGN6Eeqk',
#   'id': '6DN7GcZF1HywzrkGN6Eeqk',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273cb66bcc14c6f857c127d5969',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02cb66bcc14c6f857c127d5969',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851cb66bcc14c6f857c127d5969',
#     'width': 64}],
#   'name': 'The Marshall Mathers LP2 (Deluxe)',
#   'release_date': '2013-11-05',
#   'release_date_precision': 'day',
#   'total_tracks': 21,
#   'type': 'album',
#   'uri': 'spotify:album:6DN7GcZF1HywzrkGN6Eeqk'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#    'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#    'id': '7dGJo4pcD2V6oG8kP0tJRR',
#    'name': 'Eminem',
#    'type': 'artist',
#    'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#  'disc_number': 1,
#  'duration_ms': 434077,
#  'explicit': True,
#  'external_ids': {'isrc': 'USUM71314073'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3IaAYtmN8T0YIYVqnxNnVz'},
#  'href': 'https://api.spotify.com/v1/tracks/3IaAYtmN8T0YIYVqnxNnVz',
#  'id': '3IaAYtmN8T0YIYVqnxNnVz',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Bad Guy',
#  'popularity': 60,
#  'preview_url': None,
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:3IaAYtmN8T0YIYVqnxNnVz'}

# %%
#pprint.pprint(song['tracks']['items'][0]['uri'])
song["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2Fxmhks0bxGSBdJ92vM42m'

# %% [markdown]
# # Understanding the json

# %% [markdown]
# Understanding the hierachy of a JSON can make you mad. Therefore you can cosider using some online pages where you can paste your JSON file and see the "tree" structure of the file.
#
# https://codebeautify.org/jsonviewer
#
# So, copy the json output from the previous query and paste it on the website's left panel. On the right panel you will be able to see the hierachy of the json file.

# %% [markdown]
# Let's get used to the json at hand.

# %%
print("The json file has the following keys: ",list(results.keys())) # We can see that we only have tracks
print("The 'tracks' key has the following child keys: ",list(results["tracks"].keys())) # Let's check the values
print("The query we made is: ",results["tracks"]["href"]) # Query we have searched 
print("The song's info is contained in: ",results["tracks"]["items"]) #items (actual tracks)
print("The limit of the query we've made is: ",results["tracks"]["limit"]) #Limit we have chosen
print("The next page if any: ",results["tracks"]["next"]) #link to the next page (next 50 tracks)
print("The starting webpage: ",results["tracks"]["offset"]) # Actual offset (starting point)
print("Starting webpage: ",results["tracks"]["previous"]) #Previous search
print("Total number of results: ",results["tracks"]["total"]) # Number of matches
# Out:
# The json file has the following keys:  ['tracks']
# The 'tracks' key has the following child keys:  ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# The query we made is:  https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=1
# The song's info is contained in:  [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'}, 'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4', 'id': '1rfORa9iYmocEsnnZGMVC4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec', 'width': 64}], 'name': 'Just Lose It', 'release_date': '2004-01-01', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'disc_number': 1, 'duration_ms': 322226, 'explicit': True, 'external_ids': {'isrc': 'USIR10211559'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'}, 'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1', 'id': '1v7L65Lzy0j0vdpRjJewt1', 'is_local': False, 'is_playable': True, 'name': 'Lose Yourself - From "8 Mile" Soundtrack', 'popularity': 79, 'preview_url': None, 'track_number': 2, 'type': 'track', 'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'}]
# The limit of the query we've made is:  1
# The next page if any:  https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=1&limit=1
# The starting webpage:  0
# Starting webpage:  None
# Total number of results:  4312

# %% [markdown]
# ## Checking albums

# %%
print(results["tracks"]["items"][0]["album"]) # we have more info about the album
print("****************\n")
print(list(results["tracks"]["items"][0]["album"].keys())) # Will check artists, id, name, release date, total tracks 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["artists"]) # List with artists and information
print("****************\n")
print("The album ID is: ",results["tracks"]["items"][0]["album"]["id"]) # Album ID 
print("****************\n")
print(results["tracks"]["items"][0]["album"]["name"]) # Album name (if its a single u'll get the name of the song)
# Out:
# {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}], 'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'}, 'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4', 'id': '1rfORa9iYmocEsnnZGMVC4', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec', 'width': 64}], 'name': 'Just Lose It', 'release_date': '2004-01-01', 'release_date_precision': 'day', 'total_tracks': 2, 'type': 'album', 'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'}
# ****************
#
# ['album_type', 'artists', 'external_urls', 'href', 'id', 'images', 'name', 'release_date', 'release_date_precision', 'total_tracks', 'type', 'uri']
# ****************
#
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'}, 'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR', 'id': '7dGJo4pcD2V6oG8kP0tJRR', 'name': 'Eminem', 'type': 'artist', 'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}]
# ****************
#
# The album ID is:  1rfORa9iYmocEsnnZGMVC4
# ****************
#
# Just Lose It

# %% [markdown]
# ## Other Info

# %%
results["tracks"]["items"][0]["artists"] # Track artists
results["tracks"]["items"][0]["id"] # Track ID
results["tracks"]["items"][0]["name"] # Track name
results["tracks"]["items"][0]["popularity"] # Popularity index
results["tracks"]["items"][0]["uri"] # Basically ID
# Out:
# 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'

# %% [markdown]
# # Getting the Audio feature of a song

# %%
sp.audio_features(results["tracks"]["items"][0]["id"] )
# Out:
# [{'danceability': 0.686,
#   'energy': 0.735,
#   'key': 2,
#   'loudness': -4.616,
#   'mode': 1,
#   'speechiness': 0.264,
#   'acousticness': 0.00921,
#   'instrumentalness': 0.00066,
#   'liveness': 0.342,
#   'valence': 0.0596,
#   'tempo': 171.355,
#   'type': 'audio_features',
#   'id': '1v7L65Lzy0j0vdpRjJewt1',
#   'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1',
#   'track_href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1v7L65Lzy0j0vdpRjJewt1',
#   'duration_ms': 322227,
#   'time_signature': 4}]

# %% [markdown]
# ## building Data frame of audio features

# %%
#my_dict = sp.audio_features(song["tracks"]["items"][0]["uri"])[0] # you can provide a list of uri's

list_of_songs=[]
for index in range(0,len(song["tracks"]["items"])):
    list_of_songs.append(sp.audio_features(song["tracks"]["items"][index]["uri"])[0])
pd.DataFrame(list_of_songs)
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.701   0.425    7   -10.965     1       0.3750      0.328000
# 1          0.670   0.453    0   -11.265     1       0.2950      0.252000
# 2          0.582   0.829    2    -5.688     1       0.0465      0.000517
# 3          0.612   0.797    1    -3.648     1       0.4480      0.064000
# 4          0.811   0.748    1   -10.298     1       0.0682      0.553000
# 5          0.563   0.814    7    -4.219     0       0.0558      0.009830
# 6          0.474   0.948    3    -2.592     1       0.1220      0.022300
# 7          0.698   0.323    5    -9.980     1       0.1780      0.914000
# 8          0.829   0.327    0   -11.346     0       0.1040      0.040200
# 9          0.695   0.779    2    -5.975     1       0.2570      0.196000
# 10         0.801   0.685    0    -5.515     0       0.0656      0.420000
# 11         0.698   0.429    0    -9.246     0       0.0416      0.148000
# 12         0.826   0.323    7   -16.848     0       0.0677      0.874000
# 13         0.694   0.468    2   -10.497     1       0.0501      0.756000
# 14         0.722   0.747    2    -3.483     1       0.0509      0.024900
# 15         0.695   0.779    2    -5.975     1       0.2570      0.196000
# 16         0.914   0.648    1    -8.882     1       0.0302      0.211000
# 17         0.643   0.786    0    -3.976     1       0.0302      0.002550
# 18         0.843   0.658   11    -7.072     0       0.0678      0.004560
# 19         0.652   0.516   10    -7.748     0       0.0426      0.062200
# 20         0.842   0.623    7    -5.678     0       0.0869      0.054500
# 21         0.575   0.843    2    -4.402     1       0.0518      0.000743
# 22         0.367   0.111    4   -14.084     1       0.0972      0.978000
# 23         0.847   0.491    4    -8.025     0       0.4360      0.386000
# 24         0.730   0.710    7    -3.976     1       0.0448      0.084200
# 25         0.635   0.712    4    -5.151     0       0.1100      0.013100
# 26         0.824   0.770    5    -7.281     0       0.1770      0.142000
# 27         0.730   0.710    7    -3.976     1       0.0448      0.084100
# 28         0.781   0.722    7    -8.376     1       0.0667      0.236000
# 29         0.830   0.405    1    -8.484     1       0.4110      0.015800
# 30         0.800   0.948    9    -2.340     0       0.1920      0.003210
# 31         0.736   0.468    3    -8.572     0       0.1950      0.110000
# 32         0.612   0.521   10    -7.137     1       0.0331      0.519000
# 33         0.945   0.858    7   -10.271     1       0.4040      0.052100
# 34         0.526   0.639    7    -6.140     1       0.1040      0.010600
# 35         0.757   0.598   11    -7.777     1       0.0580      0.090400
# 36         0.905   0.389    8   -14.505     1       0.3320      0.740000
# 37         0.785   0.671   11    -7.108     0       0.0505      0.448000
# 38         0.585   0.717    2    -5.055     1       0.0426      0.009700
# 39         0.807   0.893   11    -3.745     0       0.0347      0.045100
# 40         0.700   0.693    5    -5.092     1       0.2010      0.129000
# 41         0.516   0.587    2    -5.756     1       0.0258      0.231000
# 42         0.692   0.623    7   -11.172     1       0.2880      0.030300
# 43         0.656   0.465    0   -12.132     1       0.0311      0.368000
# 44         0.535   0.579    6   -11.918     1       0.0583      0.570000
# 45         0.758   0.294    9    -9.113     0       0.0459      0.829000
# 46         0.712   0.353    7    -9.975     1       0.0357      0.651000
# 47         0.604   0.564    7    -6.875     1       0.2400      0.031600
# 48         0.444   0.309    8   -10.956     1       0.0620      0.795000
# 49         0.764   0.488    5    -6.017     1       0.0396      0.166000
#
#     instrumentalness  liveness  valence    tempo            type  \
# 0           0.130000    0.1000   0.5620  135.128  audio_features
# 1           0.330000    0.1170   0.6800  135.055  audio_features
# 2           0.000000    0.2660   0.8670  130.969  audio_features
# 3           0.000000    0.2570   0.3580   81.086  audio_features
# 4           0.000000    0.1100   0.8830  108.816  audio_features
# 5           0.043700    0.0732   0.7960  140.615  audio_features
# 6           0.000000    0.4300   0.6110  146.460  audio_features
# 7           0.037000    0.0991   0.6700  135.069  audio_features
# 8           0.545000    0.1050   0.7230  135.984  audio_features
# 9           0.000000    0.1100   0.7040  142.175  audio_features
# 10          0.000000    0.1000   0.7770  108.024  audio_features
# 11          0.691000    0.1010   0.5400  134.946  audio_features
# 12          0.818000    0.0728   0.8530  134.996  audio_features
# 13          0.000002    0.4150   0.7360  110.362  audio_features
# 14          0.000005    0.1970   0.3430   95.866  audio_features
# 15          0.000000    0.1100   0.7040  142.175  audio_features
# 16          0.000002    0.1040   0.8970  107.967  audio_features
# 17          0.000000    0.0462   0.5200  107.005  audio_features
# 18          0.730000    0.0673   0.5620  131.010  audio_features
# 19          0.000006    0.1200   0.3420   91.975  audio_features
# 20          0.000079    0.0434   0.8450  136.000  audio_features
# 21          0.000000    0.3150   0.8430  130.982  audio_features
# 22          0.000040    0.0897   0.1980   82.642  audio_features
# 23          0.000067    0.1190   0.6230  139.947  audio_features
# 24          0.000000    0.3460   0.5440  114.946  audio_features
# 25          0.000000    0.1870   0.4580   78.598  audio_features
# 26          0.000000    0.1120   0.3270  119.887  audio_features
# 27          0.000000    0.3410   0.5440  114.949  audio_features
# 28          0.000398    0.0770   0.5330   87.858  audio_features
# 29          0.000009    0.2410   0.1880  147.070  audio_features
# 30          0.000000    0.0800   0.9240  104.971  audio_features
# 31          0.000000    0.1070   0.4170   80.505  audio_features
# 32          0.000000    0.1660   0.3680   92.988  audio_features
# 33          0.143000    0.0494   0.6320  134.992  audio_features
# 34          0.000022    0.1200   0.7170  135.012  audio_features
# 35          0.551000    0.1500   0.1800  124.951  audio_features
# 36          0.162000    0.1060   0.1960  120.046  audio_features
# 37          0.000018    0.2250   0.5880  124.899  audio_features
# 38          0.031300    0.0952   0.7010  174.019  audio_features
# 39          0.000028    0.3660   0.5370  126.011  audio_features
# 40          0.000000    0.2320   0.4750  146.109  audio_features
# 41          0.000000    0.1080   0.2370   78.024  audio_features
# 42          0.000001    0.0958   0.3840  134.987  audio_features
# 43          0.000000    0.1550   0.7780   96.930  audio_features
# 44          0.000062    0.1200   0.5550  109.536  audio_features
# 45          0.000009    0.0981   0.3480  120.041  audio_features
# 46          0.000000    0.0918   0.2290  118.059  audio_features
# 47          0.000005    0.5850   0.8720  135.973  audio_features
# 48          0.132000    0.3520   0.0875  104.745  audio_features
# 49          0.000000    0.0979   0.2370  124.923  audio_features
#
#                         id                                   uri  \
# 0   2Fxmhks0bxGSBdJ92vM42m  spotify:track:2Fxmhks0bxGSBdJ92vM42m
# 1   3yNZ5r3LKfdmjoS3gkhUCT  spotify:track:3yNZ5r3LKfdmjoS3gkhUCT
# 2   0KqyBk4aVT88TEqBIC8mAP  spotify:track:0KqyBk4aVT88TEqBIC8mAP
# 3   3IaAYtmN8T0YIYVqnxNnVz  spotify:track:3IaAYtmN8T0YIYVqnxNnVz
# 4   3gZoHbFt5W3HltDGcnbDrD  spotify:track:3gZoHbFt5W3HltDGcnbDrD
# 5   0iM1Ioz4N4p7MU1DKyqsov  spotify:track:0iM1Ioz4N4p7MU1DKyqsov
# 6   78ML3F5Lz3KiNkpnFAaR3q  spotify:track:78ML3F5Lz3KiNkpnFAaR3q
# 7   1qOsHMitiWT4Zhx9ICzmjW  spotify:track:1qOsHMitiWT4Zhx9ICzmjW
# 8   4I1ypegnI8R0HlsAF5rZYn  spotify:track:4I1ypegnI8R0HlsAF5rZYn
# 9   1VQKKey9XgeYOm6rd1Aje8  spotify:track:1VQKKey9XgeYOm6rd1Aje8
# 10  6O0yvfx7qeE16s0UyhxOVT  spotify:track:6O0yvfx7qeE16s0UyhxOVT
# 11  2FH0jT9o0mz71s7AtMkAa4  spotify:track:2FH0jT9o0mz71s7AtMkAa4
# 12  2REZ4nGyiA1LChTTl1kmeX  spotify:track:2REZ4nGyiA1LChTTl1kmeX
# 13  62RAFYQzdJlRPG9Rhhsbrx  spotify:track:62RAFYQzdJlRPG9Rhhsbrx
# 14  4KVVy0GeXO03ni8Cv4SWk8  spotify:track:4KVVy0GeXO03ni8Cv4SWk8
# 15  7vLzU22xRA0pz9A8Ch1NNl  spotify:track:7vLzU22xRA0pz9A8Ch1NNl
# 16  5PdHjcV5USm51vfOlj1Rh2  spotify:track:5PdHjcV5USm51vfOlj1Rh2
# 17  760frpppJAxqsVBuiOt1yL  spotify:track:760frpppJAxqsVBuiOt1yL
# 18  5v7OrTvBQNhXQwVzi3oXpb  spotify:track:5v7OrTvBQNhXQwVzi3oXpb
# 19  0iXlgib8Sp7tU0tRdoUJYg  spotify:track:0iXlgib8Sp7tU0tRdoUJYg
# 20  0OnmY8BGZsxzEhyZJ43ooZ  spotify:track:0OnmY8BGZsxzEhyZJ43ooZ
# 21  5R4UtkoueIomI2z3Ei8B38  spotify:track:5R4UtkoueIomI2z3Ei8B38
# 22  43zdsphuZLzwA9k4DJhU0I  spotify:track:43zdsphuZLzwA9k4DJhU0I
# 23  7emJRAhUHhLtBtvzjDpjMC  spotify:track:7emJRAhUHhLtBtvzjDpjMC
# 24  5XYNCCkYoFLegWZcQU9ecn  spotify:track:5XYNCCkYoFLegWZcQU9ecn
# 25  1PokNDiTBQZgXci6rn2BVE  spotify:track:1PokNDiTBQZgXci6rn2BVE
# 26  408if5LwFlG8lsyYkSGjJn  spotify:track:408if5LwFlG8lsyYkSGjJn
# 27  4g077yizjVdMB5HFl3rJRo  spotify:track:4g077yizjVdMB5HFl3rJRo
# 28  0qeKzbUsW0V4ZWRJrHNiD3  spotify:track:0qeKzbUsW0V4ZWRJrHNiD3
# 29  5TvdhNXoHbeGeWtjCYhFuy  spotify:track:5TvdhNXoHbeGeWtjCYhFuy
# 30  6ST6x5sSLYArqrh30p3KBs  spotify:track:6ST6x5sSLYArqrh30p3KBs
# 31  5w4enr0FN8ZTwxmfnACz2f  spotify:track:5w4enr0FN8ZTwxmfnACz2f
# 32  6BZuf8iLTI18rN8L8WarzL  spotify:track:6BZuf8iLTI18rN8L8WarzL
# 33  2uqN75iYEOcDQEtpCg65Ms  spotify:track:2uqN75iYEOcDQEtpCg65Ms
# 34  3UCQwTclMnDYtS0uVjNTGO  spotify:track:3UCQwTclMnDYtS0uVjNTGO
# 35  4t2OeILB07eMGTXSUbMPEu  spotify:track:4t2OeILB07eMGTXSUbMPEu
# 36  4SSnFejRGlZikf02HLewEF  spotify:track:4SSnFejRGlZikf02HLewEF
# 37  1O8BgvuH9SMVddb3MQINwp  spotify:track:1O8BgvuH9SMVddb3MQINwp
# 38  5bnPew0sFrsFDUrkvVezRS  spotify:track:5bnPew0sFrsFDUrkvVezRS
# 39  3rmo8F54jFF8OgYsqTxm5d  spotify:track:3rmo8F54jFF8OgYsqTxm5d
# 40  4727RsuKMuY09HnC1ZD6yt  spotify:track:4727RsuKMuY09HnC1ZD6yt
# 41  0otmxJEwq9JI1CidrcYEq4  spotify:track:0otmxJEwq9JI1CidrcYEq4
# 42  7ER1r3QQOPfjj3x1UCa5pq  spotify:track:7ER1r3QQOPfjj3x1UCa5pq
# 43  4FoRp17jtblWkNCfPe9QEU  spotify:track:4FoRp17jtblWkNCfPe9QEU
# 44  69XnaNHFaYiND63w3tUoga  spotify:track:69XnaNHFaYiND63w3tUoga
# 45  1zQ2PdP4hpA9gaWiaMMoJy  spotify:track:1zQ2PdP4hpA9gaWiaMMoJy
# 46  4G1FKyLsB8xcTdVEXgwcix  spotify:track:4G1FKyLsB8xcTdVEXgwcix
# 47  6tRLfrfy692qlbT2cECgQS  spotify:track:6tRLfrfy692qlbT2cECgQS
# 48  2ygvZOXrIeVL4xZmAWJT2C  spotify:track:2ygvZOXrIeVL4xZmAWJT2C
# 49  34LbYwWS8Vxr6dsdZ64OXd  spotify:track:34LbYwWS8Vxr6dsdZ64OXd
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2Fxmhks0bxGS...
# 1   https://api.spotify.com/v1/tracks/3yNZ5r3LKfdm...
# 2   https://api.spotify.com/v1/tracks/0KqyBk4aVT88...
# 3   https://api.spotify.com/v1/tracks/3IaAYtmN8T0Y...
# 4   https://api.spotify.com/v1/tracks/3gZoHbFt5W3H...
# 5   https://api.spotify.com/v1/tracks/0iM1Ioz4N4p7...
# 6   https://api.spotify.com/v1/tracks/78ML3F5Lz3Ki...
# 7   https://api.spotify.com/v1/tracks/1qOsHMitiWT4...
# 8   https://api.spotify.com/v1/tracks/4I1ypegnI8R0...
# 9   https://api.spotify.com/v1/tracks/1VQKKey9XgeY...
# 10  https://api.spotify.com/v1/tracks/6O0yvfx7qeE1...
# 11  https://api.spotify.com/v1/tracks/2FH0jT9o0mz7...
# 12  https://api.spotify.com/v1/tracks/2REZ4nGyiA1L...
# 13  https://api.spotify.com/v1/tracks/62RAFYQzdJlR...
# 14  https://api.spotify.com/v1/tracks/4KVVy0GeXO03...
# 15  https://api.spotify.com/v1/tracks/7vLzU22xRA0p...
# 16  https://api.spotify.com/v1/tracks/5PdHjcV5USm5...
# 17  https://api.spotify.com/v1/tracks/760frpppJAxq...
# 18  https://api.spotify.com/v1/tracks/5v7OrTvBQNhX...
# 19  https://api.spotify.com/v1/tracks/0iXlgib8Sp7t...
# 20  https://api.spotify.com/v1/tracks/0OnmY8BGZsxz...
# 21  https://api.spotify.com/v1/tracks/5R4UtkoueIom...
# 22  https://api.spotify.com/v1/tracks/43zdsphuZLzw...
# 23  https://api.spotify.com/v1/tracks/7emJRAhUHhLt...
# 24  https://api.spotify.com/v1/tracks/5XYNCCkYoFLe...
# 25  https://api.spotify.com/v1/tracks/1PokNDiTBQZg...
# 26  https://api.spotify.com/v1/tracks/408if5LwFlG8...
# 27  https://api.spotify.com/v1/tracks/4g077yizjVdM...
# 28  https://api.spotify.com/v1/tracks/0qeKzbUsW0V4...
# 29  https://api.spotify.com/v1/tracks/5TvdhNXoHbeG...
# 30  https://api.spotify.com/v1/tracks/6ST6x5sSLYAr...
# 31  https://api.spotify.com/v1/tracks/5w4enr0FN8ZT...
# 32  https://api.spotify.com/v1/tracks/6BZuf8iLTI18...
# 33  https://api.spotify.com/v1/tracks/2uqN75iYEOcD...
# 34  https://api.spotify.com/v1/tracks/3UCQwTclMnDY...
# 35  https://api.spotify.com/v1/tracks/4t2OeILB07eM...
# 36  https://api.spotify.com/v1/tracks/4SSnFejRGlZi...
# 37  https://api.spotify.com/v1/tracks/1O8BgvuH9SMV...
# 38  https://api.spotify.com/v1/tracks/5bnPew0sFrsF...
# 39  https://api.spotify.com/v1/tracks/3rmo8F54jFF8...
# 40  https://api.spotify.com/v1/tracks/4727RsuKMuY0...
# 41  https://api.spotify.com/v1/tracks/0otmxJEwq9JI...
# 42  https://api.spotify.com/v1/tracks/7ER1r3QQOPfj...
# 43  https://api.spotify.com/v1/tracks/4FoRp17jtblW...
# 44  https://api.spotify.com/v1/tracks/69XnaNHFaYiN...
# 45  https://api.spotify.com/v1/tracks/1zQ2PdP4hpA9...
# 46  https://api.spotify.com/v1/tracks/4G1FKyLsB8xc...
# 47  https://api.spotify.com/v1/tracks/6tRLfrfy692q...
# 48  https://api.spotify.com/v1/tracks/2ygvZOXrIeVL...
# 49  https://api.spotify.com/v1/tracks/34LbYwWS8Vxr...
#
#                                          analysis_url  duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2Fxm...       194088
# 1   https://api.spotify.com/v1/audio-analysis/3yNZ...       194840
# 2   https://api.spotify.com/v1/audio-analysis/0Kqy...       197800
# 3   https://api.spotify.com/v1/audio-analysis/3IaA...       434077
# 4   https://api.spotify.com/v1/audio-analysis/3gZo...       136133
# 5   https://api.spotify.com/v1/audio-analysis/0iM1...       157832
# 6   https://api.spotify.com/v1/audio-analysis/78ML...       195373
# 7   https://api.spotify.com/v1/audio-analysis/1qOs...       193227
# 8   https://api.spotify.com/v1/audio-analysis/4I1y...       135882
# 9   https://api.spotify.com/v1/audio-analysis/1VQK...       221560
# 10  https://api.spotify.com/v1/audio-analysis/6O0y...       152970
# 11  https://api.spotify.com/v1/audio-analysis/2FH0...       191975
# 12  https://api.spotify.com/v1/audio-analysis/2REZ...       139989
# 13  https://api.spotify.com/v1/audio-analysis/62RA...       142706
# 14  https://api.spotify.com/v1/audio-analysis/4KVV...       279133
# 15  https://api.spotify.com/v1/audio-analysis/7vLz...       221560
# 16  https://api.spotify.com/v1/audio-analysis/5PdH...       137500
# 17  https://api.spotify.com/v1/audio-analysis/760f...       189227
# 18  https://api.spotify.com/v1/audio-analysis/5v7O...       281253
# 19  https://api.spotify.com/v1/audio-analysis/0iXl...       150811
# 20  https://api.spotify.com/v1/audio-analysis/0Onm...       240000
# 21  https://api.spotify.com/v1/audio-analysis/5R4U...       197613
# 22  https://api.spotify.com/v1/audio-analysis/43zd...       196077
# 23  https://api.spotify.com/v1/audio-analysis/7emJ...       192400
# 24  https://api.spotify.com/v1/audio-analysis/5XYN...       221253
# 25  https://api.spotify.com/v1/audio-analysis/1Pok...       304907
# 26  https://api.spotify.com/v1/audio-analysis/408i...       228500
# 27  https://api.spotify.com/v1/audio-analysis/4g07...       221253
# 28  https://api.spotify.com/v1/audio-analysis/0qeK...       229375
# 29  https://api.spotify.com/v1/audio-analysis/5Tvd...       169493
# 30  https://api.spotify.com/v1/audio-analysis/6ST6...       188817
# 31  https://api.spotify.com/v1/audio-analysis/5w4e...       146773
# 32  https://api.spotify.com/v1/audio-analysis/6BZu...       250000
# 33  https://api.spotify.com/v1/audio-analysis/2uqN...       152940
# 34  https://api.spotify.com/v1/audio-analysis/3UCQ...       191806
# 35  https://api.spotify.com/v1/audio-analysis/4t2O...       210233
# 36  https://api.spotify.com/v1/audio-analysis/4SSn...       193143
# 37  https://api.spotify.com/v1/audio-analysis/1O8B...       159360
# 38  https://api.spotify.com/v1/audio-analysis/5bnP...       181453
# 39  https://api.spotify.com/v1/audio-analysis/3rmo...       230747
# 40  https://api.spotify.com/v1/audio-analysis/4727...       138082
# 41  https://api.spotify.com/v1/audio-analysis/0otm...       225101
# 42  https://api.spotify.com/v1/audio-analysis/7ER1...       193361
# 43  https://api.spotify.com/v1/audio-analysis/4FoR...       144170
# 44  https://api.spotify.com/v1/audio-analysis/69Xn...       234107
# 45  https://api.spotify.com/v1/audio-analysis/1zQ2...       183241
# 46  https://api.spotify.com/v1/audio-analysis/4G1F...       239480
# 47  https://api.spotify.com/v1/audio-analysis/6tRL...       194062
# 48  https://api.spotify.com/v1/audio-analysis/2ygv...       208155
# 49  https://api.spotify.com/v1/audio-analysis/34Lb...       213554
#
#     time_signature
# 0                4
# 1                4
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               4
# 24               4
# 25               4
# 26               4
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4
# 45               4
# 46               4
# 47               4
# 48               4
# 49               4

# %% [markdown]
# ## Searching a playlist

# %%
playlist = sp.user_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY",market="GB")

# %%
playlist
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=0&limit=100&market=GB&additional_types=track',
#  'items': [{'added_at': '2017-06-09T17:34:13Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#        'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#        'id': '2FXC3k01G6Gw61bmprjgqS',
#        'name': 'Hozier',
#        'type': 'artist',
#        'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0Uv83rRhY5QvHKkQoULRKk'},
#      'href': 'https://api.spotify.com/v1/albums/0Uv83rRhY5QvHKkQoULRKk',
#      'id': '0Uv83rRhY5QvHKkQoULRKk',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737a9bf5f82e32d33d4503fe7b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027a9bf5f82e32d33d4503fe7b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517a9bf5f82e32d33d4503fe7b',
#        'width': 64}],
#      'name': 'Hozier',
#      'release_date': '2014-07-20',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0Uv83rRhY5QvHKkQoULRKk'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#       'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#       'id': '2FXC3k01G6Gw61bmprjgqS',
#       'name': 'Hozier',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#     'disc_number': 1,
#     'duration_ms': 241688,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'IEACJ1300031'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3dYD57lRAUcMHufyqn9GcI'},
#     'href': 'https://api.spotify.com/v1/tracks/3dYD57lRAUcMHufyqn9GcI',
#     'id': '3dYD57lRAUcMHufyqn9GcI',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7dS5EaCoMnN7DzlpT6aRn2'},
#      'href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
#      'id': '7dS5EaCoMnN7DzlpT6aRn2',
#      'type': 'track',
#      'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2'},
#     'name': 'Take Me To Church',
#     'popularity': 83,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:3dYD57lRAUcMHufyqn9GcI'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2017-06-29T20:42:16Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#        'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#        'id': '2KsP6tYLJlTBvSUxnwlVWa',
#        'name': 'Mike Posner',
#        'type': 'artist',
#        'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2nnIlWcriIqcJtjduWcTRl'},
#      'href': 'https://api.spotify.com/v1/albums/2nnIlWcriIqcJtjduWcTRl',
#      'id': '2nnIlWcriIqcJtjduWcTRl',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d6165c0d6eba7e5bf3fca16d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d6165c0d6eba7e5bf3fca16d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d6165c0d6eba7e5bf3fca16d',
#        'width': 64}],
#      'name': '31 Minutes to Takeoff',
#      'release_date': '2010-08-09',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:2nnIlWcriIqcJtjduWcTRl'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#       'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#       'id': '2KsP6tYLJlTBvSUxnwlVWa',
#       'name': 'Mike Posner',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5RIimuW7xG7et3aQX1idHV'},
#       'href': 'https://api.spotify.com/v1/artists/5RIimuW7xG7et3aQX1idHV',
#       'id': '5RIimuW7xG7et3aQX1idHV',
#       'name': 'Matt Masurka',
#       'type': 'artist',
#       'uri': 'spotify:artist:5RIimuW7xG7et3aQX1idHV'}],
#     'disc_number': 1,
#     'duration_ms': 213293,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJAY1000035'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2V4bv1fNWfTcyRJKmej6Sj'},
#     'href': 'https://api.spotify.com/v1/tracks/2V4bv1fNWfTcyRJKmej6Sj',
#     'id': '2V4bv1fNWfTcyRJKmej6Sj',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cooler Than Me - Single Mix',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/bf16e71252fdb6ef6e9306630d1606d6c44ef742?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2018-07-19T15:34:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#        'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#        'id': '4V8LLVI7PbaPR0K2TGSxFF',
#        'name': 'Tyler, The Creator',
#        'type': 'artist',
#        'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#      'href': 'https://api.spotify.com/v1/albums/2nkto6YNI4rUYTLqEwWJ3o',
#      'id': '2nkto6YNI4rUYTLqEwWJ3o',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738940ac99f49e44f59e6f7fb3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028940ac99f49e44f59e6f7fb3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518940ac99f49e44f59e6f7fb3',
#        'width': 64}],
#      'name': 'Flower Boy',
#      'release_date': '2017-07-21',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2nkto6YNI4rUYTLqEwWJ3o'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#       'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#       'id': '4V8LLVI7PbaPR0K2TGSxFF',
#       'name': 'Tyler, The Creator',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#       'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#       'id': '1U1el3k54VvEUzo3ybLPlM',
#       'name': 'Kali Uchis',
#       'type': 'artist',
#       'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#     'disc_number': 1,
#     'duration_ms': 180386,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USQX91701275'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB'},
#     'href': 'https://api.spotify.com/v1/tracks/7KA4W4McWYRpgf0fWsJZWB',
#     'id': '7KA4W4McWYRpgf0fWsJZWB',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'See You Again (feat. Kali Uchis)',
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e6c4c9656721fe0a042b61be26adbb57c7032a73?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:7KA4W4McWYRpgf0fWsJZWB'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:32:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EQ0qTo7fWT7DPxmxtSYEc'},
#        'href': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc',
#        'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#        'name': 'Bastille',
#        'type': 'artist',
#        'uri': 'spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5G6oMu9zNW2acdV0lqzI3L'},
#      'href': 'https://api.spotify.com/v1/albums/5G6oMu9zNW2acdV0lqzI3L',
#      'id': '5G6oMu9zNW2acdV0lqzI3L',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273faee7306ec2f36aeccc4bc98',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02faee7306ec2f36aeccc4bc98',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851faee7306ec2f36aeccc4bc98',
#        'width': 64}],
#      'name': 'All This Bad Blood',
#      'release_date': '2013-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:5G6oMu9zNW2acdV0lqzI3L'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EQ0qTo7fWT7DPxmxtSYEc'},
#       'href': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc',
#       'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#       'name': 'Bastille',
#       'type': 'artist',
#       'uri': 'spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc'}],
#     'disc_number': 1,
#     'duration_ms': 214147,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBAAA1200795'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4Ub8UsjWuewQrPhuepfVpd'},
#     'href': 'https://api.spotify.com/v1/tracks/4Ub8UsjWuewQrPhuepfVpd',
#     'id': '4Ub8UsjWuewQrPhuepfVpd',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3gbBpTdY8lnQwqxNCcf795'},
#      'href': 'https://api.spotify.com/v1/tracks/3gbBpTdY8lnQwqxNCcf795',
#      'id': '3gbBpTdY8lnQwqxNCcf795',
#      'type': 'track',
#      'uri': 'spotify:track:3gbBpTdY8lnQwqxNCcf795'},
#     'name': 'Pompeii',
#     'popularity': 75,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4Ub8UsjWuewQrPhuepfVpd'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#        'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#        'id': '0EmeFodog0BfCgMzAIvKQp',
#        'name': 'Shakira',
#        'type': 'artist',
#        'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5ppnlEoj4HdRRdRihnY3jU'},
#      'href': 'https://api.spotify.com/v1/albums/5ppnlEoj4HdRRdRihnY3jU',
#      'id': '5ppnlEoj4HdRRdRihnY3jU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27327ddd747545c0d0cfe7595fa',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0227ddd747545c0d0cfe7595fa',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485127ddd747545c0d0cfe7595fa',
#        'width': 64}],
#      'name': 'Oral Fixation, Vol. 2 (Expanded Edition)',
#      'release_date': '2005-11-28',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:5ppnlEoj4HdRRdRihnY3jU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aBzpmFXB4WWpPl2F7RjBe'},
#       'href': 'https://api.spotify.com/v1/artists/7aBzpmFXB4WWpPl2F7RjBe',
#       'id': '7aBzpmFXB4WWpPl2F7RjBe',
#       'name': 'Wyclef Jean',
#       'type': 'artist',
#       'uri': 'spotify:artist:7aBzpmFXB4WWpPl2F7RjBe'}],
#     'disc_number': 1,
#     'duration_ms': 218093,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10600677'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3ZFTkvIE7kyPt6Nu3PEa7V'},
#     'href': 'https://api.spotify.com/v1/tracks/3ZFTkvIE7kyPt6Nu3PEa7V',
#     'id': '3ZFTkvIE7kyPt6Nu3PEa7V',
#     'is_local': False,
#     'is_playable': True,
#     'name': "Hips Don't Lie (feat. Wyclef Jean)",
#     'popularity': 85,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5e6f328ae98e7665cb40b4580773ea0107c5631f?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:31:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#        'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#        'id': '3AQRLZ9PuTAozP28Skbq8V',
#        'name': 'The Script',
#        'type': 'artist',
#        'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7JOCOjZTcLysDMkZGWlcIj'},
#      'href': 'https://api.spotify.com/v1/albums/7JOCOjZTcLysDMkZGWlcIj',
#      'id': '7JOCOjZTcLysDMkZGWlcIj',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732e3049fef96abebf336b7366',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022e3049fef96abebf336b7366',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512e3049fef96abebf336b7366',
#        'width': 64}],
#      'name': '#3 Deluxe Version',
#      'release_date': '2012-09-10',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:7JOCOjZTcLysDMkZGWlcIj'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/085pc2PYOi8bGKj0PNjekA'},
#       'href': 'https://api.spotify.com/v1/artists/085pc2PYOi8bGKj0PNjekA',
#       'id': '085pc2PYOi8bGKj0PNjekA',
#       'name': 'will.i.am',
#       'type': 'artist',
#       'uri': 'spotify:artist:085pc2PYOi8bGKj0PNjekA'}],
#     'disc_number': 1,
#     'duration_ms': 202533,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBARL1201055'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7wMq5n8mYSKlQIGECKUgTX'},
#     'href': 'https://api.spotify.com/v1/tracks/7wMq5n8mYSKlQIGECKUgTX',
#     'id': '7wMq5n8mYSKlQIGECKUgTX',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Hall of Fame (feat. will.i.am)',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a887360f6897298991dd402161835e86480fd9c5?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7wMq5n8mYSKlQIGECKUgTX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:31:59Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fahUm8t5c0GIdeTq0ZaG8'},
#        'href': 'https://api.spotify.com/v1/artists/5fahUm8t5c0GIdeTq0ZaG8',
#        'id': '5fahUm8t5c0GIdeTq0ZaG8',
#        'name': 'Otto Knows',
#        'type': 'artist',
#        'uri': 'spotify:artist:5fahUm8t5c0GIdeTq0ZaG8'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6c4fND91gsKojyp3Mox97y'},
#      'href': 'https://api.spotify.com/v1/albums/6c4fND91gsKojyp3Mox97y',
#      'id': '6c4fND91gsKojyp3Mox97y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e86879dff1cf1476698d05c7',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e86879dff1cf1476698d05c7',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e86879dff1cf1476698d05c7',
#        'width': 64}],
#      'name': 'Back Where I Belong (feat. Avicii)',
#      'release_date': '2016-06-03',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6c4fND91gsKojyp3Mox97y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fahUm8t5c0GIdeTq0ZaG8'},
#       'href': 'https://api.spotify.com/v1/artists/5fahUm8t5c0GIdeTq0ZaG8',
#       'id': '5fahUm8t5c0GIdeTq0ZaG8',
#       'name': 'Otto Knows',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fahUm8t5c0GIdeTq0ZaG8'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#       'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#       'id': '1vCWHaC5f2uS3yhpwWbIA6',
#       'name': 'Avicii',
#       'type': 'artist',
#       'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#     'disc_number': 1,
#     'duration_ms': 174202,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'SE4OX1600112'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/78W8wiUIlQ2SnWY9TVowKZ'},
#     'href': 'https://api.spotify.com/v1/tracks/78W8wiUIlQ2SnWY9TVowKZ',
#     'id': '78W8wiUIlQ2SnWY9TVowKZ',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Back Where I Belong (feat. Avicii)',
#     'popularity': 55,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5edcfcbef8bfa1a1b4b0b0b40b2ad6a7308e8667?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:78W8wiUIlQ2SnWY9TVowKZ'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:33:25Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#        'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#        'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#        'name': 'Selena Gomez',
#        'type': 'artist',
#        'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2iFTxCYwhF5oC1L8s1B0rI'},
#      'href': 'https://api.spotify.com/v1/albums/2iFTxCYwhF5oC1L8s1B0rI',
#      'id': '2iFTxCYwhF5oC1L8s1B0rI',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273f7dd2cadacebfe2d3c5d96be',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02f7dd2cadacebfe2d3c5d96be',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851f7dd2cadacebfe2d3c5d96be',
#        'width': 64}],
#      'name': 'The Heart Wants What It Wants',
#      'release_date': '2014-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:2iFTxCYwhF5oC1L8s1B0rI'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#       'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#       'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#       'name': 'Selena Gomez',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#     'disc_number': 1,
#     'duration_ms': 227373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USHR11435979'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6wJwkMo278iWVlWl1XQ4WA'},
#     'href': 'https://api.spotify.com/v1/tracks/6wJwkMo278iWVlWl1XQ4WA',
#     'id': '6wJwkMo278iWVlWl1XQ4WA',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2jcPoPin36hyNRSi4ZsqeB'},
#      'href': 'https://api.spotify.com/v1/tracks/2jcPoPin36hyNRSi4ZsqeB',
#      'id': '2jcPoPin36hyNRSi4ZsqeB',
#      'type': 'track',
#      'uri': 'spotify:track:2jcPoPin36hyNRSi4ZsqeB'},
#     'name': 'The Heart Wants What It Wants',
#     'popularity': 68,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6wJwkMo278iWVlWl1XQ4WA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:27Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#        'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#        'id': '6MF9fzBmfXghAz953czmBC',
#        'name': 'Taio Cruz',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0eGvq1J5Ke7VlLLOYIlY4k'},
#      'href': 'https://api.spotify.com/v1/albums/0eGvq1J5Ke7VlLLOYIlY4k',
#      'id': '0eGvq1J5Ke7VlLLOYIlY4k',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27366c3eb32692a0ae487079cf1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0266c3eb32692a0ae487079cf1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485166c3eb32692a0ae487079cf1',
#        'width': 64}],
#      'name': 'The Rokstarr Hits Collection',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:0eGvq1J5Ke7VlLLOYIlY4k'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#       'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#       'id': '6MF9fzBmfXghAz953czmBC',
#       'name': 'Taio Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#     'disc_number': 1,
#     'duration_ms': 202613,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71003721'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2CEgGE6aESpnmtfiZwYlbV'},
#     'href': 'https://api.spotify.com/v1/tracks/2CEgGE6aESpnmtfiZwYlbV',
#     'id': '2CEgGE6aESpnmtfiZwYlbV',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Dynamite',
#     'popularity': 81,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2CEgGE6aESpnmtfiZwYlbV'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#        'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#        'id': '37GUqxafAvAKGMZbXCUnmr',
#        'name': 'Mohombi',
#        'type': 'artist',
#        'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0TFxOkFYPrhIzzrKv5CWZf'},
#      'href': 'https://api.spotify.com/v1/albums/0TFxOkFYPrhIzzrKv5CWZf',
#      'id': '0TFxOkFYPrhIzzrKv5CWZf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733cfcf82ef4d0685f4e4e95a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023cfcf82ef4d0685f4e4e95a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513cfcf82ef4d0685f4e4e95a5',
#        'width': 64}],
#      'name': 'MoveMeant (International)',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0TFxOkFYPrhIzzrKv5CWZf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#       'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#       'id': '37GUqxafAvAKGMZbXCUnmr',
#       'name': 'Mohombi',
#       'type': 'artist',
#       'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#     'disc_number': 1,
#     'duration_ms': 224720,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71024652'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/71R6zJsrF3ffc3TBFHfivX'},
#     'href': 'https://api.spotify.com/v1/tracks/71R6zJsrF3ffc3TBFHfivX',
#     'id': '71R6zJsrF3ffc3TBFHfivX',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0tBRo4P60DgKmg4jt48upm'},
#      'href': 'https://api.spotify.com/v1/tracks/0tBRo4P60DgKmg4jt48upm',
#      'id': '0tBRo4P60DgKmg4jt48upm',
#      'type': 'track',
#      'uri': 'spotify:track:0tBRo4P60DgKmg4jt48upm'},
#     'name': 'Bumpy Ride',
#     'popularity': 73,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:71R6zJsrF3ffc3TBFHfivX'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:32Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'},
#        'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E',
#        'id': '5bv5RplEOwdCvhq0EILh9E',
#        'name': 'Lucenzo',
#        'type': 'artist',
#        'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1eoYupgvxWRBT6nHnAHjEQ'},
#      'href': 'https://api.spotify.com/v1/albums/1eoYupgvxWRBT6nHnAHjEQ',
#      'id': '1eoYupgvxWRBT6nHnAHjEQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273dd6b19d30e8b2531c625fbc4',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02dd6b19d30e8b2531c625fbc4',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851dd6b19d30e8b2531c625fbc4',
#        'width': 64}],
#      'name': 'Emigrante Del Mundo (Remastered)',
#      'release_date': '2011-12-19',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:1eoYupgvxWRBT6nHnAHjEQ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'},
#       'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E',
#       'id': '5bv5RplEOwdCvhq0EILh9E',
#       'name': 'Lucenzo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LqXqd68BBoEk9RDYeS0ls'},
#       'href': 'https://api.spotify.com/v1/artists/4LqXqd68BBoEk9RDYeS0ls',
#       'id': '4LqXqd68BBoEk9RDYeS0ls',
#       'name': 'Big Ali',
#       'type': 'artist',
#       'uri': 'spotify:artist:4LqXqd68BBoEk9RDYeS0ls'}],
#     'disc_number': 1,
#     'duration_ms': 199235,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FR43Y1000010'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6ku3i5WNrsY3qhOq6ua9TL'},
#     'href': 'https://api.spotify.com/v1/tracks/6ku3i5WNrsY3qhOq6ua9TL',
#     'id': '6ku3i5WNrsY3qhOq6ua9TL',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1kAZhbcsXqfUjnVeqPywn2'},
#      'href': 'https://api.spotify.com/v1/tracks/1kAZhbcsXqfUjnVeqPywn2',
#      'id': '1kAZhbcsXqfUjnVeqPywn2',
#      'type': 'track',
#      'uri': 'spotify:track:1kAZhbcsXqfUjnVeqPywn2'},
#     'name': 'Vem Dancar Kuduro',
#     'popularity': 69,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:6ku3i5WNrsY3qhOq6ua9TL'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:35Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZZqIQ25HQmufjjf2trwFO'},
#        'href': 'https://api.spotify.com/v1/artists/5ZZqIQ25HQmufjjf2trwFO',
#        'id': '5ZZqIQ25HQmufjjf2trwFO',
#        'name': 'Cheek',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ZZqIQ25HQmufjjf2trwFO'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Y6qK0mEmyeXHs3DJOGGYO'},
#      'href': 'https://api.spotify.com/v1/albums/3Y6qK0mEmyeXHs3DJOGGYO',
#      'id': '3Y6qK0mEmyeXHs3DJOGGYO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27361f43967534f6d07251909ec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0261f43967534f6d07251909ec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485161f43967534f6d07251909ec',
#        'width': 64}],
#      'name': 'Sokka irti',
#      'release_date': '2012-04-04',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:3Y6qK0mEmyeXHs3DJOGGYO'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZZqIQ25HQmufjjf2trwFO'},
#       'href': 'https://api.spotify.com/v1/artists/5ZZqIQ25HQmufjjf2trwFO',
#       'id': '5ZZqIQ25HQmufjjf2trwFO',
#       'name': 'Cheek',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZZqIQ25HQmufjjf2trwFO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TZMaBvTPuICA1EQAWjKWZ'},
#       'href': 'https://api.spotify.com/v1/artists/5TZMaBvTPuICA1EQAWjKWZ',
#       'id': '5TZMaBvTPuICA1EQAWjKWZ',
#       'name': 'Yasmine Yamajako',
#       'type': 'artist',
#       'uri': 'spotify:artist:5TZMaBvTPuICA1EQAWjKWZ'}],
#     'disc_number': 1,
#     'duration_ms': 230413,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'FIWMA1200063'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2N2QvMYwyYHE8V4KZbbG4i'},
#     'href': 'https://api.spotify.com/v1/tracks/2N2QvMYwyYHE8V4KZbbG4i',
#     'id': '2N2QvMYwyYHE8V4KZbbG4i',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Syypää sun hymyyn (feat. Yasmine Yamajako)',
#     'popularity': 44,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b6b679b6753c040630918831976c472494ae6704?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2N2QvMYwyYHE8V4KZbbG4i'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#        'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#        'id': '0jnsk9HBra6NMjO2oANoPY',
#        'name': 'Flo Rida',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/355RqMyXhDoOD0l4qMUxeT'},
#      'href': 'https://api.spotify.com/v1/albums/355RqMyXhDoOD0l4qMUxeT',
#      'id': '355RqMyXhDoOD0l4qMUxeT',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738fff33d4cece7b62bda3a2a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028fff33d4cece7b62bda3a2a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518fff33d4cece7b62bda3a2a5',
#        'width': 64}],
#      'name': 'Whistle',
#      'release_date': '2012-04-24',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:355RqMyXhDoOD0l4qMUxeT'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'disc_number': 1,
#     'duration_ms': 225000,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21201745'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0ltBH1JNzSvQJPjJpvTu9B'},
#     'href': 'https://api.spotify.com/v1/tracks/0ltBH1JNzSvQJPjJpvTu9B',
#     'id': '0ltBH1JNzSvQJPjJpvTu9B',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Whistle',
#     'popularity': 59,
#     'preview_url': 'https://p.scdn.co/mp3-preview/60271ca2deeb5d44b617aa9e05281f667c45f525?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0ltBH1JNzSvQJPjJpvTu9B'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:41Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#        'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#        'id': '0p4nmQO2msCgU4IF37Wi3j',
#        'name': 'Avril Lavigne',
#        'type': 'artist',
#        'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6lqE05fiHWJVYYdMVJNj38'},
#      'href': 'https://api.spotify.com/v1/albums/6lqE05fiHWJVYYdMVJNj38',
#      'id': '6lqE05fiHWJVYYdMVJNj38',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273476cdf5837ae39eee951cc15',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02476cdf5837ae39eee951cc15',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851476cdf5837ae39eee951cc15',
#        'width': 64}],
#      'name': 'The Best Damn Thing (Expanded Edition)',
#      'release_date': '2007-04-17',
#      'release_date_precision': 'day',
#      'total_tracks': 17,
#      'type': 'album',
#      'uri': 'spotify:album:6lqE05fiHWJVYYdMVJNj38'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#       'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#       'id': '0p4nmQO2msCgU4IF37Wi3j',
#       'name': 'Avril Lavigne',
#       'type': 'artist',
#       'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#     'disc_number': 1,
#     'duration_ms': 216600,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USRC10700021'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/45hOioMDJktr86iKDHC8gr'},
#     'href': 'https://api.spotify.com/v1/tracks/45hOioMDJktr86iKDHC8gr',
#     'id': '45hOioMDJktr86iKDHC8gr',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HbCnVLXRyZVxnreOPgJCK'},
#      'href': 'https://api.spotify.com/v1/tracks/5HbCnVLXRyZVxnreOPgJCK',
#      'id': '5HbCnVLXRyZVxnreOPgJCK',
#      'type': 'track',
#      'uri': 'spotify:track:5HbCnVLXRyZVxnreOPgJCK'},
#     'name': 'Girlfriend',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a483f9955188f39637f4fd143ef47d47fbc55edf?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:45hOioMDJktr86iKDHC8gr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:45Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#        'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#        'id': '1uNFoZAHBGtllmzznpCI3s',
#        'name': 'Justin Bieber',
#        'type': 'artist',
#        'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3BmcYMh0KYsimWL6p2gPa9'},
#      'href': 'https://api.spotify.com/v1/albums/3BmcYMh0KYsimWL6p2gPa9',
#      'id': '3BmcYMh0KYsimWL6p2gPa9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273629dc9e2e3bc20bbd7d92e4a',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02629dc9e2e3bc20bbd7d92e4a',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851629dc9e2e3bc20bbd7d92e4a',
#        'width': 64}],
#      'name': 'My World 2.0',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:3BmcYMh0KYsimWL6p2gPa9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ipn9JLAPI5GUEo4y4jcoi'},
#       'href': 'https://api.spotify.com/v1/artists/3ipn9JLAPI5GUEo4y4jcoi',
#       'id': '3ipn9JLAPI5GUEo4y4jcoi',
#       'name': 'Ludacris',
#       'type': 'artist',
#       'uri': 'spotify:artist:3ipn9JLAPI5GUEo4y4jcoi'}],
#     'disc_number': 1,
#     'duration_ms': 214240,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70919263'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6epn3r7S14KUqlReYr77hA'},
#     'href': 'https://api.spotify.com/v1/tracks/6epn3r7S14KUqlReYr77hA',
#     'id': '6epn3r7S14KUqlReYr77hA',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4NFhtFE68cXUrfbne8JE2c'},
#      'href': 'https://api.spotify.com/v1/tracks/4NFhtFE68cXUrfbne8JE2c',
#      'id': '4NFhtFE68cXUrfbne8JE2c',
#      'type': 'track',
#      'uri': 'spotify:track:4NFhtFE68cXUrfbne8JE2c'},
#     'name': 'Baby',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6epn3r7S14KUqlReYr77hA'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:47Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#        'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#        'id': '0jnsk9HBra6NMjO2oANoPY',
#        'name': 'Flo Rida',
#        'type': 'artist',
#        'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0aGzTOetC7VdotwXeWLenJ'},
#      'href': 'https://api.spotify.com/v1/albums/0aGzTOetC7VdotwXeWLenJ',
#      'id': '0aGzTOetC7VdotwXeWLenJ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ea73afbe3f6fe4afb15fccdc',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ea73afbe3f6fe4afb15fccdc',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ea73afbe3f6fe4afb15fccdc',
#        'width': 64}],
#      'name': 'Wild Ones (Deluxe)',
#      'release_date': '2012-06-22',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0aGzTOetC7VdotwXeWLenJ'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'disc_number': 1,
#     'duration_ms': 223800,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USAT21202584'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5HE3z4Ew7wZ91l3ZOpGKa4'},
#     'href': 'https://api.spotify.com/v1/tracks/5HE3z4Ew7wZ91l3ZOpGKa4',
#     'id': '5HE3z4Ew7wZ91l3ZOpGKa4',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'I Cry',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/60843f82dda9ccf24caa1cc22a2e2e20a92c5e81?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:5HE3z4Ew7wZ91l3ZOpGKa4'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#        'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#        'id': '37GUqxafAvAKGMZbXCUnmr',
#        'name': 'Mohombi',
#        'type': 'artist',
#        'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0TFxOkFYPrhIzzrKv5CWZf'},
#      'href': 'https://api.spotify.com/v1/albums/0TFxOkFYPrhIzzrKv5CWZf',
#      'id': '0TFxOkFYPrhIzzrKv5CWZf',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733cfcf82ef4d0685f4e4e95a5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023cfcf82ef4d0685f4e4e95a5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513cfcf82ef4d0685f4e4e95a5',
#        'width': 64}],
#      'name': 'MoveMeant (International)',
#      'release_date': '2010-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0TFxOkFYPrhIzzrKv5CWZf'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#       'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#       'id': '37GUqxafAvAKGMZbXCUnmr',
#       'name': 'Mohombi',
#       'type': 'artist',
#       'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/40xbWSB4JPdOkRyuTDy1oP'},
#       'href': 'https://api.spotify.com/v1/artists/40xbWSB4JPdOkRyuTDy1oP',
#       'id': '40xbWSB4JPdOkRyuTDy1oP',
#       'name': 'Nicole Scherzinger',
#       'type': 'artist',
#       'uri': 'spotify:artist:40xbWSB4JPdOkRyuTDy1oP'}],
#     'disc_number': 1,
#     'duration_ms': 218373,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBUM71027585'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1j7GNdjuK5wfmvxCbVcWMY'},
#     'href': 'https://api.spotify.com/v1/tracks/1j7GNdjuK5wfmvxCbVcWMY',
#     'id': '1j7GNdjuK5wfmvxCbVcWMY',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5L9THbmMKB6ZlHlMgzaXHf'},
#      'href': 'https://api.spotify.com/v1/tracks/5L9THbmMKB6ZlHlMgzaXHf',
#      'id': '5L9THbmMKB6ZlHlMgzaXHf',
#      'type': 'track',
#      'uri': 'spotify:track:5L9THbmMKB6ZlHlMgzaXHf'},
#     'name': 'Coconut Tree',
#     'popularity': 56,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:1j7GNdjuK5wfmvxCbVcWMY'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:34:54Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
# ...
#      'href': 'https://api.spotify.com/v1/albums/1dgbFU08pXJXZhGPlybdMX',
#      'id': '1dgbFU08pXJXZhGPlybdMX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730bd44f5ff9ecc99f7770acc5',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020bd44f5ff9ecc99f7770acc5',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510bd44f5ff9ecc99f7770acc5',
#        'width': 64}],
#      'name': 'THE E.N.D. (THE ENERGY NEVER DIES) [Deluxe Version]',
#      'release_date': '2009-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 25,
#      'type': 'album',
#      'uri': 'spotify:album:1dgbFU08pXJXZhGPlybdMX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1yxSLGMDHlW21z4YXirZDS'},
#       'href': 'https://api.spotify.com/v1/artists/1yxSLGMDHlW21z4YXirZDS',
#       'id': '1yxSLGMDHlW21z4YXirZDS',
#       'name': 'Black Eyed Peas',
#       'type': 'artist',
#       'uri': 'spotify:artist:1yxSLGMDHlW21z4YXirZDS'}],
#     'disc_number': 1,
#     'duration_ms': 289133,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM70965169'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4kLLWz7srcuLKA7Et40PQR'},
#     'href': 'https://api.spotify.com/v1/tracks/4kLLWz7srcuLKA7Et40PQR',
#     'id': '4kLLWz7srcuLKA7Et40PQR',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4vp2J1l5RD4gMZwGFLfRAu'},
#      'href': 'https://api.spotify.com/v1/tracks/4vp2J1l5RD4gMZwGFLfRAu',
#      'id': '4vp2J1l5RD4gMZwGFLfRAu',
#      'type': 'track',
#      'uri': 'spotify:track:4vp2J1l5RD4gMZwGFLfRAu'},
#     'name': 'I Gotta Feeling',
#     'popularity': 82,
#     'preview_url': None,
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:4kLLWz7srcuLKA7Et40PQR'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:38:50Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#        'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#        'id': '6vWDO969PvNqNYHIOW5v0m',
#        'name': 'Beyoncé',
#        'type': 'artist',
#        'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3ROfBX6lJLnCmaw1NrP5K9'},
#      'href': 'https://api.spotify.com/v1/albums/3ROfBX6lJLnCmaw1NrP5K9',
#      'id': '3ROfBX6lJLnCmaw1NrP5K9',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b4c5982e1b92f97a126fc18c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b4c5982e1b92f97a126fc18c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b4c5982e1b92f97a126fc18c',
#        'width': 64}],
#      'name': 'I AM...SASHA FIERCE - Platinum Edition',
#      'release_date': '2008',
#      'release_date_precision': 'year',
#      'total_tracks': 20,
#      'type': 'album',
#      'uri': 'spotify:album:3ROfBX6lJLnCmaw1NrP5K9'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6vWDO969PvNqNYHIOW5v0m'},
#       'href': 'https://api.spotify.com/v1/artists/6vWDO969PvNqNYHIOW5v0m',
#       'id': '6vWDO969PvNqNYHIOW5v0m',
#       'name': 'Beyoncé',
#       'type': 'artist',
#       'uri': 'spotify:artist:6vWDO969PvNqNYHIOW5v0m'}],
#     'disc_number': 1,
#     'duration_ms': 261160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USSM10804556'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2CvOqDpQIMw69cCzWqr5yr'},
#     'href': 'https://api.spotify.com/v1/tracks/2CvOqDpQIMw69cCzWqr5yr',
#     'id': '2CvOqDpQIMw69cCzWqr5yr',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4JehYebiI9JE8sR8MisGVb'},
#      'href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb',
#      'id': '4JehYebiI9JE8sR8MisGVb',
#      'type': 'track',
#      'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb'},
#     'name': 'Halo',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b68d3fe9fc5f46ca06965b72bede905636e6a23c?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:2CvOqDpQIMw69cCzWqr5yr'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:38:52Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#        'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#        'id': '31TPClRtHm23RisEBtV3X7',
#        'name': 'Justin Timberlake',
#        'type': 'artist',
#        'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6QPkyl04rXwTGlGlcYaRoW'},
#      'href': 'https://api.spotify.com/v1/albums/6QPkyl04rXwTGlGlcYaRoW',
#      'id': '6QPkyl04rXwTGlGlcYaRoW',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273346a5742374ab4cf9ed32dee',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02346a5742374ab4cf9ed32dee',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851346a5742374ab4cf9ed32dee',
#        'width': 64}],
#      'name': 'Justified',
#      'release_date': '2002-11-04',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:6QPkyl04rXwTGlGlcYaRoW'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/31TPClRtHm23RisEBtV3X7'},
#       'href': 'https://api.spotify.com/v1/artists/31TPClRtHm23RisEBtV3X7',
#       'id': '31TPClRtHm23RisEBtV3X7',
#       'name': 'Justin Timberlake',
#       'type': 'artist',
#       'uri': 'spotify:artist:31TPClRtHm23RisEBtV3X7'}],
#     'disc_number': 1,
#     'duration_ms': 288333,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'USJI10200366'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7Lf7oSEVdzZqTA0kEDSlS5'},
#     'href': 'https://api.spotify.com/v1/tracks/7Lf7oSEVdzZqTA0kEDSlS5',
#     'id': '7Lf7oSEVdzZqTA0kEDSlS5',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Cry Me a River',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/ed9615d350705c525f74889dca3765103db3e15d?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:7Lf7oSEVdzZqTA0kEDSlS5'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:38:56Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LfGQac0EIXyAN8aUwmNAQ'},
#        'href': 'https://api.spotify.com/v1/artists/5LfGQac0EIXyAN8aUwmNAQ',
#        'id': '5LfGQac0EIXyAN8aUwmNAQ',
#        'name': 'The Offspring',
#        'type': 'artist',
#        'uri': 'spotify:artist:5LfGQac0EIXyAN8aUwmNAQ'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/67v63ubEsvDUQkYMzI7A9t'},
#      'href': 'https://api.spotify.com/v1/albums/67v63ubEsvDUQkYMzI7A9t',
#      'id': '67v63ubEsvDUQkYMzI7A9t',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273890ce61533a89e00ce593fcb',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02890ce61533a89e00ce593fcb',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851890ce61533a89e00ce593fcb',
#        'width': 64}],
#      'name': 'Rise And Fall, Rage And Grace',
#      'release_date': '2008-06-17',
#      'release_date_precision': 'day',
#      'total_tracks': 12,
#      'type': 'album',
#      'uri': 'spotify:album:67v63ubEsvDUQkYMzI7A9t'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5LfGQac0EIXyAN8aUwmNAQ'},
#       'href': 'https://api.spotify.com/v1/artists/5LfGQac0EIXyAN8aUwmNAQ',
#       'id': '5LfGQac0EIXyAN8aUwmNAQ',
#       'name': 'The Offspring',
#       'type': 'artist',
#       'uri': 'spotify:artist:5LfGQac0EIXyAN8aUwmNAQ'}],
#     'disc_number': 1,
#     'duration_ms': 177826,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USSM10801605'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6TfBA04WJ3X1d1wXhaCFVT'},
#     'href': 'https://api.spotify.com/v1/tracks/6TfBA04WJ3X1d1wXhaCFVT',
#     'id': '6TfBA04WJ3X1d1wXhaCFVT',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1FMm3wG5WOhi7js35KR7Ea'},
#      'href': 'https://api.spotify.com/v1/tracks/1FMm3wG5WOhi7js35KR7Ea',
#      'id': '1FMm3wG5WOhi7js35KR7Ea',
#      'type': 'track',
#      'uri': 'spotify:track:1FMm3wG5WOhi7js35KR7Ea'},
#     'name': "You're Gonna Go Far, Kid",
#     'popularity': 80,
#     'preview_url': None,
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:6TfBA04WJ3X1d1wXhaCFVT'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:29Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KCSPY1glIKqW2TotWuXOR'},
#        'href': 'https://api.spotify.com/v1/artists/1KCSPY1glIKqW2TotWuXOR',
#        'id': '1KCSPY1glIKqW2TotWuXOR',
#        'name': 'P!nk',
#        'type': 'artist',
#        'uri': 'spotify:artist:1KCSPY1glIKqW2TotWuXOR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1LOJfNDxQhbpssKx7oM7at'},
#      'href': 'https://api.spotify.com/v1/albums/1LOJfNDxQhbpssKx7oM7at',
#      'id': '1LOJfNDxQhbpssKx7oM7at',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735a45d5041e4ffcb9f756f740',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025a45d5041e4ffcb9f756f740',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515a45d5041e4ffcb9f756f740',
#        'width': 64}],
#      'name': 'Funhouse (Expanded Edition)',
#      'release_date': '2008-10-24',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:1LOJfNDxQhbpssKx7oM7at'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1KCSPY1glIKqW2TotWuXOR'},
#       'href': 'https://api.spotify.com/v1/artists/1KCSPY1glIKqW2TotWuXOR',
#       'id': '1KCSPY1glIKqW2TotWuXOR',
#       'name': 'P!nk',
#       'type': 'artist',
#       'uri': 'spotify:artist:1KCSPY1glIKqW2TotWuXOR'}],
#     'disc_number': 1,
#     'duration_ms': 215160,
#     'episode': False,
#     'explicit': True,
#     'external_ids': {'isrc': 'USLF20800067'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0JiY190vktuhSGN6aqJdrt'},
#     'href': 'https://api.spotify.com/v1/tracks/0JiY190vktuhSGN6aqJdrt',
#     'id': '0JiY190vktuhSGN6aqJdrt',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/6qYGUxPjQt5PJtWdiNppZx'},
#      'href': 'https://api.spotify.com/v1/tracks/6qYGUxPjQt5PJtWdiNppZx',
#      'id': '6qYGUxPjQt5PJtWdiNppZx',
#      'type': 'track',
#      'uri': 'spotify:track:6qYGUxPjQt5PJtWdiNppZx'},
#     'name': 'So What',
#     'popularity': 77,
#     'preview_url': 'https://p.scdn.co/mp3-preview/128669ff038e13b680277a3dd1913f766a0c1cb5?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:0JiY190vktuhSGN6aqJdrt'},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2016-07-05T18:39:31Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#     'href': 'https://api.spotify.com/v1/users/1130225252',
#     'id': '1130225252',
#     'type': 'user',
#     'uri': 'spotify:user:1130225252'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#        'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#        'id': '0EmeFodog0BfCgMzAIvKQp',
#        'name': 'Shakira',
#        'type': 'artist',
#        'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4DyMK9x2gnmRkRa16zHaEV'},
#      'href': 'https://api.spotify.com/v1/albums/4DyMK9x2gnmRkRa16zHaEV',
#      'id': '4DyMK9x2gnmRkRa16zHaEV',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731f400a1f4d821b00824cf58f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021f400a1f4d821b00824cf58f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511f400a1f4d821b00824cf58f',
#        'width': 64}],
#      'name': 'Laundry Service',
#      'release_date': '2001-11-13',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:4DyMK9x2gnmRkRa16zHaEV'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#     'disc_number': 1,
#     'duration_ms': 196160,
#     'episode': False,
#     'explicit': False,
#     'external_ids': {'isrc': 'NLB630100324'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2lnzGkdtDj5mtlcOW2yRtG'},
#     'href': 'https://api.spotify.com/v1/tracks/2lnzGkdtDj5mtlcOW2yRtG',
#     'id': '2lnzGkdtDj5mtlcOW2yRtG',
#     'is_local': False,
#     'is_playable': True,
#     'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0RJWhctsc1G1Hg3Ov2th7x'},
#      'href': 'https://api.spotify.com/v1/tracks/0RJWhctsc1G1Hg3Ov2th7x',
#      'id': '0RJWhctsc1G1Hg3Ov2th7x',
#      'type': 'track',
#      'uri': 'spotify:track:0RJWhctsc1G1Hg3Ov2th7x'},
#     'name': 'Whenever, Wherever',
#     'popularity': 76,
#     'preview_url': 'https://p.scdn.co/mp3-preview/a19675c31730744dc816dbf4e5ded615be1d740d?cid=27528ddd860a4c138498069634e5f2de',
#     'track': True,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:2lnzGkdtDj5mtlcOW2yRtG'},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/4rnleEAOdmFAbRcNCgZMpY/tracks?offset=100&limit=100&market=GB&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 5295}

# %%
print(list(playlist.keys())) # Let's look at items and total:
print("Total number of songs in the playlist: ",playlist["total"]) #  Let's check items:
len(playlist["items"]) # It is limited to 100 tracks, we will have to fix it:
# Out:
# ['href', 'items', 'limit', 'next', 'offset', 'previous', 'total']
# Total number of songs in the playlist:  5295
# 100

# %% [markdown]
# ## Extracting the songs of a playlist

# %% [markdown]
# Pagination using "next"
# When you collect songs from a playlist using sp.playlist_tracks, you're limited by the limit parameter, which has a maximum (and default) value of 100. When the playlist has more than 100 songs, you have to collect them by navigating through the "pages" of the results.
#
# The parameter offset allows you to retrieve resuls starting at a certain position: if you start at position 101, you'd get the next "page" of results. An offset of 201 would give you the third page, and so on.
#
# The function sp.next() does the same, but in a simpler way: it can be used on the results from any request to directly retrieve the results for the next page.
#
# We can check whether there's a next page or not by accessing the key next on the results from any request.

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
get_playlist_tracks("spotify", "4rnleEAOdmFAbRcNCgZMpY")
# Out:
# [{'added_at': '2017-06-09T17:34:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#       'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#       'id': '2FXC3k01G6Gw61bmprjgqS',
#       'name': 'Hozier',
#       'type': 'artist',
#       'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Uv83rRhY5QvHKkQoULRKk'},
#     'href': 'https://api.spotify.com/v1/albums/0Uv83rRhY5QvHKkQoULRKk',
#     'id': '0Uv83rRhY5QvHKkQoULRKk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737a9bf5f82e32d33d4503fe7b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027a9bf5f82e32d33d4503fe7b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517a9bf5f82e32d33d4503fe7b',
#       'width': 64}],
#     'name': 'Hozier',
#     'release_date': '2014-07-20',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0Uv83rRhY5QvHKkQoULRKk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2FXC3k01G6Gw61bmprjgqS'},
#      'href': 'https://api.spotify.com/v1/artists/2FXC3k01G6Gw61bmprjgqS',
#      'id': '2FXC3k01G6Gw61bmprjgqS',
#      'name': 'Hozier',
#      'type': 'artist',
#      'uri': 'spotify:artist:2FXC3k01G6Gw61bmprjgqS'}],
#    'disc_number': 1,
#    'duration_ms': 241688,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'IEACJ1300031'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3dYD57lRAUcMHufyqn9GcI'},
#    'href': 'https://api.spotify.com/v1/tracks/3dYD57lRAUcMHufyqn9GcI',
#    'id': '3dYD57lRAUcMHufyqn9GcI',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/7dS5EaCoMnN7DzlpT6aRn2'},
#     'href': 'https://api.spotify.com/v1/tracks/7dS5EaCoMnN7DzlpT6aRn2',
#     'id': '7dS5EaCoMnN7DzlpT6aRn2',
#     'type': 'track',
#     'uri': 'spotify:track:7dS5EaCoMnN7DzlpT6aRn2'},
#    'name': 'Take Me To Church',
#    'popularity': 83,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3dYD57lRAUcMHufyqn9GcI'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2017-06-29T20:42:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#       'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#       'id': '2KsP6tYLJlTBvSUxnwlVWa',
#       'name': 'Mike Posner',
#       'type': 'artist',
#       'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2nnIlWcriIqcJtjduWcTRl'},
#     'href': 'https://api.spotify.com/v1/albums/2nnIlWcriIqcJtjduWcTRl',
#     'id': '2nnIlWcriIqcJtjduWcTRl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d6165c0d6eba7e5bf3fca16d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d6165c0d6eba7e5bf3fca16d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d6165c0d6eba7e5bf3fca16d',
#       'width': 64}],
#     'name': '31 Minutes to Takeoff',
#     'release_date': '2010-08-09',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:2nnIlWcriIqcJtjduWcTRl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2KsP6tYLJlTBvSUxnwlVWa'},
#      'href': 'https://api.spotify.com/v1/artists/2KsP6tYLJlTBvSUxnwlVWa',
#      'id': '2KsP6tYLJlTBvSUxnwlVWa',
#      'name': 'Mike Posner',
#      'type': 'artist',
#      'uri': 'spotify:artist:2KsP6tYLJlTBvSUxnwlVWa'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5RIimuW7xG7et3aQX1idHV'},
#      'href': 'https://api.spotify.com/v1/artists/5RIimuW7xG7et3aQX1idHV',
#      'id': '5RIimuW7xG7et3aQX1idHV',
#      'name': 'Matt Masurka',
#      'type': 'artist',
#      'uri': 'spotify:artist:5RIimuW7xG7et3aQX1idHV'}],
#    'disc_number': 1,
#    'duration_ms': 213293,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJAY1000035'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2V4bv1fNWfTcyRJKmej6Sj'},
#    'href': 'https://api.spotify.com/v1/tracks/2V4bv1fNWfTcyRJKmej6Sj',
#    'id': '2V4bv1fNWfTcyRJKmej6Sj',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cooler Than Me - Single Mix',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/bf16e71252fdb6ef6e9306630d1606d6c44ef742?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2V4bv1fNWfTcyRJKmej6Sj'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2018-07-19T15:34:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#       'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#       'id': '4V8LLVI7PbaPR0K2TGSxFF',
#       'name': 'Tyler, The Creator',
#       'type': 'artist',
#       'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2nkto6YNI4rUYTLqEwWJ3o'},
#     'href': 'https://api.spotify.com/v1/albums/2nkto6YNI4rUYTLqEwWJ3o',
#     'id': '2nkto6YNI4rUYTLqEwWJ3o',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738940ac99f49e44f59e6f7fb3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028940ac99f49e44f59e6f7fb3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518940ac99f49e44f59e6f7fb3',
#       'width': 64}],
#     'name': 'Flower Boy',
#     'release_date': '2017-07-21',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:2nkto6YNI4rUYTLqEwWJ3o'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4V8LLVI7PbaPR0K2TGSxFF'},
#      'href': 'https://api.spotify.com/v1/artists/4V8LLVI7PbaPR0K2TGSxFF',
#      'id': '4V8LLVI7PbaPR0K2TGSxFF',
#      'name': 'Tyler, The Creator',
#      'type': 'artist',
#      'uri': 'spotify:artist:4V8LLVI7PbaPR0K2TGSxFF'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1U1el3k54VvEUzo3ybLPlM'},
#      'href': 'https://api.spotify.com/v1/artists/1U1el3k54VvEUzo3ybLPlM',
#      'id': '1U1el3k54VvEUzo3ybLPlM',
#      'name': 'Kali Uchis',
#      'type': 'artist',
#      'uri': 'spotify:artist:1U1el3k54VvEUzo3ybLPlM'}],
#    'disc_number': 1,
#    'duration_ms': 180386,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USQX91701275'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7KA4W4McWYRpgf0fWsJZWB'},
#    'href': 'https://api.spotify.com/v1/tracks/7KA4W4McWYRpgf0fWsJZWB',
#    'id': '7KA4W4McWYRpgf0fWsJZWB',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'See You Again (feat. Kali Uchis)',
#    'popularity': 85,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e6c4c9656721fe0a042b61be26adbb57c7032a73?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7KA4W4McWYRpgf0fWsJZWB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:32:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EQ0qTo7fWT7DPxmxtSYEc'},
#       'href': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc',
#       'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#       'name': 'Bastille',
#       'type': 'artist',
#       'uri': 'spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5G6oMu9zNW2acdV0lqzI3L'},
#     'href': 'https://api.spotify.com/v1/albums/5G6oMu9zNW2acdV0lqzI3L',
#     'id': '5G6oMu9zNW2acdV0lqzI3L',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273faee7306ec2f36aeccc4bc98',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02faee7306ec2f36aeccc4bc98',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851faee7306ec2f36aeccc4bc98',
#       'width': 64}],
#     'name': 'All This Bad Blood',
#     'release_date': '2013-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 25,
#     'type': 'album',
#     'uri': 'spotify:album:5G6oMu9zNW2acdV0lqzI3L'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7EQ0qTo7fWT7DPxmxtSYEc'},
#      'href': 'https://api.spotify.com/v1/artists/7EQ0qTo7fWT7DPxmxtSYEc',
#      'id': '7EQ0qTo7fWT7DPxmxtSYEc',
#      'name': 'Bastille',
#      'type': 'artist',
#      'uri': 'spotify:artist:7EQ0qTo7fWT7DPxmxtSYEc'}],
#    'disc_number': 1,
#    'duration_ms': 214147,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBAAA1200795'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4Ub8UsjWuewQrPhuepfVpd'},
#    'href': 'https://api.spotify.com/v1/tracks/4Ub8UsjWuewQrPhuepfVpd',
#    'id': '4Ub8UsjWuewQrPhuepfVpd',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/3gbBpTdY8lnQwqxNCcf795'},
#     'href': 'https://api.spotify.com/v1/tracks/3gbBpTdY8lnQwqxNCcf795',
#     'id': '3gbBpTdY8lnQwqxNCcf795',
#     'type': 'track',
#     'uri': 'spotify:track:3gbBpTdY8lnQwqxNCcf795'},
#    'name': 'Pompeii',
#    'popularity': 75,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:4Ub8UsjWuewQrPhuepfVpd'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:39:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#       'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#       'id': '0EmeFodog0BfCgMzAIvKQp',
#       'name': 'Shakira',
#       'type': 'artist',
#       'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ppnlEoj4HdRRdRihnY3jU'},
#     'href': 'https://api.spotify.com/v1/albums/5ppnlEoj4HdRRdRihnY3jU',
#     'id': '5ppnlEoj4HdRRdRihnY3jU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27327ddd747545c0d0cfe7595fa',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0227ddd747545c0d0cfe7595fa',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485127ddd747545c0d0cfe7595fa',
#       'width': 64}],
#     'name': 'Oral Fixation, Vol. 2 (Expanded Edition)',
#     'release_date': '2005-11-28',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:5ppnlEoj4HdRRdRihnY3jU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0EmeFodog0BfCgMzAIvKQp'},
#      'href': 'https://api.spotify.com/v1/artists/0EmeFodog0BfCgMzAIvKQp',
#      'id': '0EmeFodog0BfCgMzAIvKQp',
#      'name': 'Shakira',
#      'type': 'artist',
#      'uri': 'spotify:artist:0EmeFodog0BfCgMzAIvKQp'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aBzpmFXB4WWpPl2F7RjBe'},
#      'href': 'https://api.spotify.com/v1/artists/7aBzpmFXB4WWpPl2F7RjBe',
#      'id': '7aBzpmFXB4WWpPl2F7RjBe',
#      'name': 'Wyclef Jean',
#      'type': 'artist',
#      'uri': 'spotify:artist:7aBzpmFXB4WWpPl2F7RjBe'}],
#    'disc_number': 1,
#    'duration_ms': 218093,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10600677'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3ZFTkvIE7kyPt6Nu3PEa7V'},
#    'href': 'https://api.spotify.com/v1/tracks/3ZFTkvIE7kyPt6Nu3PEa7V',
#    'id': '3ZFTkvIE7kyPt6Nu3PEa7V',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Hips Don't Lie (feat. Wyclef Jean)",
#    'popularity': 85,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5e6f328ae98e7665cb40b4580773ea0107c5631f?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3ZFTkvIE7kyPt6Nu3PEa7V'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:31:49Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#       'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#       'id': '3AQRLZ9PuTAozP28Skbq8V',
#       'name': 'The Script',
#       'type': 'artist',
#       'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7JOCOjZTcLysDMkZGWlcIj'},
#     'href': 'https://api.spotify.com/v1/albums/7JOCOjZTcLysDMkZGWlcIj',
#     'id': '7JOCOjZTcLysDMkZGWlcIj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732e3049fef96abebf336b7366',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022e3049fef96abebf336b7366',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512e3049fef96abebf336b7366',
#       'width': 64}],
#     'name': '#3 Deluxe Version',
#     'release_date': '2012-09-10',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:7JOCOjZTcLysDMkZGWlcIj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3AQRLZ9PuTAozP28Skbq8V'},
#      'href': 'https://api.spotify.com/v1/artists/3AQRLZ9PuTAozP28Skbq8V',
#      'id': '3AQRLZ9PuTAozP28Skbq8V',
#      'name': 'The Script',
#      'type': 'artist',
#      'uri': 'spotify:artist:3AQRLZ9PuTAozP28Skbq8V'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/085pc2PYOi8bGKj0PNjekA'},
#      'href': 'https://api.spotify.com/v1/artists/085pc2PYOi8bGKj0PNjekA',
#      'id': '085pc2PYOi8bGKj0PNjekA',
#      'name': 'will.i.am',
#      'type': 'artist',
#      'uri': 'spotify:artist:085pc2PYOi8bGKj0PNjekA'}],
#    'disc_number': 1,
#    'duration_ms': 202533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBARL1201055'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7wMq5n8mYSKlQIGECKUgTX'},
#    'href': 'https://api.spotify.com/v1/tracks/7wMq5n8mYSKlQIGECKUgTX',
#    'id': '7wMq5n8mYSKlQIGECKUgTX',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Hall of Fame (feat. will.i.am)',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a887360f6897298991dd402161835e86480fd9c5?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:7wMq5n8mYSKlQIGECKUgTX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:31:59Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fahUm8t5c0GIdeTq0ZaG8'},
#       'href': 'https://api.spotify.com/v1/artists/5fahUm8t5c0GIdeTq0ZaG8',
#       'id': '5fahUm8t5c0GIdeTq0ZaG8',
#       'name': 'Otto Knows',
#       'type': 'artist',
#       'uri': 'spotify:artist:5fahUm8t5c0GIdeTq0ZaG8'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6c4fND91gsKojyp3Mox97y'},
#     'href': 'https://api.spotify.com/v1/albums/6c4fND91gsKojyp3Mox97y',
#     'id': '6c4fND91gsKojyp3Mox97y',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e86879dff1cf1476698d05c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e86879dff1cf1476698d05c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e86879dff1cf1476698d05c7',
#       'width': 64}],
#     'name': 'Back Where I Belong (feat. Avicii)',
#     'release_date': '2016-06-03',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:6c4fND91gsKojyp3Mox97y'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5fahUm8t5c0GIdeTq0ZaG8'},
#      'href': 'https://api.spotify.com/v1/artists/5fahUm8t5c0GIdeTq0ZaG8',
#      'id': '5fahUm8t5c0GIdeTq0ZaG8',
#      'name': 'Otto Knows',
#      'type': 'artist',
#      'uri': 'spotify:artist:5fahUm8t5c0GIdeTq0ZaG8'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/1vCWHaC5f2uS3yhpwWbIA6'},
#      'href': 'https://api.spotify.com/v1/artists/1vCWHaC5f2uS3yhpwWbIA6',
#      'id': '1vCWHaC5f2uS3yhpwWbIA6',
#      'name': 'Avicii',
#      'type': 'artist',
#      'uri': 'spotify:artist:1vCWHaC5f2uS3yhpwWbIA6'}],
#    'disc_number': 1,
#    'duration_ms': 174202,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'SE4OX1600112'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/78W8wiUIlQ2SnWY9TVowKZ'},
#    'href': 'https://api.spotify.com/v1/tracks/78W8wiUIlQ2SnWY9TVowKZ',
#    'id': '78W8wiUIlQ2SnWY9TVowKZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Back Where I Belong (feat. Avicii)',
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5edcfcbef8bfa1a1b4b0b0b40b2ad6a7308e8667?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:78W8wiUIlQ2SnWY9TVowKZ'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:33:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#       'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#       'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#       'name': 'Selena Gomez',
#       'type': 'artist',
#       'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2iFTxCYwhF5oC1L8s1B0rI'},
#     'href': 'https://api.spotify.com/v1/albums/2iFTxCYwhF5oC1L8s1B0rI',
#     'id': '2iFTxCYwhF5oC1L8s1B0rI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273f7dd2cadacebfe2d3c5d96be',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02f7dd2cadacebfe2d3c5d96be',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851f7dd2cadacebfe2d3c5d96be',
#       'width': 64}],
#     'name': 'The Heart Wants What It Wants',
#     'release_date': '2014-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:2iFTxCYwhF5oC1L8s1B0rI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0C8ZW7ezQVs4URX5aX7Kqx'},
#      'href': 'https://api.spotify.com/v1/artists/0C8ZW7ezQVs4URX5aX7Kqx',
#      'id': '0C8ZW7ezQVs4URX5aX7Kqx',
#      'name': 'Selena Gomez',
#      'type': 'artist',
#      'uri': 'spotify:artist:0C8ZW7ezQVs4URX5aX7Kqx'}],
#    'disc_number': 1,
#    'duration_ms': 227373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHR11435979'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6wJwkMo278iWVlWl1XQ4WA'},
#    'href': 'https://api.spotify.com/v1/tracks/6wJwkMo278iWVlWl1XQ4WA',
#    'id': '6wJwkMo278iWVlWl1XQ4WA',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2jcPoPin36hyNRSi4ZsqeB'},
#     'href': 'https://api.spotify.com/v1/tracks/2jcPoPin36hyNRSi4ZsqeB',
#     'id': '2jcPoPin36hyNRSi4ZsqeB',
#     'type': 'track',
#     'uri': 'spotify:track:2jcPoPin36hyNRSi4ZsqeB'},
#    'name': 'The Heart Wants What It Wants',
#    'popularity': 68,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6wJwkMo278iWVlWl1XQ4WA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#       'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#       'id': '6MF9fzBmfXghAz953czmBC',
#       'name': 'Taio Cruz',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0eGvq1J5Ke7VlLLOYIlY4k'},
#     'href': 'https://api.spotify.com/v1/albums/0eGvq1J5Ke7VlLLOYIlY4k',
#     'id': '0eGvq1J5Ke7VlLLOYIlY4k',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27366c3eb32692a0ae487079cf1',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0266c3eb32692a0ae487079cf1',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485166c3eb32692a0ae487079cf1',
#       'width': 64}],
#     'name': 'The Rokstarr Hits Collection',
#     'release_date': '2010-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:0eGvq1J5Ke7VlLLOYIlY4k'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MF9fzBmfXghAz953czmBC'},
#      'href': 'https://api.spotify.com/v1/artists/6MF9fzBmfXghAz953czmBC',
#      'id': '6MF9fzBmfXghAz953czmBC',
#      'name': 'Taio Cruz',
#      'type': 'artist',
#      'uri': 'spotify:artist:6MF9fzBmfXghAz953czmBC'}],
#    'disc_number': 1,
#    'duration_ms': 202613,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71003721'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2CEgGE6aESpnmtfiZwYlbV'},
#    'href': 'https://api.spotify.com/v1/tracks/2CEgGE6aESpnmtfiZwYlbV',
#    'id': '2CEgGE6aESpnmtfiZwYlbV',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Dynamite',
#    'popularity': 81,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2CEgGE6aESpnmtfiZwYlbV'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:29Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#       'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#       'id': '37GUqxafAvAKGMZbXCUnmr',
#       'name': 'Mohombi',
#       'type': 'artist',
#       'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0TFxOkFYPrhIzzrKv5CWZf'},
#     'href': 'https://api.spotify.com/v1/albums/0TFxOkFYPrhIzzrKv5CWZf',
#     'id': '0TFxOkFYPrhIzzrKv5CWZf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733cfcf82ef4d0685f4e4e95a5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023cfcf82ef4d0685f4e4e95a5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513cfcf82ef4d0685f4e4e95a5',
#       'width': 64}],
#     'name': 'MoveMeant (International)',
#     'release_date': '2010-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0TFxOkFYPrhIzzrKv5CWZf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#      'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#      'id': '37GUqxafAvAKGMZbXCUnmr',
#      'name': 'Mohombi',
#      'type': 'artist',
#      'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#    'disc_number': 1,
#    'duration_ms': 224720,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71024652'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/71R6zJsrF3ffc3TBFHfivX'},
#    'href': 'https://api.spotify.com/v1/tracks/71R6zJsrF3ffc3TBFHfivX',
#    'id': '71R6zJsrF3ffc3TBFHfivX',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0tBRo4P60DgKmg4jt48upm'},
#     'href': 'https://api.spotify.com/v1/tracks/0tBRo4P60DgKmg4jt48upm',
#     'id': '0tBRo4P60DgKmg4jt48upm',
#     'type': 'track',
#     'uri': 'spotify:track:0tBRo4P60DgKmg4jt48upm'},
#    'name': 'Bumpy Ride',
#    'popularity': 73,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:71R6zJsrF3ffc3TBFHfivX'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'},
#       'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E',
#       'id': '5bv5RplEOwdCvhq0EILh9E',
#       'name': 'Lucenzo',
#       'type': 'artist',
#       'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1eoYupgvxWRBT6nHnAHjEQ'},
#     'href': 'https://api.spotify.com/v1/albums/1eoYupgvxWRBT6nHnAHjEQ',
#     'id': '1eoYupgvxWRBT6nHnAHjEQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dd6b19d30e8b2531c625fbc4',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dd6b19d30e8b2531c625fbc4',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dd6b19d30e8b2531c625fbc4',
#       'width': 64}],
#     'name': 'Emigrante Del Mundo (Remastered)',
#     'release_date': '2011-12-19',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:1eoYupgvxWRBT6nHnAHjEQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5bv5RplEOwdCvhq0EILh9E'},
#      'href': 'https://api.spotify.com/v1/artists/5bv5RplEOwdCvhq0EILh9E',
#      'id': '5bv5RplEOwdCvhq0EILh9E',
#      'name': 'Lucenzo',
#      'type': 'artist',
#      'uri': 'spotify:artist:5bv5RplEOwdCvhq0EILh9E'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4LqXqd68BBoEk9RDYeS0ls'},
#      'href': 'https://api.spotify.com/v1/artists/4LqXqd68BBoEk9RDYeS0ls',
#      'id': '4LqXqd68BBoEk9RDYeS0ls',
#      'name': 'Big Ali',
#      'type': 'artist',
#      'uri': 'spotify:artist:4LqXqd68BBoEk9RDYeS0ls'}],
#    'disc_number': 1,
#    'duration_ms': 199235,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FR43Y1000010'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ku3i5WNrsY3qhOq6ua9TL'},
#    'href': 'https://api.spotify.com/v1/tracks/6ku3i5WNrsY3qhOq6ua9TL',
#    'id': '6ku3i5WNrsY3qhOq6ua9TL',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/1kAZhbcsXqfUjnVeqPywn2'},
#     'href': 'https://api.spotify.com/v1/tracks/1kAZhbcsXqfUjnVeqPywn2',
#     'id': '1kAZhbcsXqfUjnVeqPywn2',
#     'type': 'track',
#     'uri': 'spotify:track:1kAZhbcsXqfUjnVeqPywn2'},
#    'name': 'Vem Dancar Kuduro',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:6ku3i5WNrsY3qhOq6ua9TL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZZqIQ25HQmufjjf2trwFO'},
#       'href': 'https://api.spotify.com/v1/artists/5ZZqIQ25HQmufjjf2trwFO',
#       'id': '5ZZqIQ25HQmufjjf2trwFO',
#       'name': 'Cheek',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZZqIQ25HQmufjjf2trwFO'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3Y6qK0mEmyeXHs3DJOGGYO'},
#     'href': 'https://api.spotify.com/v1/albums/3Y6qK0mEmyeXHs3DJOGGYO',
#     'id': '3Y6qK0mEmyeXHs3DJOGGYO',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27361f43967534f6d07251909ec',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0261f43967534f6d07251909ec',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485161f43967534f6d07251909ec',
#       'width': 64}],
#     'name': 'Sokka irti',
#     'release_date': '2012-04-04',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:3Y6qK0mEmyeXHs3DJOGGYO'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZZqIQ25HQmufjjf2trwFO'},
#      'href': 'https://api.spotify.com/v1/artists/5ZZqIQ25HQmufjjf2trwFO',
#      'id': '5ZZqIQ25HQmufjjf2trwFO',
#      'name': 'Cheek',
#      'type': 'artist',
#      'uri': 'spotify:artist:5ZZqIQ25HQmufjjf2trwFO'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/5TZMaBvTPuICA1EQAWjKWZ'},
#      'href': 'https://api.spotify.com/v1/artists/5TZMaBvTPuICA1EQAWjKWZ',
#      'id': '5TZMaBvTPuICA1EQAWjKWZ',
#      'name': 'Yasmine Yamajako',
#      'type': 'artist',
#      'uri': 'spotify:artist:5TZMaBvTPuICA1EQAWjKWZ'}],
#    'disc_number': 1,
#    'duration_ms': 230413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FIWMA1200063'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2N2QvMYwyYHE8V4KZbbG4i'},
#    'href': 'https://api.spotify.com/v1/tracks/2N2QvMYwyYHE8V4KZbbG4i',
#    'id': '2N2QvMYwyYHE8V4KZbbG4i',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Syypää sun hymyyn (feat. Yasmine Yamajako)',
#    'popularity': 44,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b6b679b6753c040630918831976c472494ae6704?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:2N2QvMYwyYHE8V4KZbbG4i'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:38Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/355RqMyXhDoOD0l4qMUxeT'},
#     'href': 'https://api.spotify.com/v1/albums/355RqMyXhDoOD0l4qMUxeT',
#     'id': '355RqMyXhDoOD0l4qMUxeT',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738fff33d4cece7b62bda3a2a5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028fff33d4cece7b62bda3a2a5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518fff33d4cece7b62bda3a2a5',
#       'width': 64}],
#     'name': 'Whistle',
#     'release_date': '2012-04-24',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:355RqMyXhDoOD0l4qMUxeT'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#      'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#      'id': '0jnsk9HBra6NMjO2oANoPY',
#      'name': 'Flo Rida',
#      'type': 'artist',
#      'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#    'disc_number': 1,
#    'duration_ms': 225000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21201745'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0ltBH1JNzSvQJPjJpvTu9B'},
#    'href': 'https://api.spotify.com/v1/tracks/0ltBH1JNzSvQJPjJpvTu9B',
#    'id': '0ltBH1JNzSvQJPjJpvTu9B',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Whistle',
#    'popularity': 59,
#    'preview_url': 'https://p.scdn.co/mp3-preview/60271ca2deeb5d44b617aa9e05281f667c45f525?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:0ltBH1JNzSvQJPjJpvTu9B'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:41Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#       'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#       'id': '0p4nmQO2msCgU4IF37Wi3j',
#       'name': 'Avril Lavigne',
#       'type': 'artist',
#       'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6lqE05fiHWJVYYdMVJNj38'},
#     'href': 'https://api.spotify.com/v1/albums/6lqE05fiHWJVYYdMVJNj38',
#     'id': '6lqE05fiHWJVYYdMVJNj38',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273476cdf5837ae39eee951cc15',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02476cdf5837ae39eee951cc15',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851476cdf5837ae39eee951cc15',
#       'width': 64}],
#     'name': 'The Best Damn Thing (Expanded Edition)',
#     'release_date': '2007-04-17',
#     'release_date_precision': 'day',
#     'total_tracks': 17,
#     'type': 'album',
#     'uri': 'spotify:album:6lqE05fiHWJVYYdMVJNj38'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0p4nmQO2msCgU4IF37Wi3j'},
#      'href': 'https://api.spotify.com/v1/artists/0p4nmQO2msCgU4IF37Wi3j',
#      'id': '0p4nmQO2msCgU4IF37Wi3j',
#      'name': 'Avril Lavigne',
#      'type': 'artist',
#      'uri': 'spotify:artist:0p4nmQO2msCgU4IF37Wi3j'}],
#    'disc_number': 1,
#    'duration_ms': 216600,
#    'episode': False,
#    'explicit': True,
#    'external_ids': {'isrc': 'USRC10700021'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/45hOioMDJktr86iKDHC8gr'},
#    'href': 'https://api.spotify.com/v1/tracks/45hOioMDJktr86iKDHC8gr',
#    'id': '45hOioMDJktr86iKDHC8gr',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5HbCnVLXRyZVxnreOPgJCK'},
#     'href': 'https://api.spotify.com/v1/tracks/5HbCnVLXRyZVxnreOPgJCK',
#     'id': '5HbCnVLXRyZVxnreOPgJCK',
#     'type': 'track',
#     'uri': 'spotify:track:5HbCnVLXRyZVxnreOPgJCK'},
#    'name': 'Girlfriend',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a483f9955188f39637f4fd143ef47d47fbc55edf?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:45hOioMDJktr86iKDHC8gr'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:45Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3BmcYMh0KYsimWL6p2gPa9'},
#     'href': 'https://api.spotify.com/v1/albums/3BmcYMh0KYsimWL6p2gPa9',
#     'id': '3BmcYMh0KYsimWL6p2gPa9',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273629dc9e2e3bc20bbd7d92e4a',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02629dc9e2e3bc20bbd7d92e4a',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851629dc9e2e3bc20bbd7d92e4a',
#       'width': 64}],
#     'name': 'My World 2.0',
#     'release_date': '2010-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3BmcYMh0KYsimWL6p2gPa9'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#      'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#      'id': '1uNFoZAHBGtllmzznpCI3s',
#      'name': 'Justin Bieber',
#      'type': 'artist',
#      'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3ipn9JLAPI5GUEo4y4jcoi'},
#      'href': 'https://api.spotify.com/v1/artists/3ipn9JLAPI5GUEo4y4jcoi',
#      'id': '3ipn9JLAPI5GUEo4y4jcoi',
#      'name': 'Ludacris',
#      'type': 'artist',
#      'uri': 'spotify:artist:3ipn9JLAPI5GUEo4y4jcoi'}],
#    'disc_number': 1,
#    'duration_ms': 214240,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70919263'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6epn3r7S14KUqlReYr77hA'},
#    'href': 'https://api.spotify.com/v1/tracks/6epn3r7S14KUqlReYr77hA',
#    'id': '6epn3r7S14KUqlReYr77hA',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4NFhtFE68cXUrfbne8JE2c'},
#     'href': 'https://api.spotify.com/v1/tracks/4NFhtFE68cXUrfbne8JE2c',
#     'id': '4NFhtFE68cXUrfbne8JE2c',
#     'type': 'track',
#     'uri': 'spotify:track:4NFhtFE68cXUrfbne8JE2c'},
#    'name': 'Baby',
#    'popularity': 82,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6epn3r7S14KUqlReYr77hA'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:47Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#       'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#       'id': '0jnsk9HBra6NMjO2oANoPY',
#       'name': 'Flo Rida',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0aGzTOetC7VdotwXeWLenJ'},
#     'href': 'https://api.spotify.com/v1/albums/0aGzTOetC7VdotwXeWLenJ',
#     'id': '0aGzTOetC7VdotwXeWLenJ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ea73afbe3f6fe4afb15fccdc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ea73afbe3f6fe4afb15fccdc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ea73afbe3f6fe4afb15fccdc',
#       'width': 64}],
#     'name': 'Wild Ones (Deluxe)',
#     'release_date': '2012-06-22',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:0aGzTOetC7VdotwXeWLenJ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0jnsk9HBra6NMjO2oANoPY'},
#      'href': 'https://api.spotify.com/v1/artists/0jnsk9HBra6NMjO2oANoPY',
#      'id': '0jnsk9HBra6NMjO2oANoPY',
#      'name': 'Flo Rida',
#      'type': 'artist',
#      'uri': 'spotify:artist:0jnsk9HBra6NMjO2oANoPY'}],
#    'disc_number': 1,
#    'duration_ms': 223800,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAT21202584'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5HE3z4Ew7wZ91l3ZOpGKa4'},
#    'href': 'https://api.spotify.com/v1/tracks/5HE3z4Ew7wZ91l3ZOpGKa4',
#    'id': '5HE3z4Ew7wZ91l3ZOpGKa4',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Cry',
#    'popularity': 32,
#    'preview_url': 'https://p.scdn.co/mp3-preview/60843f82dda9ccf24caa1cc22a2e2e20a92c5e81?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:5HE3z4Ew7wZ91l3ZOpGKa4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:50Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#       'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#       'id': '37GUqxafAvAKGMZbXCUnmr',
#       'name': 'Mohombi',
#       'type': 'artist',
#       'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0TFxOkFYPrhIzzrKv5CWZf'},
#     'href': 'https://api.spotify.com/v1/albums/0TFxOkFYPrhIzzrKv5CWZf',
#     'id': '0TFxOkFYPrhIzzrKv5CWZf',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2733cfcf82ef4d0685f4e4e95a5',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e023cfcf82ef4d0685f4e4e95a5',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048513cfcf82ef4d0685f4e4e95a5',
#       'width': 64}],
#     'name': 'MoveMeant (International)',
#     'release_date': '2010-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:0TFxOkFYPrhIzzrKv5CWZf'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/37GUqxafAvAKGMZbXCUnmr'},
#      'href': 'https://api.spotify.com/v1/artists/37GUqxafAvAKGMZbXCUnmr',
#      'id': '37GUqxafAvAKGMZbXCUnmr',
#      'name': 'Mohombi',
#      'type': 'artist',
#      'uri': 'spotify:artist:37GUqxafAvAKGMZbXCUnmr'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/40xbWSB4JPdOkRyuTDy1oP'},
#      'href': 'https://api.spotify.com/v1/artists/40xbWSB4JPdOkRyuTDy1oP',
#      'id': '40xbWSB4JPdOkRyuTDy1oP',
#      'name': 'Nicole Scherzinger',
#      'type': 'artist',
#      'uri': 'spotify:artist:40xbWSB4JPdOkRyuTDy1oP'}],
#    'disc_number': 1,
#    'duration_ms': 218373,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBUM71027585'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1j7GNdjuK5wfmvxCbVcWMY'},
#    'href': 'https://api.spotify.com/v1/tracks/1j7GNdjuK5wfmvxCbVcWMY',
#    'id': '1j7GNdjuK5wfmvxCbVcWMY',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5L9THbmMKB6ZlHlMgzaXHf'},
#     'href': 'https://api.spotify.com/v1/tracks/5L9THbmMKB6ZlHlMgzaXHf',
#     'id': '5L9THbmMKB6ZlHlMgzaXHf',
#     'type': 'track',
#     'uri': 'spotify:track:5L9THbmMKB6ZlHlMgzaXHf'},
#    'name': 'Coconut Tree',
#    'popularity': 56,
#    'preview_url': None,
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:1j7GNdjuK5wfmvxCbVcWMY'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-07-05T18:34:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#       'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#       'id': '1uNFoZAHBGtllmzznpCI3s',
#       'name': 'Justin Bieber',
#       'type': 'artist',
#       'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1rG5TDs3jYh6OU753I54CI'},
#     'href': 'https://api.spotify.com/v1/albums/1rG5TDs3jYh6OU753I54CI',
#     'id': '1rG5TDs3jYh6OU753I54CI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737c3bb9f74a98f60bdda6c9a7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027c3bb9f74a98f60bdda6c9a7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517c3bb9f74a98f60bdda6c9a7',
#       'width': 64}],
#     'name': 'My World',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 7,
# ...
#    'disc_number': 1,
#    'duration_ms': 312986,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70845927'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0lqYRbRiGc5oiCUW51JH5s'},
#    'href': 'https://api.spotify.com/v1/tracks/0lqYRbRiGc5oiCUW51JH5s',
#    'id': '0lqYRbRiGc5oiCUW51JH5s',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/4rqR0yM2k41leqyErhNzTs'},
#     'href': 'https://api.spotify.com/v1/tracks/4rqR0yM2k41leqyErhNzTs',
#     'id': '4rqR0yM2k41leqyErhNzTs',
#     'type': 'track',
#     'uri': 'spotify:track:4rqR0yM2k41leqyErhNzTs'},
#    'name': 'Beautiful',
#    'popularity': 66,
#    'preview_url': None,
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:0lqYRbRiGc5oiCUW51JH5s'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-12-08T20:31:01Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KgHd8tKiKYsazNkydQgYM'},
#       'href': 'https://api.spotify.com/v1/artists/3KgHd8tKiKYsazNkydQgYM',
#       'id': '3KgHd8tKiKYsazNkydQgYM',
#       'name': 'Evelina',
#       'type': 'artist',
#       'uri': 'spotify:artist:3KgHd8tKiKYsazNkydQgYM'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1D9n5Ff8prsm56x9Oa9Udk'},
#     'href': 'https://api.spotify.com/v1/albums/1D9n5Ff8prsm56x9Oa9Udk',
#     'id': '1D9n5Ff8prsm56x9Oa9Udk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273153e0c1264428d50d070cd01',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02153e0c1264428d50d070cd01',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851153e0c1264428d50d070cd01',
#       'width': 64}],
#     'name': '24K',
#     'release_date': '2016-10-28',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:1D9n5Ff8prsm56x9Oa9Udk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3KgHd8tKiKYsazNkydQgYM'},
#      'href': 'https://api.spotify.com/v1/artists/3KgHd8tKiKYsazNkydQgYM',
#      'id': '3KgHd8tKiKYsazNkydQgYM',
#      'name': 'Evelina',
#      'type': 'artist',
#      'uri': 'spotify:artist:3KgHd8tKiKYsazNkydQgYM'}],
#    'disc_number': 1,
#    'duration_ms': 187664,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FIUM71601052'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6ItkmsAMKvcab9ikCN1TBW'},
#    'href': 'https://api.spotify.com/v1/tracks/6ItkmsAMKvcab9ikCN1TBW',
#    'id': '6ItkmsAMKvcab9ikCN1TBW',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ei Filtterii',
#    'popularity': 37,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:6ItkmsAMKvcab9ikCN1TBW'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-12-08T20:31:03Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g9yyIlJ0sIunQWJLmIYhn'},
#       'href': 'https://api.spotify.com/v1/artists/3g9yyIlJ0sIunQWJLmIYhn',
#       'id': '3g9yyIlJ0sIunQWJLmIYhn',
#       'name': 'Sound Of Legend',
#       'type': 'artist',
#       'uri': 'spotify:artist:3g9yyIlJ0sIunQWJLmIYhn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/44wxQAjbdbgIYffburDIZy'},
#     'href': 'https://api.spotify.com/v1/albums/44wxQAjbdbgIYffburDIZy',
#     'id': '44wxQAjbdbgIYffburDIZy',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736c756efbc68675229eb0036d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026c756efbc68675229eb0036d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516c756efbc68675229eb0036d',
#       'width': 64}],
#     'name': 'Blue (Da Ba Dee) [Sound of Legend Version Edit]',
#     'release_date': '2016-12-16',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:44wxQAjbdbgIYffburDIZy'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3g9yyIlJ0sIunQWJLmIYhn'},
#      'href': 'https://api.spotify.com/v1/artists/3g9yyIlJ0sIunQWJLmIYhn',
#      'id': '3g9yyIlJ0sIunQWJLmIYhn',
#      'name': 'Sound Of Legend',
#      'type': 'artist',
#      'uri': 'spotify:artist:3g9yyIlJ0sIunQWJLmIYhn'}],
#    'disc_number': 1,
#    'duration_ms': 179000,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FRPBS1600070'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3VPNH1HKLVFFJe7KxiG07e'},
#    'href': 'https://api.spotify.com/v1/tracks/3VPNH1HKLVFFJe7KxiG07e',
#    'id': '3VPNH1HKLVFFJe7KxiG07e',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/5jXypD1EKG2pwhtFNJfywj'},
#     'href': 'https://api.spotify.com/v1/tracks/5jXypD1EKG2pwhtFNJfywj',
#     'id': '5jXypD1EKG2pwhtFNJfywj',
#     'type': 'track',
#     'uri': 'spotify:track:5jXypD1EKG2pwhtFNJfywj'},
#    'name': 'Blue (Da Ba Dee) - Sound of Legend Version Edit',
#    'popularity': 31,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b1162a9271bea27ebc00096891c63003c5da176c?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3VPNH1HKLVFFJe7KxiG07e'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-12-08T20:31:26Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SLANaLk13zw9NaKeIS49U'},
#       'href': 'https://api.spotify.com/v1/artists/5SLANaLk13zw9NaKeIS49U',
#       'id': '5SLANaLk13zw9NaKeIS49U',
#       'name': 'Mon DJ',
#       'type': 'artist',
#       'uri': 'spotify:artist:5SLANaLk13zw9NaKeIS49U'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3X2UbcPnCKrl1XYkjWeUmx'},
#     'href': 'https://api.spotify.com/v1/albums/3X2UbcPnCKrl1XYkjWeUmx',
#     'id': '3X2UbcPnCKrl1XYkjWeUmx',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273138abadf90fa2f5bacaabbab',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02138abadf90fa2f5bacaabbab',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851138abadf90fa2f5bacaabbab',
#       'width': 64}],
#     'name': 'Sex (With My Ex)',
#     'release_date': '2013-10-04',
#     'release_date_precision': 'day',
#     'total_tracks': 2,
#     'type': 'album',
#     'uri': 'spotify:album:3X2UbcPnCKrl1XYkjWeUmx'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5SLANaLk13zw9NaKeIS49U'},
#      'href': 'https://api.spotify.com/v1/artists/5SLANaLk13zw9NaKeIS49U',
#      'id': '5SLANaLk13zw9NaKeIS49U',
#      'name': 'Mon DJ',
#      'type': 'artist',
#      'uri': 'spotify:artist:5SLANaLk13zw9NaKeIS49U'}],
#    'disc_number': 1,
#    'duration_ms': 184875,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'ES61A1357901'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2IOvpCME5BWATj3KT1WPSD'},
#    'href': 'https://api.spotify.com/v1/tracks/2IOvpCME5BWATj3KT1WPSD',
#    'id': '2IOvpCME5BWATj3KT1WPSD',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Sex (With My Ex) - Radio Edit',
#    'popularity': 37,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cb5877ba57ca7c6ece4c54593e5ad6546f4e479f?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2IOvpCME5BWATj3KT1WPSD'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-12-08T20:31:28Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1b81zU0IfjHE8krv2IZ0Hf'},
#       'href': 'https://api.spotify.com/v1/artists/1b81zU0IfjHE8krv2IZ0Hf',
#       'id': '1b81zU0IfjHE8krv2IZ0Hf',
#       'name': 'Captain Jack',
#       'type': 'artist',
#       'uri': 'spotify:artist:1b81zU0IfjHE8krv2IZ0Hf'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0hpZzIHtMqYBt6RDYnLLww'},
#     'href': 'https://api.spotify.com/v1/albums/0hpZzIHtMqYBt6RDYnLLww',
#     'id': '0hpZzIHtMqYBt6RDYnLLww',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a48317fd6371b05ce693efc2',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a48317fd6371b05ce693efc2',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a48317fd6371b05ce693efc2',
#       'width': 64}],
#     'name': 'Captain Jack',
#     'release_date': '1995-11-17',
#     'release_date_precision': 'day',
#     'total_tracks': 5,
#     'type': 'album',
#     'uri': 'spotify:album:0hpZzIHtMqYBt6RDYnLLww'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1b81zU0IfjHE8krv2IZ0Hf'},
#      'href': 'https://api.spotify.com/v1/artists/1b81zU0IfjHE8krv2IZ0Hf',
#      'id': '1b81zU0IfjHE8krv2IZ0Hf',
#      'name': 'Captain Jack',
#      'type': 'artist',
#      'uri': 'spotify:artist:1b81zU0IfjHE8krv2IZ0Hf'}],
#    'disc_number': 1,
#    'duration_ms': 248533,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'DED710506011'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/09uma8kvpf699ailOSlzds'},
#    'href': 'https://api.spotify.com/v1/tracks/09uma8kvpf699ailOSlzds',
#    'id': '09uma8kvpf699ailOSlzds',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Captain Jack - Short Mix',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1312c7628d08552450f914fd01085ade20d3a68d?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:09uma8kvpf699ailOSlzds'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-12-08T20:31:35Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Nc6H2qbH5SljekjNBTX7m'},
#       'href': 'https://api.spotify.com/v1/artists/1Nc6H2qbH5SljekjNBTX7m',
#       'id': '1Nc6H2qbH5SljekjNBTX7m',
#       'name': 'Indica',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Nc6H2qbH5SljekjNBTX7m'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3kFDZ18cm20qCVK05XxiXp'},
#     'href': 'https://api.spotify.com/v1/albums/3kFDZ18cm20qCVK05XxiXp',
#     'id': '3kFDZ18cm20qCVK05XxiXp',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273224c56d1050efc7094c70a1e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02224c56d1050efc7094c70a1e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851224c56d1050efc7094c70a1e',
#       'width': 64}],
#     'name': 'Ikuinen Virta',
#     'release_date': '2004-01-11',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3kFDZ18cm20qCVK05XxiXp'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Nc6H2qbH5SljekjNBTX7m'},
#      'href': 'https://api.spotify.com/v1/artists/1Nc6H2qbH5SljekjNBTX7m',
#      'id': '1Nc6H2qbH5SljekjNBTX7m',
#      'name': 'Indica',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Nc6H2qbH5SljekjNBTX7m'}],
#    'disc_number': 1,
#    'duration_ms': 255693,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FISMC0400039'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2N2vT7prULYdnOeqA0XBDy'},
#    'href': 'https://api.spotify.com/v1/tracks/2N2vT7prULYdnOeqA0XBDy',
#    'id': '2N2vT7prULYdnOeqA0XBDy',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ikuinen Virta',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c13792a3f414ced419743345b65686182b3bf54d?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2N2vT7prULYdnOeqA0XBDy'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2016-12-08T20:31:42Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1130225252'},
#    'href': 'https://api.spotify.com/v1/users/1130225252',
#    'id': '1130225252',
#    'type': 'user',
#    'uri': 'spotify:user:1130225252'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75HwtYoQin1Ofc40jTvVVq'},
#       'href': 'https://api.spotify.com/v1/artists/75HwtYoQin1Ofc40jTvVVq',
#       'id': '75HwtYoQin1Ofc40jTvVVq',
#       'name': 'duo',
#       'type': 'artist',
#       'uri': 'spotify:artist:75HwtYoQin1Ofc40jTvVVq'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3iQcR4eazZWfR0Nv271tuQ'},
#     'href': 'https://api.spotify.com/v1/albums/3iQcR4eazZWfR0Nv271tuQ',
#     'id': '3iQcR4eazZWfR0Nv271tuQ',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273ee1f66c06370af3d183e981d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02ee1f66c06370af3d183e981d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851ee1f66c06370af3d183e981d',
#       'width': 64}],
#     'name': 'Panisin',
#     'release_date': '2012-05-21',
#     'release_date_precision': 'day',
#     'total_tracks': 1,
#     'type': 'album',
#     'uri': 'spotify:album:3iQcR4eazZWfR0Nv271tuQ'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/75HwtYoQin1Ofc40jTvVVq'},
#      'href': 'https://api.spotify.com/v1/artists/75HwtYoQin1Ofc40jTvVVq',
#      'id': '75HwtYoQin1Ofc40jTvVVq',
#      'name': 'duo',
#      'type': 'artist',
#      'uri': 'spotify:artist:75HwtYoQin1Ofc40jTvVVq'}],
#    'disc_number': 1,
#    'duration_ms': 248626,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'FIWMA1200135'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6nw6HDH049R7j7JArouHn3'},
#    'href': 'https://api.spotify.com/v1/tracks/6nw6HDH049R7j7JArouHn3',
#    'id': '6nw6HDH049R7j7JArouHn3',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Panisin',
#    'popularity': 42,
#    'preview_url': 'https://p.scdn.co/mp3-preview/ce1e61958fd374e2ef79a863e779836799dc2fad?cid=27528ddd860a4c138498069634e5f2de',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6nw6HDH049R7j7JArouHn3'},
#   'video_thumbnail': {'url': None}},
#  ...]

# %% [markdown]
# ## Getting the artists of the playlist

# %%
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(set(artist for subset in [get_artists_from_track(track["track"]) for track in tracks_from_playlist] for artist in subset))

# %%
get_artists_from_playlist("4rnleEAOdmFAbRcNCgZMpY")
# Out:
# ['',
#  'Remy Ma',
#  'TobyMac',
#  'Labrinth',
#  'Marshmello',
#  'Rune RK',
#  'Dua Lipa',
#  'Rebourne',
#  'eetu',
#  'WTF!',
#  'Lil Jon',
#  'WIL',
#  'Lee Marrow',
#  'Sirah',
#  'Hussa',
#  'Russ',
#  'Jennifer Lopez',
#  'Alex Vargas',
#  'WALK THE MOON',
#  'Boombox Cartel',
#  'TRAQULA',
#  'DJ Martin ElectroSpin',
#  'Pete Parkkonen',
#  'Matoma',
#  'The Fray',
#  'Konsta Original',
#  'Ege Zulu',
#  'JORI SJÖROOS',
#  'American Authors',
#  'Contiez',
#  'Eric Prydz',
#  'Two Feet',
#  'Laura Närhi',
#  'Project.M',
#  'Eurythmics',
#  'DEM',
#  'Elias Kaskinen & Päivän Sankarit',
#  'Bobby Shmurda',
#  'Ed Sheeran',
#  'Vigiland',
#  'Karmin',
#  'Vaboh',
#  'Madison Beer',
#  'Descemer Bueno',
#  'Mikky Ekko',
#  'Sini Sabotage',
#  'SHY Martin',
#  'Skandaali',
#  'Sasha Alex Sloan',
#  'Temur',
#  'Quando Rondo',
#  'Space Cowboy',
#  'Landon Cube',
#  'Foster The People',
#  'YNW Melly',
#  'Kwabs',
#  'The Boyboy West Coast',
#  'Mahogany Lox',
#  'Tai Verdes',
#  'Trouble',
#  'Shenie Fogo',
#  'EDEN',
#  'Bethany Mota',
#  'PistePiste',
#  'Kristiina Brask',
#  'Ryos',
#  'salem ilese',
#  'Sharpay Evans',
#  'Jontte Valosaari',
#  'Anna Puu',
#  'CamelPhat',
#  'Sairas T',
#  'Maty Noyes',
#  'Fat Joe',
#  'Denzel Curry',
#  'Jorma Uotinen',
#  'PSY',
#  'Mariska',
#  'Faydee',
#  "Lil' Kim",
#  'Reino Nordin',
#  'Leevi and the leavings',
#  'Jonas Vogel',
#  'Duke Dumont',
#  'Alexandra Babitzin',
#  'DJ White Shadow',
#  'Hey Violet',
#  'Jadakiss',
#  'Jed Will',
#  'Death Grips',
#  'Mäkki',
#  'Avicii',
#  'Infinity',
#  'Lexxmatiq',
#  'Third Party',
#  'Yung Bae',
#  'Natalie La Rose',
#  'Chimamanda Ngozi Adichie',
#  'Haneri',
#  'Nathan Goshen',
#  'Jesse McCartney',
#  'DJ Fresh',
#  'Chad Kroeger',
#  'Kim Petras',
#  'Vinttikoira',
#  'PastoriPike',
#  'Ringnes-Ronny',
#  'LIOHN',
#  'Killua the Pilgrim',
#  'Ricky Montgomery',
#  'Sean Kingston',
#  'Lukas Leon',
#  'AJR',
#  'Noah Cyrus',
#  "Destiny's Child",
#  'Speernorman',
#  'Mr Hudson',
#  'Faul & Wad',
#  'Julma H',
#  'Leo Stannard',
#  'Jabba',
#  'Musta Barbaari',
#  'Jack Harlow',
#  'Jope Ruonansuu',
#  'Benji Reyes',
#  'Fall Out Boy',
#  'Solo Lucci',
#  'Frankie Knuckles',
#  'Popeda',
#  'Nicco',
#  'Alli Simpson',
#  'Bass Modulators',
#  'Arrhult',
#  'Majid Jordan',
#  'Eden Prince',
#  'Alphaville',
#  'Christoph Andersson',
#  'Taylor Swift',
#  'Foreigner',
#  'Migos',
#  'Conor Maynard',
#  'The Script',
#  'Omar Varela',
#  '112',
#  'dj 6rb',
#  'Kid Bloom',
#  'YOUNGHEARTED',
#  'Millie B',
#  'Danelle Sandoval',
#  'Jasmine Thompson',
#  'Larray',
#  'Bizzey',
#  'Ella Eyre',
#  'Stryker Pose',
#  'K-System',
#  'Jason Mraz',
#  'DJ Blyatman',
#  'Hkeem',
#  'Me & My',
#  'Marcus Schössow',
#  'Kaija Koo',
#  'Birdy',
#  'Las Ketchup',
#  'BlocBoy JB',
#  'David Guetta',
#  'ILARI',
#  'Thomas Doherty',
#  'S3RL',
#  'Matchbox Twenty',
#  'Ben Morfitt (SquidPhysics)',
#  'Hot Chelle Rae',
#  'Mike Taylor',
#  'Illi',
#  'J.I the Prince of N.Y',
#  'Jeff Kush',
#  'Lil Sage x JustSeAbu x MVD J€¥$ON',
#  'Annika Eklund',
#  'Emma Hewitt',
#  'LIFE',
#  'Surf Curse',
#  'Frank Ocean',
#  'Juju',
#  'Michael Schulte',
#  'Cledos',
#  'Tuure Boelius',
#  'LLusion',
#  'Lil Revive',
#  'Ayo & Teo',
#  'Oz Sparx',
#  'Heikki Kuula',
#  'Jeremih',
#  'DallasK',
#  'Wheatus',
#  'Princess Nokia',
#  'Chimbala',
#  'Indy & Karim',
#  'Kodak Black',
#  'Prince Royce',
#  'Boyat',
#  'VINAI',
#  'Fatman Scoop',
#  'Santana',
#  'Calboy',
#  'Vanessa Carlton',
#  'Loud Luxury',
#  'Solid Base',
#  'E-Rotic',
#  'LMFAO',
#  'China Anne McClain',
#  'Mikkel Øwre',
#  'Jason Derulo',
#  'KHEA',
#  'Michael Bublé',
#  'Dan Caplen',
#  'TOTO',
#  'Sharon',
#  'Aku Hirviniemi',
#  'Miranda Cosgrove',
#  'Bananarama',
#  'Far East Movement',
#  'Yade Lauren',
#  'Dzeko',
#  'Gente De Zona',
#  'Hayden James',
#  'Ryan Riback',
#  'Linkin Park',
#  'DJ Chose',
#  'Skee-Lo',
#  'Slim Mill',
#  'Plustwo',
#  'Florence Welch',
#  'FTampa',
#  'Juha Tapio',
#  'The Notorious B.I.G.',
#  'Daft Punk',
#  'Seekae',
#  'Bronski Beat',
#  'Coldplay',
#  'SZA',
#  'Pää-äijät',
#  'ILLENIUM',
#  'Gettomasa',
#  'El Cata',
#  '24hrs',
#  'Nightcore',
#  'Mac Miller',
#  'Ace of Base',
#  'Buddy',
#  'Ella Mai',
#  'Marja',
#  'Sak Noel',
#  'Juno',
#  'Ginuwine',
#  'Becky G',
#  'Sam Smith',
#  'Tyler, The Creator',
#  'Bobby Summer',
#  'Aste',
#  'Justin Mylo',
#  'Kauniit & Uhkarohkeat',
#  'Bryan Rice',
#  'Kris Kross Amsterdam',
#  'Lilli Paasikivi',
#  'Vaahteramäen Nege',
#  'Justimus',
#  'The Offspring',
#  'Anuel AA',
#  'Titta',
#  'Beats And Styles',
#  'Jani Wickholm',
#  'Classified',
#  'Heavyweight',
#  'Daya',
#  'Matisyahu',
#  'Munamies',
#  'LILMozart',
#  'Ida Paul',
#  'Scarlet',
#  'Dropgun',
#  'Dorrough Music',
#  'Aminé',
#  'Nopsajalka',
#  'Jem Cooke',
#  'U2',
#  'Kerli',
#  "Colby O'Donis",
#  'Setä Tamu',
#  'Andi',
#  'Nost3 & Protro',
#  'Wale',
#  'Meiju Suvas',
#  'Mark McCabe',
#  'Dingo',
#  'Miguel',
#  'Emily Warren',
#  'Disco Ensemble',
#  'Blaise',
#  'Pouya',
#  'Danny Saucedo',
#  'Vanilla Ice',
#  'Ella Lymi',
#  'Cher',
#  'Samu Haber',
#  'Ashley Tisdale',
#  'GoldLink',
#  'R.E.M.',
#  'Trisha Paytas',
#  'Timbaland',
#  'Ape Drums',
#  'Willy William',
#  'Yetmir',
#  'Tame Impala',
#  'Dayglow',
#  'D-wayne',
#  'Firebeatz',
#  'Günther',
#  'Todrick Hall',
#  'Eino Antiwäkki',
#  'LP',
#  'Wintertime',
#  'Clean Bandit',
#  'Pepe Willberg',
#  'Lilly Wood and The Prick',
#  'Michael Jackson',
#  'Murda Beatz',
#  'Thirty Seconds To Mars',
#  'Khlaw',
#  'Banx & Ranx',
#  'P-Lo',
#  'DCup',
#  'Spark Master Tape',
#  'Raaban',
#  'Ollie',
#  'Erakossa',
#  'Paramore',
#  'Eevil Stöö',
#  'dodie',
#  'Haddaway',
#  'Alexis Jordan',
#  'Mura Masa',
#  'Echosmith',
#  'ROZES',
#  'Petri Nygård',
#  'Normani',
#  'Quavo',
#  'Enrique Iglesias',
#  'Bow Wow',
#  'Frederik',
#  'Nelly Furtado',
#  'RAYE',
#  'Michael Constantino',
#  'Bonde R300',
#  'Charli XCX',
#  'Attom',
#  'Molly Brazy',
#  'Smino',
#  'Michael Andrews',
#  'Ruel',
#  'Pale Waves',
#  'Drake Bell',
#  'City Spud',
#  'Debra Reynolds',
#  'Take A Daytrip',
#  'Sir Mix-A-Lot',
#  'Brendon Urie',
#  'Baby Keem',
#  'MOGUAI',
#  'The Prince Karma',
#  'Carnage',
#  'Supergrass',
#  'AronChupa',
#  'Cody Simpson',
#  'Master Blaster',
#  'kai',
#  'Tango-Teemu',
#  'Mitchell Hope',
#  'Lady A',
#  'Aaro630',
#  'TIX',
#  'Naomi Wild',
#  'Of Monsters and Men',
#  'Lush & Simon',
#  '6ix9ine',
#  'Tina Turner',
#  'Tuomas Kauhanen',
#  'Big L',
#  'Sonique',
#  'The Game',
#  'Alok',
#  'Jare',
#  'Modern Talking',
#  'Dopebwoy',
#  'Taras',
#  'Kube',
#  'Soulja Boy',
#  'Bag Raiders',
#  'lovelytheband',
#  'Giorgio Tuinfort',
#  'Dirty Disco Youth',
#  'Lexi Jayde',
#  'Kash Doll',
#  'Bobby Helms',
#  'Costi',
#  'Ilsey',
#  'Veela',
#  '3 Doors Down',
#  'SINI YASEMIN',
#  'Kristal',
#  'gianni & kyle',
#  'Grouplove',
#  'Queen',
#  'Sibel',
#  'Lauren Bennett',
#  'J. Cole',
#  'Tiny Tim',
#  'Dash Berlin',
#  'YoungBoy Never Broke Again',
#  'Cardi B',
#  'Alec Benjamin',
#  'Chelsea Cutler',
#  'NCO',
#  'Paul McCartney',
#  'Mike Williams',
#  'Elton John',
#  'Jared Lee',
#  'Jayceeoh',
#  'Eric Nally',
#  'Spice Girls',
#  'Adele',
#  'Hugh Jackman',
#  'Jonas Blue',
#  'Richard Smitt',
#  'Kid Crave',
#  'Nick Bonin',
#  'Ella Henderson',
#  'Rex Orange County',
#  'Ryan Lewis',
#  'Imagine Dragons',
#  'The Companions',
#  'Talk Talk',
#  'Sigma',
#  'Carlprit',
#  'Wasted Penguinz',
#  'Kesha',
#  'Matte Caliste',
#  'Victorious Cast',
#  'twocolors',
#  'Aamupojat',
#  'Danny Towers',
#  'Dixie',
#  'Kaoma',
#  'TisaKorean',
#  'Logan Paul',
#  'Dragonette',
#  'Masterboy',
#  'Darin',
#  'Audrey Mika',
#  'Lukas Meijer',
#  'Fabe',
#  'Anders Nilsen',
#  'Electric Light Orchestra',
#  'Dominic Fike',
#  'Savage Garden',
#  'Dopant Beats',
#  'Slash',
#  'D.O.E.',
#  'Tim Bergling',
#  'Elle King',
#  'Venior',
#  'Bebe Rexha',
#  'Game of Thrones',
#  'Jeremy Folderol',
#  'Within Temptation',
#  'Bobby Rock',
#  'Mariah Carey',
#  'Ariana Grande',
#  'Aiko',
#  'DJ KIMERA',
#  'Craig Xen',
#  'Yolanda Be Cool',
#  'Era Istrefi',
#  'Wham!',
#  'S.Pri Noir',
#  'Lil Gotit',
#  'Jay Hardway',
#  'David Rush',
#  'Mk.gee',
#  'Alis',
#  'iann dior',
#  'Florence + The Machine',
#  'Brayden',
#  'Pikku G',
#  'The Police',
#  'Dani Poppitt',
#  'Grey',
#  'Savage',
#  'Bassjackers',
#  'STIG',
#  'Lost Kings',
#  'Ironine',
#  'Brandy',
#  'Mabel',
#  '$wave',
#  'Handsome Luke',
#  'Madonna',
#  'DJ Mental Theos Bazzheadz',
#  'Leighton Meester',
#  'Joey Bada$$',
#  'PnB Rock',
#  'Ghostface Killah',
#  'Riki Sorsa',
#  'Etham',
#  'Raappana',
#  'Say Lou Lou',
#  'Kayla Nicole',
#  'Lil Rain',
#  'ppcocaine',
#  'Ugly God',
#  'Diamond D',
#  'Calvin Harris',
#  'Annie Lennox',
#  'Fergie',
#  'Malo',
#  'Morgan Page',
#  'LEO',
#  'AJ McLean',
#  'Little Big',
#  'Chris Lake',
#  'Asa',
#  'Aikakone',
#  'Oh Wonder',
#  'Justin Timberlake',
#  'Mark Ronson',
#  'INNA',
#  'ODEE',
#  'KC',
#  'Mike Cervello',
#  'Radiohead',
#  'J. Karjalainen Yhtyeineen',
#  'Absofacto',
#  'Peter Könemann',
#  'Bipolar Sunshine',
#  'Kygo',
#  'Selena Gomez & The Scene',
#  'Linda',
#  'Nicholas Fraser',
#  'Janet Jackson',
#  'Sani',
#  'Yung Anime',
#  'Rick Astley',
#  'Jesse Markin',
#  'The Him',
#  'Bon Jovi',
#  'Zara Larsson',
#  'Clairo',
#  'Sandro Cavazza',
#  'Ty James',
#  'Robin og Bugge',
#  'Marcus Vinicius Campos',
#  'Maxx',
#  'Jussi 69',
#  'Egotrippi',
#  'Jeremy Zucker',
#  'Kalle Lindroth',
#  '7ru7h',
#  'John Newman',
#  'Jake Paul',
#  'Lil Wayne',
#  'ZAYN',
#  'Kobe',
#  'Amy Winehouse',
#  'Sandra Lyng',
#  'BEHM',
#  'Jhené Aiko',
#  'Nick "Fierce" Fiorucci',
#  'Six-Two',
#  'Lil Peep',
#  'Grace Phipps',
#  'Yung Berg',
#  'Blush',
#  'DJ Snake',
#  'Tatarka',
#  'HEDEGAARD',
#  'Devon Baldwin',
#  'Beach House',
#  'Gabriella',
#  'KSHMR',
#  'Lil Dicky',
#  'Calpurnia',
#  'Vesa-Matti Loiri',
#  'william',
#  'Demi Lovato',
#  'Jamie Lynn Spears',
#  'Alvaro Soler',
#  'Dax',
#  'Dawin',
#  'Anna Maria Perez de Taglé',
#  'Poju',
#  'Kylie Minogue',
#  'Junge Junge',
#  'Farruko',
#  'BigKlit',
#  'Armin van Buuren',
#  'N.W.A.',
#  'Rick Rock',
#  'Pitbull',
#  'Afrojack',
#  'Casso',
#  'Elokuu',
#  'Camila Mendes',
#  'TIPPA',
#  'Redrama',
#  'La Bouche',
#  'The Wanted',
#  'Jhay Cortez',
#  'Bonnie Tyler',
#  'Foxes',
#  'Rihanna',
#  'JACKBOYS',
#  'Jeezy',
#  'La Cream',
#  'Dagny',
#  'Crystal Castles',
#  'James Brown & The Famous Flames',
#  'DJ Battlecat',
#  'Huncho',
#  'Drenchill',
#  'Sage The Gemini',
#  'Alanis Morissette',
#  "I'Dees",
#  'Janna',
#  'Arttu Lindeman',
#  'Moneybagg Yo',
#  'Kuwada',
#  'YB026',
#  'BØRNS',
#  'Lucenzo',
#  'Snow Patrol',
#  'Parson James',
#  'Luniz',
#  'Lovely Peaches',
#  'Lost Frequencies',
#  'Louis The Child',
#  'Tujamo',
#  'Drake',
#  'BIA',
#  'City Girls',
#  'Isaiah Firebrace',
#  'Das EFX',
#  'Scala & Kolacny Brothers',
#  'A$AP Mob',
#  'Maluma',
#  'Lil Baby',
#  'Drew Love',
#  'Cyndi Lauper',
#  'Soufly',
#  'Profeetat',
#  'Christina Perri',
#  'Aimie Atkinson',
#  '3robi',
#  'Example',
#  'Kasmir',
#  'Guy Sebastian',
#  'Whitney Houston',
#  'Darius & Finlay',
#  'ABBA',
#  'Flipmode Squad',
#  'Ozzy Osbourne',
#  'Sam Fischer',
#  'Pihlaja',
#  'SHAUN',
#  'Nikke Ankara',
#  'Bktherula',
#  'Priory',
#  'Kranium',
#  'Kodaline',
#  'Dj Slim D',
#  'Christina Aguilera',
#  'Kansas',
#  'Outkast',
#  'Ryan',
#  'Rebecca Black',
#  'The Cars',
#  'Roy Jones Jr.',
#  'DJ Sammy',
#  'Skrillex',
#  'Asteriks',
#  'Sasha Lopez',
#  'KiFi',
#  'Amy Macdonald',
#  'Mindless Self Indulgence',
#  'Joe Jonas',
#  'Janieck',
#  'H.E.R.',
#  'Belly',
#  'Tom Walker',
#  'Nate Dogg',
#  'SNAP!',
#  'Becky Hill',
#  'Paperi T',
#  'Ian Everson',
#  'James Blake',
#  'Little Mix',
#  'Disney',
#  'Passenger',
#  'Jay Park',
#  'Black Eyed Peas',
#  'BONES',
#  'TWENTY88',
#  'Julie Bergan',
#  'jxdn',
#  'Peter Piffen',
#  'Kaptan',
#  'Meghan Trainor',
#  'Jennifer Lawrence',
#  'Mouhous',
#  'Kenndog',
#  'ilyTOMMY',
#  'Mr. Probz',
#  'Sideshow',
#  'Waka Flocka Flame',
#  'Nylon Beat',
#  'Summer Walker',
#  'Lauriana Mae',
#  'Eva Simons',
#  'Busy Signal',
#  'Kendrick Lamar',
#  'Olivia',
#  'Eric Turner',
#  'Rock Mafia',
#  'Tham Sway',
#  'Kovee',
#  'Timmy Trumpet',
#  'Monica',
#  'Borgore',
#  'Tiktak',
#  'The Rasmus',
#  'will.i.am',
#  'SLS',
#  'MELO',
#  'Dosdela',
#  'O.C',
#  'Lil 2z',
#  'LOLO',
#  'LuxLyfe',
#  'Arizona Zervas',
#  'Ellie Goulding',
#  'La La La La',
#  'Real Deal',
#  'Tom & Hills',
#  'Conro',
#  'Alexander 23',
#  'Majestic',
#  'Foe G4ng',
#  'BENEE',
#  'Maroon 5',
#  'Ruben Haze',
#  'Hilary Duff',
#  'Crazy Frog',
#  'Taio Cruz',
#  'Chisu',
#  'King Staccz',
#  'HEALTH',
#  'KILLBOY',
#  'Tarrus Riley',
#  'JP Saxe',
#  'Nelly',
#  'Adam Lambert',
#  'Herrat',
#  'Tyga',
#  'Macklemore & Ryan Lewis',
#  'Kuselofte',
#  'Stanaj',
#  'Evang',
#  'ZHU',
#  'O-Zone',
#  'Baby Alice',
#  'View',
#  'Don Toliver',
#  'Duncan Laurence',
#  'Purple Disco Machine',
#  'Parliament Funkadelic',
#  'Ilpo Kaikkonen',
#  'Au/Ra',
#  'Naomi Scott',
#  'Gym Class Heroes',
#  'Dermot Kennedy',
#  'Starley',
#  'Cosmo Sheldrake',
#  'Pekka Kuusisto',
#  'Portion Boys',
#  'Egzod',
#  'Monday 2 Friday',
#  'Thomas Jack',
#  'Trey Songz',
#  'Styles P',
#  'Wanz',
#  'Amba Shepherd',
#  'AlunaGeorge',
#  'Wheeler Walker Jr.',
#  'Kid Francescoli',
#  'Fools Garden',
#  'Jack Stauber',
#  'Takeo Ischi',
#  'All Saints',
#  'Dimitri Vangelis & Wyman',
#  'Gabry Ponte',
#  'Olly Murs',
#  'Cal Chuchesta',
#  'Sebastian Ingrosso',
#  'Good Charlotte',
#  'BACALL',
#  'Stepa',
#  'Hayley Kiyoko',
#  'Mase',
#  'Emily Osment',
#  'Aurora',
#  'Justin Prime',
#  'InfaRed',
#  'Michelle Williams',
#  'Altis',
#  'THEY.',
#  'The Magician',
#  'Sam Feldt',
#  '916frosty',
#  '5 Seconds of Summer',
#  'Sliki & Hamuelos',
#  'Joji',
#  'Lorde',
#  'Neljänsuora',
#  'DJ DX',
#  'The Pussycat Dolls',
#  'TheHxliday',
#  'Joel Corry',
#  'Alesha Dixon',
#  'Oliver Francis',
#  'Fintelligens',
#  'Natalie Imbruglia',
#  'The Carters',
#  'Lidl Stingy',
#  'Vice',
#  'Westside Connection',
#  'Andy Marsh',
#  'Future',
#  'Hozier',
#  'Sapienza',
#  'Hellberg',
#  'Skan',
#  'Hampton The Hampster',
#  'Borgeous',
#  'IDOLS-Finalistit 2007',
#  'Tee Grizzley',
#  'Arash',
#  'A Great Big World',
#  'Denmark + Winter',
#  'R3HAB',
#  'Märkä-Simo',
#  'Juulia',
#  'Swae Lee',
#  'Q-Tip',
#  'Spencer Barnett',
#  'Elastinen',
#  'Laurell',
#  'Jason Agel',
#  'Gabriel Lion',
#  'Shawn Hook',
#  'Mr Magic',
#  'Hight',
#  'Marvin Gaye',
#  'Nelma U',
#  'Verdine White',
#  'Todiefor',
#  'The Chordettes',
#  'BloodPop®',
#  'Fareoh',
#  'Krista Siegfrids',
#  'Ritt Momney',
#  'Eduardo Luzquiños',
#  'J. Karjalainen & Mustat Lasit',
#  'DJ Katch',
#  'Yo Gotti',
#  'Sonny Wilson',
#  'Qulinez',
#  'Getter',
#  'Vengaboys',
#  'Riton',
#  'Happoradio',
#  'Gusttavo Lima',
#  'Jack Perry',
#  'Ida Paul & Kalle Lindroth',
#  'Eppu Normaali',
#  'XS Project',
#  'Dirty South',
#  "Gigi D'Agostino",
#  'Bad Bunny',
#  'Shania Twain',
#  'A Boogie Wit da Hoodie',
#  'Martin Solveig',
#  'The Civil Wars',
#  'Pet Shop Boys',
#  'Wynter Gordon',
#  'Cavallini & Shrty',
#  'Ashe',
#  'Kristinia DeBarge',
#  'Indica',
#  'Anna of the North',
#  'Sophia Annello',
#  'FlicFlac',
#  'Britt Daley',
#  'Owl City',
#  'Fousheé',
#  'VG+',
#  'Cashmere Cat',
#  'Red Hot Chili Peppers',
#  'Bonnie McKee',
#  'HIM',
#  'Henriguez',
#  'DJ Frank E',
#  'BROCKHAMPTON',
#  'Polo G',
#  'Slim Jxmmi',
#  'Lewis Capaldi',
#  'Collagen Girl',
#  'Bryson Tiller',
#  'CMC$',
#  'Kanye West',
#  'Jessie J',
#  'Dido',
#  'Hazers',
#  'Hardwell',
#  'Bakermat',
#  'VASSY',
#  'Chris Brown',
#  'Running Touch',
#  'Yellow Claw',
#  'M.I.A.',
#  'Sultan',
#  'Taikapeili',
#  'Infernal',
#  'Tinashe',
#  'Childish Gambino',
#  'Mascara',
#  'Dizzee Rascal',
#  'Cory Gunz',
#  'Poo Bear',
#  'Simple Plan',
#  'Francesco Yates',
#  'Hurts',
#  'KStewart',
#  'Oliver Nelson',
#  'SNBRN',
#  'Anna Eriksson',
#  'Collin McLoughlin',
#  'Cutting Crew',
#  'Bang For The Buck',
#  'NF',
#  'Turisti',
#  'Mind Vortex',
#  'Axwell',
#  'The Chainsmokers',
#  'Luke Combs',
#  'Ray Dalton',
#  'The Weeknd',
#  'MGMT',
#  'Steve Aoki',
#  'Cheek',
#  'Kielijuhani',
#  'Gucci Mane',
#  'Diddy',
#  'Ca$his',
#  'Surfaces',
#  'Ralph Tresvant',
#  'Niall Horan',
#  'Väinöväinö',
#  'Nirvana',
#  'Tony Junior',
#  'Sugababes',
#  'Freeman',
#  'Aksel Kankaanranta',
#  'Maiki',
#  'Jez Dior',
#  'The Outlaws',
#  'DJ Antoine',
#  'Jonne Aaron',
#  'Trap City',
#  'Daniel Okas',
#  'Cast of Shake It Up: Break It Down',
#  'Kyla',
#  'Bruno Mars',
#  'Havana Brown',
#  'Mike Posner',
#  'TheoFuego',
#  'NLE Choppa',
#  'Kimbra',
#  'William Singe',
#  'Phoebe Ryan',
#  'Pras',
#  'Cousin Stizz',
#  'London On Da Track',
#  'Jessica Jarrell',
#  ...]

# %% [markdown]
# # Getting albums

# %% [markdown]
# In this section we will work with albums to extract information. We will start by extracting all the albums of an artist.

# %%
def get_albums_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50,country="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# Same for albums ids
def get_album_ids_from_artist(artist_id):
    results = sp.artist_albums(artist_id, limit = 50)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return [track["id"] for track in tracks]

# %% [markdown]
# Example: Coldplay

# %%
coldplay_id = "4gzpq5DPGxSnKTe4SA8HAU"
coldplay_albums = get_albums_from_artist(coldplay_id)
coldplay_album_ids = get_album_ids_from_artist(coldplay_id)

# Check artists that played with coldplay
set([artist["name"] for track in coldplay_albums for artist in track["artists"]])
# Out:
# {'Alexandre Desplat',
#  'Alyx Ander',
#  'BTS',
#  'Banda Sinfónica da Polícia de Seguranca Pública',
#  'Banda de Música da Força Aérea',
#  'Coldplay',
#  'David Guetta',
#  'Galantis',
#  'Greta Bradman',
#  'Jon Hopkins',
#  'José Manuel Ferreira Brito',
#  'Ofenbach',
#  'Rihanna',
#  'Robin Schulz',
#  'SUGA',
#  'Seeb',
#  'Selena Gomez',
#  'Swedish House Mafia',
#  'The Chainsmokers',
#  'The String Family',
#  'Tiësto',
#  'Various Artists',
#  'Yotto',
#  'ZHU'}

# %% [markdown]
# ## Getting the songs of a given album

# %%
def get_track_ids_from_albums(album_ids):
    return list(set([i["id"] for j in album_ids for i in sp.album(j)["tracks"]["items"]]))

# %%
coldplay_songs = get_track_ids_from_albums(coldplay_album_ids)

len(coldplay_songs)
# Out:
# 67905

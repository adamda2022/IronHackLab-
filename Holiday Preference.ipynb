# %% [markdown]
# ## Index:
# * [1. The Markdown](#themarkdown)
# * [2. Name and picture of me](#name)
# * [3. Holidays preferences and video](#holidays)

# %% [markdown]
# ## 1. The Markdown<a class="anchor" id="themarkdown"></a>
# <h1> This is a Headtitle

# %% [markdown]
# The Markdown cell is used for Narritive text, Equations using "LATEX", Images and Videos.

# %% [markdown]
# ## 2. Name and picture of me <a class="anchor" id="name"></a>

# %%
x = input('Enter your Name:' )
x
# Out:
# Enter your Name:ADam
# 'ADam'

# %% [markdown]
# ![The%20Rock.jpeg](attachment:The%20Rock.jpeg)

# %% [markdown]
# ## 3. Holiday Preferences <a class="anchor" id="holidays"></a>

# %%
day_preference = input('Please tell me your holiday preferences: ')
day_preference

# %% [markdown]
# ![beach.webp](attachment:beach.webp)

# %% [markdown]
# - <b>Surfing <br>
# - <b>Party <br>
# - <b>Explore new places <br>

# %%
from IPython.display import Image
Image(url= "https://repone.de/wp-content/uploads/2018/04/01-principal-la-roca.jpg", width=400, height=400)
# Out:
# <img src="https://repone.de/wp-content/uploads/2018/04/01-principal-la-roca.jpg" width="400" height="400"/>

# %% [markdown]
# It gives two ways to add phots, one way is to use the insert function. When you use the insert function , you have to change the cell code to markdown. Otherwise you can use the iphython display function in code cell.
#
# At input function the result of the input will save in a variable.

# %% [markdown]
# <b> <span style='color:red'>This Text <span style='color:blue'>shows what is <span style='color:yellow'>possible in <span style='color:pink'>jupyter markdown

# %% [markdown]
# [Beautiful beach]( https://www.youtube.com/watch?v=DGIXT7ce3vQ)

# %% [markdown]
# [The best Song Ever](https://www.youtube.com/watch?v=pHlSE9j5FGY)

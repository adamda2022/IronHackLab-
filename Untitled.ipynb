# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')
df
# Out:
#            region  customer_lifetime_value response  coverage education  \
# 0         arizona                     4809       no     basic   college
# 1      california                     2228       no     basic   college
# 2      washington                    14947       no     basic  bachelor
# 3          oregon                    22332      yes  extended   college
# 4          oregon                     9025       no   premium  bachelor
# ...           ...                      ...      ...       ...       ...
# 10597      nevada                    15563       no   premium  bachelor
# 10598      oregon                     5259       no     basic   college
# 10599     arizona                    23893       no  extended  bachelor
# 10600  california                    11971       no   premium   college
# 10601  california                     6857       no     basic  bachelor
#
#       effective_to_date employment_status gender  income location_code  ...  \
# 0               2/18/11          employed      m   48029      suburban  ...
# 1               1/18/11        unemployed      f   61311      suburban  ...
# 2               2/10/11          employed      m   22139      suburban  ...
# 3               1/11/11          employed      m   49078      suburban  ...
# 4               1/17/11     medical leave      f   23675      suburban  ...
# ...                 ...               ...    ...     ...           ...  ...
# 10597           1/19/11        unemployed      f   38966      suburban  ...
# 10598            1/6/11          employed      f   61146         urban  ...
# 10599            2/6/11          employed      f   39837         rural  ...
# 10600           2/13/11          employed      f   64195         urban  ...
# 10601            1/8/11        unemployed      m   85639      suburban  ...
#
#       months_since_policy_inception  number_of_open_complaints  \
# 0                                52                          0
# 1                                26                          0
# 2                                31                          0
# 3                                 3                          0
# 4                                31                          0
# ...                             ...                        ...
# 10597                            40                          0
# 10598                            68                          0
# 10599                            63                          0
# 10600                            27                          4
# 10601                             1                          0
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# 0                       9  corporate auto  corporate l3            offer3
# 1                       1   personal auto   personal l3            offer4
# 2                       2   personal auto   personal l3            offer3
# 3                       2  corporate auto  corporate l3            offer2
# 4                       7   personal auto   personal l2            offer1
# ...                   ...             ...           ...               ...
# 10597                   7   personal auto   personal l1            offer3
# 10598                   6   personal auto   personal l3            offer2
# 10599                   2  corporate auto  corporate l3            offer1
# 10600                   6   personal auto   personal l1            offer1
# 10601                   3   personal auto   personal l1            offer4
#
#       sales_channel total_claim_amount  vehicle_class vehicle_size
# 0             agent                292  four-door car      medsize
# 1       call center                744  four-door car      medsize
# 2       call center                480            suv      medsize
# 3            branch                484  four-door car      medsize
# 4            branch                707  four-door car      medsize
# ...             ...                ...            ...          ...
# 10597           web               1214     luxury car      medsize
# 10598        branch                273  four-door car      medsize
# 10599           web                381     luxury suv      medsize
# 10600        branch                618            suv      medsize
# 10601           web               1021            suv      medsize
#
# [10602 rows x 23 columns]

# %%
numerical = df.select_dtypes(include=[np.number])
categoricals = df.select_dtypes(include=[np.object0])
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   61311                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10597                    15563   38966                   253
# 10598                     5259   61146                    65
# 10599                    23893   39837                   201
# 10600                    11971   64195                   158
# 10601                     6857   85639                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# 2                           34                             31
# 3                           10                              3
# 4                           25                             31
# ...                        ...                            ...
# 10597                       19                             40
# 10598                        7                             68
# 10599                       11                             63
# 10600                        0                             27
# 10601                       31                              1
#
#        number_of_open_complaints  number_of_policies  total_claim_amount
# 0                              0                   9                 292
# 1                              0                   1                 744
# 2                              0                   2                 480
# 3                              0                   2                 484
# 4                              0                   7                 707
# ...                          ...                 ...                 ...
# 10597                          0                   7                1214
# 10598                          0                   6                 273
# 10599                          0                   2                 381
# 10600                          4                   6                 618
# 10601                          0                   3                1021
#
# [10602 rows x 8 columns]

# %%
numerical.shape
# Out:
# (10602, 8)

# %%
categoricals.shape
# Out:
# (10602, 15)

# %%
numerical[numerical].hist(bins=15, figsize=(15, 6), layout=(2, 4));
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3280/2962633888.py in <module>
# ----> 1 numerical[numerical].hist(bins=15, figsize=(15, 6), layout=(2, 4));
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3443         # Do we have a (boolean) DataFrame?
#    3444         if isinstance(key, DataFrame):
# -> 3445             return self.where(key)
#    3446
#    3447         # Do we have a (boolean) 1d indexer?
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#   10734         try_cast=lib.no_default,
#   10735     ):
# > 10736         return super().where(cond, other, inplace, axis, level, errors, try_cast)
#   10737
#   10738     @deprecate_nonkeyword_arguments(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast)
#    9030             )
#    9031
# -> 9032         return self._where(cond, other, inplace, axis, level, errors=errors)
#    9033
#    9034     @final
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _where(self, cond, other, inplace, axis, level, errors)
#    8786                 for dt in cond.dtypes:
#    8787                     if not is_bool_dtype(dt):
# -> 8788                         raise ValueError(msg.format(dtype=dt))
#    8789         else:
#    8790             # GH#21947 we have an empty DataFrame/Series, could be object-dtype
#
# ValueError: Boolean array expected for the condition, not int64
